# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
import torch.nn.functional as F
import torchaudio
from torchaudio import transforms
from IPython.display import Audio
import torchvision
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd
import os

import math, random

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed = 0
seed_everything(seed)

# %%
class CFG:
    isOneHot = False
    rate = 32000
    num_classes = 264

# %%
class AudioUtil():
  @staticmethod
  def open(audio_file):
    sig, sr = torchaudio.load(audio_file)
    return (sig, sr)

  @staticmethod
  def rechannel(aud, new_channel):
    sig, sr = aud
    if (sig.shape[0] == new_channel):
      return aud
    if (new_channel == 1):
      resig = sig[:1, :]
    else:
      resig = torch.cat([sig, sig, sig])
    return ((resig, sr))

  @staticmethod
  def resample(aud, newsr):
    sig, sr = aud
    if (sr == newsr):
      return aud
    num_channels = sig.shape[0]
    resig = torchaudio.transforms.Resample(sr, newsr)(sig[:1,:])
    if (num_channels > 1):
      retwo = torchaudio.transforms.Resample(sr, newsr)(sig[1:,:])
      resig = torch.cat([resig, retwo])
    return ((resig, newsr))

  @staticmethod
  def pad_trunc(aud, max_ms):
    sig, sr = aud
    num_rows, sig_len = sig.shape
    max_len = sr//1000 * max_ms

    if (sig_len > max_len):
      sig = sig[:,:max_len]

    elif (sig_len < max_len):
      pad_begin_len = random.randint(0, max_len - sig_len)
      pad_end_len = max_len - sig_len - pad_begin_len
      pad_begin = torch.zeros((num_rows, pad_begin_len))
      pad_end = torch.zeros((num_rows, pad_end_len))
      sig = torch.cat((pad_begin, sig, pad_end), 1)    
    return (sig, sr)

  @staticmethod
  def time_shift(aud, shift_limit):
    sig,sr = aud
    _, sig_len = sig.shape
    shift_amt = int(random.random() * shift_limit * sig_len)
    return (sig.roll(shift_amt), sr)

  @staticmethod
  def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
    sig,sr = aud
    top_db = 80
    spec = torchaudio.transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)
    spec = torchaudio.transforms.AmplitudeToDB(top_db=top_db)(spec)
    return (spec)

  @staticmethod
  def spectro_augment(spec, max_mask_pct=0.1, n_freq_masks=1, n_time_masks=1):
    _, n_mels, n_steps = spec.shape
    mask_value = spec.mean()
    aug_spec = spec
    freq_mask_param = max_mask_pct * n_mels
    for _ in range(n_freq_masks):
      aug_spec = torchaudio.transforms.FrequencyMasking(freq_mask_param)(aug_spec, mask_value)
    time_mask_param = max_mask_pct * n_steps
    for _ in range(n_time_masks):
      aug_spec = torchaudio.transforms.TimeMasking(time_mask_param)(aug_spec, mask_value)
    return aug_spec

# %%
meta_df = pd.read_csv('/birdclef-2023/train_metadata.csv')
print('data shape:',meta_df.shape)
meta_df.head()
# Out:
# data shape: (16941, 12)
#   primary_label secondary_labels              type  latitude  longitude  \
# 0       abethr1               []          ['song']    4.3906    38.2788
# 1       abethr1               []          ['call']   -2.9524    38.2921
# 2       abethr1               []          ['song']   -2.9524    38.2921
# 3       abethr1               []          ['song']   -2.9524    38.2921
# 4       abethr1               []  ['call', 'song']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.5
#
#                                  url              filename
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg
# 2  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg
# 3  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg
# 4  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg

# %%
unique_categories = meta_df['primary_label'].unique()
first_10_categories = unique_categories[:10]
meta_df = meta_df[meta_df['primary_label'].isin(first_10_categories)]
print(meta_df.shape)
# Out:
# (473, 12)

# %%
print('Number of classes and number samples in each class:',meta_df.primary_label.value_counts().reset_index().shape)
print('Number of classes with more than 1 sample:',meta_df.primary_label.value_counts().reset_index()\
                                                              .query('primary_label > 1').shape)
# Out:
# Number of classes and number samples in each class: (10, 2)
# Number of classes with more than 1 sample: (10, 2)

# %%
if CFG.isOneHot:
    label = OneHotEncoder(sparse=False)\
                                    .fit_transform(meta_df['primary_label'].to_numpy().reshape(-1,1))
    meta_df['label'] = pd.DataFrame(label).apply(lambda x: list(x), axis = 1)
else:
    meta_df['label'] = LabelEncoder().fit_transform(meta_df['primary_label'])
meta_df.head(2)
# Out:
#   primary_label secondary_labels      type  latitude  longitude  \
# 0       abethr1               []  ['song']    4.3906    38.2788
# 1       abethr1               []  ['call']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
#
#                                  url              filename  label
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg      0
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg      0

# %%
def cv_split(Xtrain, ytrain, n_folds, seed):
    kfold = StratifiedKFold(n_splits = n_folds, shuffle = True, random_state = seed)
    for num, (train_index, val_index) in enumerate(kfold.split(Xtrain, ytrain)):
        Xtrain.loc[val_index, 'fold'] = int(num)
    Xtrain['fold'] = Xtrain['fold'].astype(int)
    return Xtrain
meta_df = cv_split(meta_df,meta_df['primary_label'], 5, 42)
meta_df.head(6)
# Out:
#   primary_label secondary_labels              type  latitude  longitude  \
# 0       abethr1               []          ['song']    4.3906    38.2788
# 1       abethr1               []          ['call']   -2.9524    38.2921
# 2       abethr1               []          ['song']   -2.9524    38.2921
# 3       abethr1               []          ['song']   -2.9524    38.2921
# 4       abethr1               []  ['call', 'song']   -2.9524    38.2921
# 5       abethr1      ['rbsrob1']          ['song']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 5  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.5
# 5  Creative Commons Attribution-NonCommercial-Sha...     3.5
#
#                                  url              filename  label  fold
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg      0     3
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg      0     3
# 2  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg      0     0
# 3  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg      0     4
# 4  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg      0     1
# 5  https://www.xeno-canto.org/379322  abethr1/XC379322.ogg      0     2

# %%
class SoundDS(Dataset):
  def __init__(self, df, data_path ='/birdclef-2023/train_audio/', mode='train'):
    self.df = df
    self.data_path = str(data_path)
    self.duration = 8000
    self.sr = 32000
    self.channel = 3
    self.shift_pct = 0.4
    self.mode = mode
  def __len__(self):
    return len(self.df)    
    
  def __getitem__(self, idx):
    audio_file = self.data_path + self.df.loc[idx, 'filename']
    class_id = np.array(self.df.loc[idx, 'label'])
    aud = AudioUtil.open(audio_file)
    reaud = AudioUtil.resample(aud, self.sr)
    rechan = AudioUtil.rechannel(reaud, self.channel)
    dur_aud = AudioUtil.pad_trunc(rechan, self.duration)
    if self.mode == 'train':
        shift_aud = AudioUtil.time_shift(dur_aud, self.shift_pct)
        sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
        aug_sgram = AudioUtil.spectro_augment(sgram, max_mask_pct=0.1, n_freq_masks=2, n_time_masks=2)
        return aug_sgram, class_id
    else:
        shift_aud = dur_aud
        sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
        return sgram, class_id

# %%
train_ds = SoundDS(meta_df[meta_df.fold != 0].reset_index(), mode='train')
test_ds = SoundDS(meta_df[meta_df.fold == 0].reset_index(), mode='test')
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=16, shuffle=True)
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=16, shuffle=True)

print('train samples ', meta_df[meta_df.fold != 0].shape)
print('test samples ', meta_df[meta_df.fold == 0].shape)
# Out:
# train samples  (378, 14)
# test samples  (95, 14)

# %%
a,b = next(iter(train_dl))
print(a.shape)
print(b.shape)
# Out:
# torch.Size([16, 3, 64, 501])
# torch.Size([16])

# %%
model = torchvision.models.resnet34(pretrained=True)


num_features = model.fc.in_features
model.fc = nn.Linear(num_features, CFG.num_classes)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
myModel = model.to(device)
next(myModel.parameters()).device
# Out:
# /opt/conda/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# /opt/conda/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# device(type='cuda', index=0)

# %% [markdown]
# # 6. Start Training

# %%
def training(model, train_dl, num_epochs):
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
  scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01,
                                                steps_per_epoch=int(len(train_dl)),
                                                epochs=num_epochs,
                                                anneal_strategy='linear')

  best_acc = -1
  for epoch in range(num_epochs):
    running_loss = 0.0
    correct_prediction = 0
    total_prediction = 0

    for i, data in enumerate(train_dl):
        inputs, labels = data[0].to(device), data[1].to(device)
        inputs_m, inputs_s = inputs.mean(), inputs.std()
        inputs = (inputs - inputs_m) / inputs_s
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()
        running_loss += loss.item()
        _, prediction = torch.max(outputs,1)
        correct_prediction += (prediction == labels).sum().item()
        total_prediction += prediction.shape[0]
        if (i + 1) % 1 == 0:    
           print('Epoch [{}/{}], Step [{}/{}], Loss : {:.4f}'
            .format(epoch + 1, num_epochs, i + 1, len(train_dl), running_loss/(i + 1)))
    num_batches = len(train_dl)
    avg_loss = running_loss / num_batches
    acc = correct_prediction/total_prediction
    print(f'Epoch: {epoch + 1}, Loss: {avg_loss:.4f}, Accuracy: {acc:.4f}')

    if (best_acc < acc):
        best_acc = acc
        print("Saving best model!")
        torch.save(model.state_dict(), f'BirdSound_MobileNetV2_fold0_epoch{epoch}.pth')

  print('Finished Training')
  
num_epochs = 15  
training(myModel, train_dl, num_epochs)
# Out:
# Epoch [1/15], Step [1/24], Loss : 5.6219
# Epoch [1/15], Step [2/24], Loss : 5.3636
# Epoch [1/15], Step [3/24], Loss : 5.0221
# Epoch [1/15], Step [4/24], Loss : 4.9101
# Epoch [1/15], Step [5/24], Loss : 4.5313
# Epoch [1/15], Step [6/24], Loss : 4.2813
# Epoch [1/15], Step [7/24], Loss : 4.0626
# Epoch [1/15], Step [8/24], Loss : 4.1152
# Epoch [1/15], Step [9/24], Loss : 3.8533
# Epoch [1/15], Step [10/24], Loss : 3.7177
# Epoch [1/15], Step [11/24], Loss : 3.5946
# Epoch [1/15], Step [12/24], Loss : 3.4083
# Epoch [1/15], Step [13/24], Loss : 3.4044
# Epoch [1/15], Step [14/24], Loss : 3.3890
# Epoch [1/15], Step [15/24], Loss : 3.2875
# Epoch [1/15], Step [16/24], Loss : 3.1850
# Epoch [1/15], Step [17/24], Loss : 3.1074
# Epoch [1/15], Step [18/24], Loss : 3.0479
# Epoch [1/15], Step [19/24], Loss : 2.9908
# Epoch [1/15], Step [20/24], Loss : 2.9464
# Epoch [1/15], Step [21/24], Loss : 2.8757
# Epoch [1/15], Step [22/24], Loss : 2.8018
# Epoch [1/15], Step [23/24], Loss : 2.7507
# Epoch [1/15], Step [24/24], Loss : 2.7092
# Epoch: 1, Loss: 2.7092, Accuracy: 0.3519
# Saving best model!
# Epoch [2/15], Step [1/24], Loss : 2.4152
# Epoch [2/15], Step [2/24], Loss : 2.0430
# Epoch [2/15], Step [3/24], Loss : 1.7899
# Epoch [2/15], Step [4/24], Loss : 1.7736
# Epoch [2/15], Step [5/24], Loss : 1.6753
# Epoch [2/15], Step [6/24], Loss : 1.8085
# Epoch [2/15], Step [7/24], Loss : 1.7128
# Epoch [2/15], Step [8/24], Loss : 1.7007
# Epoch [2/15], Step [9/24], Loss : 1.6558
# Epoch [2/15], Step [10/24], Loss : 1.6390
# Epoch [2/15], Step [11/24], Loss : 1.6806
# Epoch [2/15], Step [12/24], Loss : 1.6413
# Epoch [2/15], Step [13/24], Loss : 1.6789
# Epoch [2/15], Step [14/24], Loss : 1.6494
# Epoch [2/15], Step [15/24], Loss : 1.7097
# Epoch [2/15], Step [16/24], Loss : 1.7356
# Epoch [2/15], Step [17/24], Loss : 1.7410
# Epoch [2/15], Step [18/24], Loss : 1.7623
# Epoch [2/15], Step [19/24], Loss : 1.7789
# Epoch [2/15], Step [20/24], Loss : 1.7766
# Epoch [2/15], Step [21/24], Loss : 1.7753
# Epoch [2/15], Step [22/24], Loss : 1.7613
# Epoch [2/15], Step [23/24], Loss : 1.7545
# Epoch [2/15], Step [24/24], Loss : 1.7501
# Epoch: 2, Loss: 1.7501, Accuracy: 0.3995
# Saving best model!
# Epoch [3/15], Step [1/24], Loss : 1.2379
# Epoch [3/15], Step [2/24], Loss : 1.3450
# Epoch [3/15], Step [3/24], Loss : 1.4688
# Epoch [3/15], Step [4/24], Loss : 1.5987
# Epoch [3/15], Step [5/24], Loss : 1.5768
# Epoch [3/15], Step [6/24], Loss : 1.4535
# Epoch [3/15], Step [7/24], Loss : 1.4241
# Epoch [3/15], Step [8/24], Loss : 1.4179
# Epoch [3/15], Step [9/24], Loss : 1.4085
# Epoch [3/15], Step [10/24], Loss : 1.4632
# Epoch [3/15], Step [11/24], Loss : 1.5640
# Epoch [3/15], Step [12/24], Loss : 1.5357
# Epoch [3/15], Step [13/24], Loss : 1.5710
# Epoch [3/15], Step [14/24], Loss : 1.6281
# Epoch [3/15], Step [15/24], Loss : 1.6243
# Epoch [3/15], Step [16/24], Loss : 1.6217
# Epoch [3/15], Step [17/24], Loss : 1.6078
# Epoch [3/15], Step [18/24], Loss : 1.5895
# Epoch [3/15], Step [19/24], Loss : 1.5838
# Epoch [3/15], Step [20/24], Loss : 1.5826
# Epoch [3/15], Step [21/24], Loss : 1.5845
# Epoch [3/15], Step [22/24], Loss : 1.5808
# Epoch [3/15], Step [23/24], Loss : 1.6096
# Epoch [3/15], Step [24/24], Loss : 1.5728
# Epoch: 3, Loss: 1.5728, Accuracy: 0.5053
# Saving best model!
# Epoch [4/15], Step [1/24], Loss : 1.9674
# Epoch [4/15], Step [2/24], Loss : 1.8109
# Epoch [4/15], Step [3/24], Loss : 1.4823
# Epoch [4/15], Step [4/24], Loss : 1.7270
# Epoch [4/15], Step [5/24], Loss : 1.6480
# Epoch [4/15], Step [6/24], Loss : 1.5823
# Epoch [4/15], Step [7/24], Loss : 1.5444
# Epoch [4/15], Step [8/24], Loss : 1.5478
# Epoch [4/15], Step [9/24], Loss : 1.5632
# Epoch [4/15], Step [10/24], Loss : 1.5422
# Epoch [4/15], Step [11/24], Loss : 1.5423
# Epoch [4/15], Step [12/24], Loss : 1.5933
# Epoch [4/15], Step [13/24], Loss : 1.6736
# Epoch [4/15], Step [14/24], Loss : 1.6831
# Epoch [4/15], Step [15/24], Loss : 1.6434
# Epoch [4/15], Step [16/24], Loss : 1.6219
# Epoch [4/15], Step [17/24], Loss : 1.6841
# Epoch [4/15], Step [18/24], Loss : 1.6708
# Epoch [4/15], Step [19/24], Loss : 1.6957
# Epoch [4/15], Step [20/24], Loss : 1.6863
# Epoch [4/15], Step [21/24], Loss : 1.7153
# Epoch [4/15], Step [22/24], Loss : 1.6989
# Epoch [4/15], Step [23/24], Loss : 1.7170
# Epoch [4/15], Step [24/24], Loss : 1.7216
# Epoch: 4, Loss: 1.7216, Accuracy: 0.5132
# Saving best model!
# Epoch [5/15], Step [1/24], Loss : 1.7308
# Epoch [5/15], Step [2/24], Loss : 1.4958
# Epoch [5/15], Step [3/24], Loss : 1.8069
# Epoch [5/15], Step [4/24], Loss : 1.7948
# Epoch [5/15], Step [5/24], Loss : 1.7447
# Epoch [5/15], Step [6/24], Loss : 1.7826
# Epoch [5/15], Step [7/24], Loss : 2.0470
# Epoch [5/15], Step [8/24], Loss : 1.9911
# Epoch [5/15], Step [9/24], Loss : 1.9924
# Epoch [5/15], Step [10/24], Loss : 1.9254
# Epoch [5/15], Step [11/24], Loss : 1.8874
# Epoch [5/15], Step [12/24], Loss : 1.8881
# Epoch [5/15], Step [13/24], Loss : 1.8715
# Epoch [5/15], Step [14/24], Loss : 1.8700
# Epoch [5/15], Step [15/24], Loss : 1.8515
# Epoch [5/15], Step [16/24], Loss : 1.8023
# Epoch [5/15], Step [17/24], Loss : 1.7696
# Epoch [5/15], Step [18/24], Loss : 1.7637
# Epoch [5/15], Step [19/24], Loss : 1.7400
# Epoch [5/15], Step [20/24], Loss : 1.7265
# Epoch [5/15], Step [21/24], Loss : 1.6918
# Epoch [5/15], Step [22/24], Loss : 1.6739
# Epoch [5/15], Step [23/24], Loss : 1.6603
# Epoch [5/15], Step [24/24], Loss : 1.6526
# Epoch: 5, Loss: 1.6526, Accuracy: 0.4947
# Epoch [6/15], Step [1/24], Loss : 1.5380
# Epoch [6/15], Step [2/24], Loss : 1.3987
# Epoch [6/15], Step [3/24], Loss : 1.1937
# Epoch [6/15], Step [4/24], Loss : 1.3257
# Epoch [6/15], Step [5/24], Loss : 1.3053
# Epoch [6/15], Step [6/24], Loss : 1.2735
# Epoch [6/15], Step [7/24], Loss : 1.3204
# Epoch [6/15], Step [8/24], Loss : 1.3247
# Epoch [6/15], Step [9/24], Loss : 1.2549
# Epoch [6/15], Step [10/24], Loss : 1.2317
# Epoch [6/15], Step [11/24], Loss : 1.2213
# Epoch [6/15], Step [12/24], Loss : 1.2640
# Epoch [6/15], Step [13/24], Loss : 1.2601
# Epoch [6/15], Step [14/24], Loss : 1.3311
# Epoch [6/15], Step [15/24], Loss : 1.3261
# Epoch [6/15], Step [16/24], Loss : 1.2974
# Epoch [6/15], Step [17/24], Loss : 1.3215
# Epoch [6/15], Step [18/24], Loss : 1.3162
# Epoch [6/15], Step [19/24], Loss : 1.3110
# Epoch [6/15], Step [20/24], Loss : 1.3194
# Epoch [6/15], Step [21/24], Loss : 1.3465
# Epoch [6/15], Step [22/24], Loss : 1.3493
# Epoch [6/15], Step [23/24], Loss : 1.3475
# Epoch [6/15], Step [24/24], Loss : 1.3515
# Epoch: 6, Loss: 1.3515, Accuracy: 0.5899
# Saving best model!
# Epoch [7/15], Step [1/24], Loss : 1.0576
# Epoch [7/15], Step [2/24], Loss : 1.1496
# Epoch [7/15], Step [3/24], Loss : 1.1257
# Epoch [7/15], Step [4/24], Loss : 1.0830
# Epoch [7/15], Step [5/24], Loss : 1.0882
# Epoch [7/15], Step [6/24], Loss : 1.0625
# Epoch [7/15], Step [7/24], Loss : 1.2065
# Epoch [7/15], Step [8/24], Loss : 1.1854
# Epoch [7/15], Step [9/24], Loss : 1.1728
# Epoch [7/15], Step [10/24], Loss : 1.1688
# Epoch [7/15], Step [11/24], Loss : 1.1883
# Epoch [7/15], Step [12/24], Loss : 1.1886
# Epoch [7/15], Step [13/24], Loss : 1.1914
# Epoch [7/15], Step [14/24], Loss : 1.1932
# Epoch [7/15], Step [15/24], Loss : 1.1790
# Epoch [7/15], Step [16/24], Loss : 1.1608
# Epoch [7/15], Step [17/24], Loss : 1.1894
# Epoch [7/15], Step [18/24], Loss : 1.1611
# Epoch [7/15], Step [19/24], Loss : 1.1615
# Epoch [7/15], Step [20/24], Loss : 1.1639
# Epoch [7/15], Step [21/24], Loss : 1.1368
# Epoch [7/15], Step [22/24], Loss : 1.1176
# Epoch [7/15], Step [23/24], Loss : 1.1066
# Epoch [7/15], Step [24/24], Loss : 1.0945
# Epoch: 7, Loss: 1.0945, Accuracy: 0.6614
# Saving best model!
# Epoch [8/15], Step [1/24], Loss : 1.1960
# Epoch [8/15], Step [2/24], Loss : 1.0492
# Epoch [8/15], Step [3/24], Loss : 0.9663
# Epoch [8/15], Step [4/24], Loss : 0.9652
# Epoch [8/15], Step [5/24], Loss : 1.0439
# Epoch [8/15], Step [6/24], Loss : 1.0709
# Epoch [8/15], Step [7/24], Loss : 1.0589
# Epoch [8/15], Step [8/24], Loss : 1.0709
# Epoch [8/15], Step [9/24], Loss : 1.0395
# Epoch [8/15], Step [10/24], Loss : 1.0285
# Epoch [8/15], Step [11/24], Loss : 1.0133
# Epoch [8/15], Step [12/24], Loss : 1.0429
# Epoch [8/15], Step [13/24], Loss : 1.0626
# Epoch [8/15], Step [14/24], Loss : 1.1046
# Epoch [8/15], Step [15/24], Loss : 1.1071
# Epoch [8/15], Step [16/24], Loss : 1.1200
# Epoch [8/15], Step [17/24], Loss : 1.1030
# Epoch [8/15], Step [18/24], Loss : 1.1215
# Epoch [8/15], Step [19/24], Loss : 1.0960
# Epoch [8/15], Step [20/24], Loss : 1.0927
# Epoch [8/15], Step [21/24], Loss : 1.0877
# Epoch [8/15], Step [22/24], Loss : 1.0828
# Epoch [8/15], Step [23/24], Loss : 1.0809
# Epoch [8/15], Step [24/24], Loss : 1.0726
# Epoch: 8, Loss: 1.0726, Accuracy: 0.6720
# Saving best model!
# Epoch [9/15], Step [1/24], Loss : 1.0141
# Epoch [9/15], Step [2/24], Loss : 1.1198
# Epoch [9/15], Step [3/24], Loss : 0.9687
# Epoch [9/15], Step [4/24], Loss : 0.9320
# Epoch [9/15], Step [5/24], Loss : 0.8884
# Epoch [9/15], Step [6/24], Loss : 1.0040
# Epoch [9/15], Step [7/24], Loss : 1.0448
# Epoch [9/15], Step [8/24], Loss : 1.0734
# Epoch [9/15], Step [9/24], Loss : 1.0620
# Epoch [9/15], Step [10/24], Loss : 1.0352
# Epoch [9/15], Step [11/24], Loss : 0.9978
# Epoch [9/15], Step [12/24], Loss : 0.9545
# Epoch [9/15], Step [13/24], Loss : 0.9263
# Epoch [9/15], Step [14/24], Loss : 0.8910
# Epoch [9/15], Step [15/24], Loss : 0.8913
# Epoch [9/15], Step [16/24], Loss : 0.9234
# Epoch [9/15], Step [17/24], Loss : 0.9341
# Epoch [9/15], Step [18/24], Loss : 0.9210
# Epoch [9/15], Step [19/24], Loss : 0.9307
# Epoch [9/15], Step [20/24], Loss : 0.9413
# Epoch [9/15], Step [21/24], Loss : 0.9584
# Epoch [9/15], Step [22/24], Loss : 1.0010
# Epoch [9/15], Step [23/24], Loss : 0.9863
# Epoch [9/15], Step [24/24], Loss : 0.9914
# Epoch: 9, Loss: 0.9914, Accuracy: 0.7169
# Saving best model!
# Epoch [10/15], Step [1/24], Loss : 0.5792
# Epoch [10/15], Step [2/24], Loss : 0.7680
# Epoch [10/15], Step [3/24], Loss : 0.7792
# Epoch [10/15], Step [4/24], Loss : 0.7667
# Epoch [10/15], Step [5/24], Loss : 0.7508
# Epoch [10/15], Step [6/24], Loss : 0.7456
# Epoch [10/15], Step [7/24], Loss : 0.8461
# Epoch [10/15], Step [8/24], Loss : 0.8486
# Epoch [10/15], Step [9/24], Loss : 0.7930
# Epoch [10/15], Step [10/24], Loss : 0.8390
# Epoch [10/15], Step [11/24], Loss : 0.8419
# Epoch [10/15], Step [12/24], Loss : 0.8879
# Epoch [10/15], Step [13/24], Loss : 0.8894
# Epoch [10/15], Step [14/24], Loss : 0.9078
# Epoch [10/15], Step [15/24], Loss : 0.9422
# Epoch [10/15], Step [16/24], Loss : 0.9415
# Epoch [10/15], Step [17/24], Loss : 0.9724
# Epoch [10/15], Step [18/24], Loss : 0.9547
# Epoch [10/15], Step [19/24], Loss : 0.9470
# Epoch [10/15], Step [20/24], Loss : 0.9285
# Epoch [10/15], Step [21/24], Loss : 0.9074
# Epoch [10/15], Step [22/24], Loss : 0.9287
# Epoch [10/15], Step [23/24], Loss : 0.9304
# Epoch [10/15], Step [24/24], Loss : 0.9612
# Epoch: 10, Loss: 0.9612, Accuracy: 0.6746
# Epoch [11/15], Step [1/24], Loss : 0.5653
# Epoch [11/15], Step [2/24], Loss : 0.8274
# Epoch [11/15], Step [3/24], Loss : 0.7318
# Epoch [11/15], Step [4/24], Loss : 0.6435
# Epoch [11/15], Step [5/24], Loss : 0.6427
# Epoch [11/15], Step [6/24], Loss : 0.6486
# Epoch [11/15], Step [7/24], Loss : 0.7175
# Epoch [11/15], Step [8/24], Loss : 0.6918
# Epoch [11/15], Step [9/24], Loss : 0.7762
# Epoch [11/15], Step [10/24], Loss : 0.8009
# Epoch [11/15], Step [11/24], Loss : 0.8258
# Epoch [11/15], Step [12/24], Loss : 0.8739
# Epoch [11/15], Step [13/24], Loss : 0.8673
# Epoch [11/15], Step [14/24], Loss : 0.8511
# Epoch [11/15], Step [15/24], Loss : 0.8180
# Epoch [11/15], Step [16/24], Loss : 0.7967
# Epoch [11/15], Step [17/24], Loss : 0.8110
# Epoch [11/15], Step [18/24], Loss : 0.8185
# Epoch [11/15], Step [19/24], Loss : 0.8134
# Epoch [11/15], Step [20/24], Loss : 0.8231
# Epoch [11/15], Step [21/24], Loss : 0.8105
# Epoch [11/15], Step [22/24], Loss : 0.7996
# Epoch [11/15], Step [23/24], Loss : 0.8043
# Epoch [11/15], Step [24/24], Loss : 0.7841
# Epoch: 11, Loss: 0.7841, Accuracy: 0.7381
# Saving best model!
# Epoch [12/15], Step [1/24], Loss : 0.5515
# Epoch [12/15], Step [2/24], Loss : 0.5644
# Epoch [12/15], Step [3/24], Loss : 0.9543
# Epoch [12/15], Step [4/24], Loss : 1.2168
# Epoch [12/15], Step [5/24], Loss : 1.0957
# Epoch [12/15], Step [6/24], Loss : 1.0144
# Epoch [12/15], Step [7/24], Loss : 0.8949
# Epoch [12/15], Step [8/24], Loss : 0.8621
# Epoch [12/15], Step [9/24], Loss : 0.8821
# Epoch [12/15], Step [10/24], Loss : 0.9583
# Epoch [12/15], Step [11/24], Loss : 0.9323
# Epoch [12/15], Step [12/24], Loss : 0.9078
# Epoch [12/15], Step [13/24], Loss : 0.8932
# Epoch [12/15], Step [14/24], Loss : 0.8572
# Epoch [12/15], Step [15/24], Loss : 0.8400
# Epoch [12/15], Step [16/24], Loss : 0.8355
# Epoch [12/15], Step [17/24], Loss : 0.8295
# Epoch [12/15], Step [18/24], Loss : 0.8134
# Epoch [12/15], Step [19/24], Loss : 0.7925
# Epoch [12/15], Step [20/24], Loss : 0.7905
# Epoch [12/15], Step [21/24], Loss : 0.7900
# Epoch [12/15], Step [22/24], Loss : 0.8025
# Epoch [12/15], Step [23/24], Loss : 0.8300
# Epoch [12/15], Step [24/24], Loss : 0.8217
# Epoch: 12, Loss: 0.8217, Accuracy: 0.7434
# Saving best model!
# Epoch [13/15], Step [1/24], Loss : 0.3095
# Epoch [13/15], Step [2/24], Loss : 0.4874
# Epoch [13/15], Step [3/24], Loss : 0.4951
# Epoch [13/15], Step [4/24], Loss : 0.6535
# Epoch [13/15], Step [5/24], Loss : 0.6067
# Epoch [13/15], Step [6/24], Loss : 0.6638
# Epoch [13/15], Step [7/24], Loss : 0.6737
# Epoch [13/15], Step [8/24], Loss : 0.6736
# Epoch [13/15], Step [9/24], Loss : 0.6643
# Epoch [13/15], Step [10/24], Loss : 0.6625
# Epoch [13/15], Step [11/24], Loss : 0.6408
# Epoch [13/15], Step [12/24], Loss : 0.6306
# Epoch [13/15], Step [13/24], Loss : 0.6198
# Epoch [13/15], Step [14/24], Loss : 0.5935
# Epoch [13/15], Step [15/24], Loss : 0.5836
# Epoch [13/15], Step [16/24], Loss : 0.5855
# Epoch [13/15], Step [17/24], Loss : 0.6029
# Epoch [13/15], Step [18/24], Loss : 0.5999
# Epoch [13/15], Step [19/24], Loss : 0.5803
# Epoch [13/15], Step [20/24], Loss : 0.5684
# Epoch [13/15], Step [21/24], Loss : 0.5788
# Epoch [13/15], Step [22/24], Loss : 0.5800
# Epoch [13/15], Step [23/24], Loss : 0.5989
# Epoch [13/15], Step [24/24], Loss : 0.6057
# Epoch: 13, Loss: 0.6057, Accuracy: 0.8016
# Saving best model!
# Epoch [14/15], Step [1/24], Loss : 0.5170
# Epoch [14/15], Step [2/24], Loss : 0.7658
# Epoch [14/15], Step [3/24], Loss : 0.6584
# Epoch [14/15], Step [4/24], Loss : 0.5730
# Epoch [14/15], Step [5/24], Loss : 0.5617
# Epoch [14/15], Step [6/24], Loss : 0.5632
# Epoch [14/15], Step [7/24], Loss : 0.6192
# Epoch [14/15], Step [8/24], Loss : 0.6054
# Epoch [14/15], Step [9/24], Loss : 0.6390
# Epoch [14/15], Step [10/24], Loss : 0.6654
# Epoch [14/15], Step [11/24], Loss : 0.6289
# Epoch [14/15], Step [12/24], Loss : 0.6014
# Epoch [14/15], Step [13/24], Loss : 0.5998
# Epoch [14/15], Step [14/24], Loss : 0.6342
# Epoch [14/15], Step [15/24], Loss : 0.6349
# Epoch [14/15], Step [16/24], Loss : 0.6347
# Epoch [14/15], Step [17/24], Loss : 0.6391
# Epoch [14/15], Step [18/24], Loss : 0.6580
# Epoch [14/15], Step [19/24], Loss : 0.6698
# Epoch [14/15], Step [20/24], Loss : 0.6450
# Epoch [14/15], Step [21/24], Loss : 0.6548
# Epoch [14/15], Step [22/24], Loss : 0.6371
# Epoch [14/15], Step [23/24], Loss : 0.6186
# Epoch [14/15], Step [24/24], Loss : 0.6075
# Epoch: 14, Loss: 0.6075, Accuracy: 0.8148
# Saving best model!
# Epoch [15/15], Step [1/24], Loss : 0.4823
# Epoch [15/15], Step [2/24], Loss : 0.3688
# Epoch [15/15], Step [3/24], Loss : 0.4330
# Epoch [15/15], Step [4/24], Loss : 0.4714
# Epoch [15/15], Step [5/24], Loss : 0.4851
# Epoch [15/15], Step [6/24], Loss : 0.5287
# Epoch [15/15], Step [7/24], Loss : 0.4931
# Epoch [15/15], Step [8/24], Loss : 0.4696
# Epoch [15/15], Step [9/24], Loss : 0.4561
# Epoch [15/15], Step [10/24], Loss : 0.4388
# Epoch [15/15], Step [11/24], Loss : 0.4462
# Epoch [15/15], Step [12/24], Loss : 0.4437
# Epoch [15/15], Step [13/24], Loss : 0.4448
# Epoch [15/15], Step [14/24], Loss : 0.4342
# Epoch [15/15], Step [15/24], Loss : 0.4341
# Epoch [15/15], Step [16/24], Loss : 0.4392
# Epoch [15/15], Step [17/24], Loss : 0.4374
# Epoch [15/15], Step [18/24], Loss : 0.4712
# Epoch [15/15], Step [19/24], Loss : 0.4528
# Epoch [15/15], Step [20/24], Loss : 0.4665
# Epoch [15/15], Step [21/24], Loss : 0.4550
# Epoch [15/15], Step [22/24], Loss : 0.4708
# Epoch [15/15], Step [23/24], Loss : 0.4719
# Epoch [15/15], Step [24/24], Loss : 0.4606
# Epoch: 15, Loss: 0.4606, Accuracy: 0.8519
# Saving best model!
# Finished Training

# %%
def testing(model, test_dl):
    criterion = nn.CrossEntropyLoss()
    gt = []
    pred = []
    with torch.no_grad():
        correct = 0
        total = 0
        val_loss = 0 
        for idx, data_ in enumerate(test_dl):
            inputs, labels = data_[0].to(device), data_[1].to(device)
            inputs_m, inputs_s = inputs.mean(), inputs.std()
            inputs = (inputs - inputs_m) / inputs_s
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, prediction = torch.max(outputs,1)
            predi = torch.softmax(outputs, dim = -1)
            gt.append(labels)
            pred.append(predi[:,1])
            correct += (prediction == labels).sum().item()
            total += prediction.shape[0]
        final_score = 100 * correct / total
        print("Final Test Accuracy", final_score)

# %%
saved_model_path = '/kaggle/working/BirdSound_MobileNetV2_fold0_epoch14.pth'
checkpoint = torch.load(saved_model_path)
# print(checkpoint.keys())
model.load_state_dict(checkpoint)
# model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

testing(model, test_dl)
# Out:
# Final Test Accuracy 83.15789473684211
