# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
import torch.nn.functional as F
import torchaudio
from torchaudio import transforms
from IPython.display import Audio
import torchvision
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd
import os

import math, random

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed = 0
seed_everything(seed)

# %%
class CFG:
    isOneHot = False
    rate = 32000
    num_classes = 264

# %%
class AudioUtil():
  @staticmethod
  def open(audio_file):
    sig, sr = torchaudio.load(audio_file)
    return (sig, sr)

  @staticmethod
  def rechannel(aud, new_channel):
    sig, sr = aud
    if (sig.shape[0] == new_channel):
      return aud

    if (new_channel == 1):
      resig = sig[:1, :]
    else:
      resig = torch.cat([sig, sig, sig])
    return ((resig, sr))

  @staticmethod
  def resample(aud, newsr):
    sig, sr = aud
    if (sr == newsr):
      return aud
    num_channels = sig.shape[0]
    resig = torchaudio.transforms.Resample(sr, newsr)(sig[:1,:])
    if (num_channels > 1):
      retwo = torchaudio.transforms.Resample(sr, newsr)(sig[1:,:])
      resig = torch.cat([resig, retwo])

    return ((resig, newsr))

  @staticmethod
  def pad_trunc(aud, max_ms):
    sig, sr = aud
    num_rows, sig_len = sig.shape
    max_len = sr//1000 * max_ms

    if (sig_len > max_len):
      sig = sig[:,:max_len]

    elif (sig_len < max_len):
      pad_begin_len = random.randint(0, max_len - sig_len)
      pad_end_len = max_len - sig_len - pad_begin_len
      pad_begin = torch.zeros((num_rows, pad_begin_len))
      pad_end = torch.zeros((num_rows, pad_end_len))

      sig = torch.cat((pad_begin, sig, pad_end), 1)
      
    return (sig, sr)

  @staticmethod
  def time_shift(aud, shift_limit):
    sig,sr = aud
    _, sig_len = sig.shape
    shift_amt = int(random.random() * shift_limit * sig_len)
    return (sig.roll(shift_amt), sr)

  @staticmethod
  def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
    sig,sr = aud
    top_db = 80
    spec = torchaudio.transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)
    spec = torchaudio.transforms.AmplitudeToDB(top_db=top_db)(spec)
    return (spec)

  @staticmethod
  def spectro_augment(spec, max_mask_pct=0.1, n_freq_masks=1, n_time_masks=1):
    _, n_mels, n_steps = spec.shape
    mask_value = spec.mean()
    aug_spec = spec

    freq_mask_param = max_mask_pct * n_mels
    for _ in range(n_freq_masks):
      aug_spec = torchaudio.transforms.FrequencyMasking(freq_mask_param)(aug_spec, mask_value)

    time_mask_param = max_mask_pct * n_steps
    for _ in range(n_time_masks):
      aug_spec = torchaudio.transforms.TimeMasking(time_mask_param)(aug_spec, mask_value)

    return aug_spec

# %%
meta_df = pd.read_csv('/birdclef-2023/train_metadata.csv')
print('data shape:',meta_df.shape)
meta_df.head()
# Out:
# data shape: (16941, 12)
#   primary_label secondary_labels              type  latitude  longitude  \
# 0       abethr1               []          ['song']    4.3906    38.2788
# 1       abethr1               []          ['call']   -2.9524    38.2921
# 2       abethr1               []          ['song']   -2.9524    38.2921
# 3       abethr1               []          ['song']   -2.9524    38.2921
# 4       abethr1               []  ['call', 'song']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.5
#
#                                  url              filename
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg
# 2  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg
# 3  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg
# 4  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg

# %%
print('Number of classes and number samples in each class:',meta_df.primary_label.value_counts().reset_index().shape)
print('Number of classes with more than 1 sample:',meta_df.primary_label.value_counts().reset_index()\
                                                              .query('primary_label > 1').shape)
# Out:
# Number of classes and number samples in each class: (264, 2)
# Number of classes with more than 1 sample: (257, 2)

# %%
if CFG.isOneHot:
    label = OneHotEncoder(sparse=False)\
                                    .fit_transform(meta_df['primary_label'].to_numpy().reshape(-1,1))
    meta_df['label'] = pd.DataFrame(label).apply(lambda x: list(x), axis = 1)
else:
    meta_df['label'] = LabelEncoder().fit_transform(meta_df['primary_label'])
meta_df.head(2)
# Out:
#   primary_label secondary_labels      type  latitude  longitude  \
# 0       abethr1               []  ['song']    4.3906    38.2788
# 1       abethr1               []  ['call']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
#
#                                  url              filename  label
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg      0
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg      0

# %%
def cv_split(Xtrain, ytrain, n_folds, seed):
    kfold = StratifiedKFold(n_splits = n_folds, shuffle = True, random_state = seed)
    for num, (train_index, val_index) in enumerate(kfold.split(Xtrain, ytrain)):
        Xtrain.loc[val_index, 'fold'] = int(num)
    Xtrain['fold'] = Xtrain['fold'].astype(int)
    return Xtrain
meta_df = cv_split(meta_df,meta_df['primary_label'], 5, 42)
meta_df.head(6)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   UserWarning,
#   primary_label secondary_labels              type  latitude  longitude  \
# 0       abethr1               []          ['song']    4.3906    38.2788
# 1       abethr1               []          ['call']   -2.9524    38.2921
# 2       abethr1               []          ['song']   -2.9524    38.2921
# 3       abethr1               []          ['song']   -2.9524    38.2921
# 4       abethr1               []  ['call', 'song']   -2.9524    38.2921
# 5       abethr1      ['rbsrob1']          ['song']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 5  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.5
# 5  Creative Commons Attribution-NonCommercial-Sha...     3.5
#
#                                  url              filename  label  fold
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg      0     3
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg      0     3
# 2  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg      0     0
# 3  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg      0     4
# 4  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg      0     1
# 5  https://www.xeno-canto.org/379322  abethr1/XC379322.ogg      0     2

# %%
class SoundDS(Dataset):
  def __init__(self, df, data_path ='/birdclef-2023/train_audio/', mode='train'):
    self.df = df
    self.data_path = str(data_path)
    self.duration = 8000
    self.sr = 32000
    self.channel = 3
    self.shift_pct = 0.4
    self.mode = mode
    
  def __len__(self):
    return len(self.df)    
    
  def __getitem__(self, idx):
    audio_file = self.data_path + self.df.loc[idx, 'filename']
    class_id = np.array(self.df.loc[idx, 'label'])
    aud = AudioUtil.open(audio_file)
    reaud = AudioUtil.resample(aud, self.sr)
    rechan = AudioUtil.rechannel(reaud, self.channel)
    dur_aud = AudioUtil.pad_trunc(rechan, self.duration)
    if self.mode == 'train':
        shift_aud = AudioUtil.time_shift(dur_aud, self.shift_pct)
        sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
        aug_sgram = AudioUtil.spectro_augment(sgram, max_mask_pct=0.1, n_freq_masks=2, n_time_masks=2)

        return aug_sgram, class_id
    else:
        shift_aud = dur_aud
        sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
        return sgram, class_id

# %%
train_ds = SoundDS(meta_df[meta_df.fold != 0].reset_index(), mode='train')
test_ds = SoundDS(meta_df[meta_df.fold == 0].reset_index(), mode='test')
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=16, shuffle=True)
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=16, shuffle=True)

print('train samples ', meta_df[meta_df.fold != 0].shape)
print('test samples ', meta_df[meta_df.fold == 0].shape)
# Out:
# train samples  (13552, 14)
# test samples  (3389, 14)

# %%
a,b = next(iter(train_dl))
print(a.shape)
print(b.shape)
# Out:
# torch.Size([16, 3, 64, 501])
# torch.Size([16])

# %% [markdown]
# # 5. Import Backbone Pretrained Model

# %%
model = torchvision.models.efficientnet_b4(weights=torchvision.models.EfficientNet_B4_Weights.DEFAULT, progress=True)

model.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))
model.classifier = nn.Sequential(nn.Flatten(),
                                 nn.Linear(1792, 256),
                                 nn.ReLU(),
                                 nn.Dropout(0.3),
                                 nn.Linear(256, CFG.num_classes),
                                )
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
myModel = model.to(device)
next(myModel.parameters()).device
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b4_rwightman-7eb33cd5.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b4_rwightman-7eb33cd5.pth
#   0%|          | 0.00/74.5M [00:00<?, ?B/s]
# device(type='cuda', index=0)

# %% [markdown]
# # 6. Start Training

# %%
def training(model, train_dl, num_epochs):
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
  scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01,
                                                steps_per_epoch=int(len(train_dl)),
                                                epochs=num_epochs,
                                                anneal_strategy='linear')

  best_acc = -1
  for epoch in range(num_epochs):
    running_loss = 0.0
    correct_prediction = 0
    total_prediction = 0

    for i, data in enumerate(train_dl):
        inputs, labels = data[0].to(device), data[1].to(device)
        inputs_m, inputs_s = inputs.mean(), inputs.std()
        inputs = (inputs - inputs_m) / inputs_s
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()
        running_loss += loss.item()
        _, prediction = torch.max(outputs,1)
        correct_prediction += (prediction == labels).sum().item()
        total_prediction += prediction.shape[0]

        if (i + 1) % 1 == 0:   
           print('Epoch [{}/{}], Step [{}/{}], Loss : {:.4f}'
            .format(epoch + 1, num_epochs, i + 1, len(train_dl), running_loss/(i + 1)))
    num_batches = len(train_dl)
    avg_loss = running_loss / num_batches
    acc = correct_prediction/total_prediction
    print(f'Epoch: {epoch + 1}, Loss: {avg_loss:.4f}, Accuracy: {acc:.4f}')

    if (best_acc < acc):
        best_acc = acc
        print("Saving best model!")
        torch.save(model.state_dict(), f'BirdSound_EfficientNet_B4_epoch{epoch}.pth')

  print('Finished Training')
  
num_epochs = 15   
training(myModel, train_dl, num_epochs)
# Out:
# Epoch [1/15], Step [1/847], Loss : 5.5790
# Epoch [1/15], Step [2/847], Loss : 5.5837
# Epoch [1/15], Step [3/847], Loss : 5.5873
# Epoch [1/15], Step [4/847], Loss : 5.5949
# Epoch [1/15], Step [5/847], Loss : 5.5852
# Epoch [1/15], Step [6/847], Loss : 5.5875
# Epoch [1/15], Step [7/847], Loss : 5.5842
# Epoch [1/15], Step [8/847], Loss : 5.5825
# Epoch [1/15], Step [9/847], Loss : 5.5806
# Epoch [1/15], Step [10/847], Loss : 5.5792
# Epoch [1/15], Step [11/847], Loss : 5.5765
# Epoch [1/15], Step [12/847], Loss : 5.5713
# Epoch [1/15], Step [13/847], Loss : 5.5687
# Epoch [1/15], Step [14/847], Loss : 5.5657
# Epoch [1/15], Step [15/847], Loss : 5.5598
# Epoch [1/15], Step [16/847], Loss : 5.5600
# Epoch [1/15], Step [17/847], Loss : 5.5561
# Epoch [1/15], Step [18/847], Loss : 5.5521
# Epoch [1/15], Step [19/847], Loss : 5.5467
# Epoch [1/15], Step [20/847], Loss : 5.5462
# Epoch [1/15], Step [21/847], Loss : 5.5427
# Epoch [1/15], Step [22/847], Loss : 5.5418
# Epoch [1/15], Step [23/847], Loss : 5.5385
# Epoch [1/15], Step [24/847], Loss : 5.5320
# Epoch [1/15], Step [25/847], Loss : 5.5279
# Epoch [1/15], Step [26/847], Loss : 5.5220
# Epoch [1/15], Step [27/847], Loss : 5.5169
# Epoch [1/15], Step [28/847], Loss : 5.5131
# Epoch [1/15], Step [29/847], Loss : 5.5117
# Epoch [1/15], Step [30/847], Loss : 5.5023
# Epoch [1/15], Step [31/847], Loss : 5.4997
# Epoch [1/15], Step [32/847], Loss : 5.4917
# Epoch [1/15], Step [33/847], Loss : 5.4911
# Epoch [1/15], Step [34/847], Loss : 5.4887
# Epoch [1/15], Step [35/847], Loss : 5.4814
# Epoch [1/15], Step [36/847], Loss : 5.4756
# Epoch [1/15], Step [37/847], Loss : 5.4712
# Epoch [1/15], Step [38/847], Loss : 5.4678
# Epoch [1/15], Step [39/847], Loss : 5.4606
# Epoch [1/15], Step [40/847], Loss : 5.4581
# Epoch [1/15], Step [41/847], Loss : 5.4467
# Epoch [1/15], Step [42/847], Loss : 5.4435
# Epoch [1/15], Step [43/847], Loss : 5.4434
# Epoch [1/15], Step [44/847], Loss : 5.4369
# Epoch [1/15], Step [45/847], Loss : 5.4337
# Epoch [1/15], Step [46/847], Loss : 5.4318
# Epoch [1/15], Step [47/847], Loss : 5.4169
# Epoch [1/15], Step [48/847], Loss : 5.4123
# Epoch [1/15], Step [49/847], Loss : 5.4044
# Epoch [1/15], Step [50/847], Loss : 5.3990
# Epoch [1/15], Step [51/847], Loss : 5.3868
# Epoch [1/15], Step [52/847], Loss : 5.3774
# Epoch [1/15], Step [53/847], Loss : 5.3729
# Epoch [1/15], Step [54/847], Loss : 5.3700
# Epoch [1/15], Step [55/847], Loss : 5.3606
# Epoch [1/15], Step [56/847], Loss : 5.3561
# Epoch [1/15], Step [57/847], Loss : 5.3547
# Epoch [1/15], Step [58/847], Loss : 5.3543
# Epoch [1/15], Step [59/847], Loss : 5.3475
# Epoch [1/15], Step [60/847], Loss : 5.3342
# Epoch [1/15], Step [61/847], Loss : 5.3298
# Epoch [1/15], Step [62/847], Loss : 5.3399
# Epoch [1/15], Step [63/847], Loss : 5.3395
# Epoch [1/15], Step [64/847], Loss : 5.3379
# Epoch [1/15], Step [65/847], Loss : 5.3280
# Epoch [1/15], Step [66/847], Loss : 5.3207
# Epoch [1/15], Step [67/847], Loss : 5.3219
# Epoch [1/15], Step [68/847], Loss : 5.3279
# Epoch [1/15], Step [69/847], Loss : 5.3281
# Epoch [1/15], Step [70/847], Loss : 5.3332
# Epoch [1/15], Step [71/847], Loss : 5.3256
# Epoch [1/15], Step [72/847], Loss : 5.3234
# Epoch [1/15], Step [73/847], Loss : 5.3238
# Epoch [1/15], Step [74/847], Loss : 5.3208
# Epoch [1/15], Step [75/847], Loss : 5.3302
# Epoch [1/15], Step [76/847], Loss : 5.3204
# Epoch [1/15], Step [77/847], Loss : 5.3121
# Epoch [1/15], Step [78/847], Loss : 5.3066
# Epoch [1/15], Step [79/847], Loss : 5.3025
# Epoch [1/15], Step [80/847], Loss : 5.2967
# Epoch [1/15], Step [81/847], Loss : 5.2976
# Epoch [1/15], Step [82/847], Loss : 5.2987
# Epoch [1/15], Step [83/847], Loss : 5.2995
# Epoch [1/15], Step [84/847], Loss : 5.3000
# Epoch [1/15], Step [85/847], Loss : 5.2947
# Epoch [1/15], Step [86/847], Loss : 5.2905
# Epoch [1/15], Step [87/847], Loss : 5.2886
# Epoch [1/15], Step [88/847], Loss : 5.2913
# Epoch [1/15], Step [89/847], Loss : 5.2882
# Epoch [1/15], Step [90/847], Loss : 5.2839
# Epoch [1/15], Step [91/847], Loss : 5.2849
# Epoch [1/15], Step [92/847], Loss : 5.2854
# Epoch [1/15], Step [93/847], Loss : 5.2854
# Epoch [1/15], Step [94/847], Loss : 5.2806
# Epoch [1/15], Step [95/847], Loss : 5.2771
# Epoch [1/15], Step [96/847], Loss : 5.2774
# Epoch [1/15], Step [97/847], Loss : 5.2738
# Epoch [1/15], Step [98/847], Loss : 5.2715
# Epoch [1/15], Step [99/847], Loss : 5.2690
# Epoch [1/15], Step [100/847], Loss : 5.2660
# Epoch [1/15], Step [101/847], Loss : 5.2645
# Epoch [1/15], Step [102/847], Loss : 5.2591
# Epoch [1/15], Step [103/847], Loss : 5.2554
# Epoch [1/15], Step [104/847], Loss : 5.2506
# Epoch [1/15], Step [105/847], Loss : 5.2495
# Epoch [1/15], Step [106/847], Loss : 5.2487
# Epoch [1/15], Step [107/847], Loss : 5.2449
# Epoch [1/15], Step [108/847], Loss : 5.2429
# Epoch [1/15], Step [109/847], Loss : 5.2367
# Epoch [1/15], Step [110/847], Loss : 5.2316
# Epoch [1/15], Step [111/847], Loss : 5.2264
# Epoch [1/15], Step [112/847], Loss : 5.2258
# Epoch [1/15], Step [113/847], Loss : 5.2298
# Epoch [1/15], Step [114/847], Loss : 5.2247
# Epoch [1/15], Step [115/847], Loss : 5.2195
# Epoch [1/15], Step [116/847], Loss : 5.2135
# Epoch [1/15], Step [117/847], Loss : 5.2139
# Epoch [1/15], Step [118/847], Loss : 5.2086
# Epoch [1/15], Step [119/847], Loss : 5.2063
# Epoch [1/15], Step [120/847], Loss : 5.2100
# Epoch [1/15], Step [121/847], Loss : 5.2060
# Epoch [1/15], Step [122/847], Loss : 5.2038
# Epoch [1/15], Step [123/847], Loss : 5.2021
# Epoch [1/15], Step [124/847], Loss : 5.1985
# Epoch [1/15], Step [125/847], Loss : 5.1946
# Epoch [1/15], Step [126/847], Loss : 5.1977
# Epoch [1/15], Step [127/847], Loss : 5.1931
# Epoch [1/15], Step [128/847], Loss : 5.1886
# Epoch [1/15], Step [129/847], Loss : 5.1874
# Epoch [1/15], Step [130/847], Loss : 5.1879
# Epoch [1/15], Step [131/847], Loss : 5.1849
# Epoch [1/15], Step [132/847], Loss : 5.1836
# Epoch [1/15], Step [133/847], Loss : 5.1806
# Epoch [1/15], Step [134/847], Loss : 5.1750
# Epoch [1/15], Step [135/847], Loss : 5.1703
# Epoch [1/15], Step [136/847], Loss : 5.1651
# Epoch [1/15], Step [137/847], Loss : 5.1612
# Epoch [1/15], Step [138/847], Loss : 5.1580
# Epoch [1/15], Step [139/847], Loss : 5.1601
# Epoch [1/15], Step [140/847], Loss : 5.1593
# Epoch [1/15], Step [141/847], Loss : 5.1602
# Epoch [1/15], Step [142/847], Loss : 5.1576
# Epoch [1/15], Step [143/847], Loss : 5.1551
# Epoch [1/15], Step [144/847], Loss : 5.1558
# Epoch [1/15], Step [145/847], Loss : 5.1552
# Epoch [1/15], Step [146/847], Loss : 5.1557
# Epoch [1/15], Step [147/847], Loss : 5.1533
# Epoch [1/15], Step [148/847], Loss : 5.1538
# Epoch [1/15], Step [149/847], Loss : 5.1510
# Epoch [1/15], Step [150/847], Loss : 5.1504
# Epoch [1/15], Step [151/847], Loss : 5.1476
# Epoch [1/15], Step [152/847], Loss : 5.1461
# Epoch [1/15], Step [153/847], Loss : 5.1441
# Epoch [1/15], Step [154/847], Loss : 5.1423
# Epoch [1/15], Step [155/847], Loss : 5.1390
# Epoch [1/15], Step [156/847], Loss : 5.1390
# Epoch [1/15], Step [157/847], Loss : 5.1367
# Epoch [1/15], Step [158/847], Loss : 5.1329
# Epoch [1/15], Step [159/847], Loss : 5.1311
# Epoch [1/15], Step [160/847], Loss : 5.1286
# Epoch [1/15], Step [161/847], Loss : 5.1244
# Epoch [1/15], Step [162/847], Loss : 5.1230
# Epoch [1/15], Step [163/847], Loss : 5.1200
# Epoch [1/15], Step [164/847], Loss : 5.1194
# Epoch [1/15], Step [165/847], Loss : 5.1168
# Epoch [1/15], Step [166/847], Loss : 5.1153
# Epoch [1/15], Step [167/847], Loss : 5.1114
# Epoch [1/15], Step [168/847], Loss : 5.1089
# Epoch [1/15], Step [169/847], Loss : 5.1057
# Epoch [1/15], Step [170/847], Loss : 5.1024
# Epoch [1/15], Step [171/847], Loss : 5.0988
# Epoch [1/15], Step [172/847], Loss : 5.0981
# Epoch [1/15], Step [173/847], Loss : 5.0948
# Epoch [1/15], Step [174/847], Loss : 5.0981
# Epoch [1/15], Step [175/847], Loss : 5.0961
# Epoch [1/15], Step [176/847], Loss : 5.0952
# Epoch [1/15], Step [177/847], Loss : 5.0974
# Epoch [1/15], Step [178/847], Loss : 5.0965
# Epoch [1/15], Step [179/847], Loss : 5.0940
# Epoch [1/15], Step [180/847], Loss : 5.0966
# Epoch [1/15], Step [181/847], Loss : 5.0980
# Epoch [1/15], Step [182/847], Loss : 5.0994
# Epoch [1/15], Step [183/847], Loss : 5.0994
# Epoch [1/15], Step [184/847], Loss : 5.0954
# Epoch [1/15], Step [185/847], Loss : 5.0922
# Epoch [1/15], Step [186/847], Loss : 5.0917
# Epoch [1/15], Step [187/847], Loss : 5.0904
# Epoch [1/15], Step [188/847], Loss : 5.0890
# Epoch [1/15], Step [189/847], Loss : 5.0875
# Epoch [1/15], Step [190/847], Loss : 5.0837
# Epoch [1/15], Step [191/847], Loss : 5.0851
# Epoch [1/15], Step [192/847], Loss : 5.0846
# Epoch [1/15], Step [193/847], Loss : 5.0829
# Epoch [1/15], Step [194/847], Loss : 5.0791
# Epoch [1/15], Step [195/847], Loss : 5.0798
# Epoch [1/15], Step [196/847], Loss : 5.0783
# Epoch [1/15], Step [197/847], Loss : 5.0738
# Epoch [1/15], Step [198/847], Loss : 5.0727
# Epoch [1/15], Step [199/847], Loss : 5.0710
# Epoch [1/15], Step [200/847], Loss : 5.0704
# Epoch [1/15], Step [201/847], Loss : 5.0683
# Epoch [1/15], Step [202/847], Loss : 5.0677
# Epoch [1/15], Step [203/847], Loss : 5.0633
# Epoch [1/15], Step [204/847], Loss : 5.0591
# Epoch [1/15], Step [205/847], Loss : 5.0569
# Epoch [1/15], Step [206/847], Loss : 5.0560
# Epoch [1/15], Step [207/847], Loss : 5.0565
# Epoch [1/15], Step [208/847], Loss : 5.0535
# Epoch [1/15], Step [209/847], Loss : 5.0508
# Epoch [1/15], Step [210/847], Loss : 5.0523
# Epoch [1/15], Step [211/847], Loss : 5.0525
# Epoch [1/15], Step [212/847], Loss : 5.0530
# Epoch [1/15], Step [213/847], Loss : 5.0520
# Epoch [1/15], Step [214/847], Loss : 5.0518
# Epoch [1/15], Step [215/847], Loss : 5.0502
# Epoch [1/15], Step [216/847], Loss : 5.0492
# Epoch [1/15], Step [217/847], Loss : 5.0488
# Epoch [1/15], Step [218/847], Loss : 5.0482
# Epoch [1/15], Step [219/847], Loss : 5.0495
# Epoch [1/15], Step [220/847], Loss : 5.0492
# Epoch [1/15], Step [221/847], Loss : 5.0466
# Epoch [1/15], Step [222/847], Loss : 5.0456
# Epoch [1/15], Step [223/847], Loss : 5.0407
# Epoch [1/15], Step [224/847], Loss : 5.0414
# Epoch [1/15], Step [225/847], Loss : 5.0414
# Epoch [1/15], Step [226/847], Loss : 5.0382
# Epoch [1/15], Step [227/847], Loss : 5.0359
# Epoch [1/15], Step [228/847], Loss : 5.0367
# Epoch [1/15], Step [229/847], Loss : 5.0362
# Epoch [1/15], Step [230/847], Loss : 5.0352
# Epoch [1/15], Step [231/847], Loss : 5.0347
# Epoch [1/15], Step [232/847], Loss : 5.0323
# Epoch [1/15], Step [233/847], Loss : 5.0312
# Epoch [1/15], Step [234/847], Loss : 5.0302
# Epoch [1/15], Step [235/847], Loss : 5.0292
# Epoch [1/15], Step [236/847], Loss : 5.0292
# Epoch [1/15], Step [237/847], Loss : 5.0274
# Epoch [1/15], Step [238/847], Loss : 5.0279
# Epoch [1/15], Step [239/847], Loss : 5.0283
# Epoch [1/15], Step [240/847], Loss : 5.0264
# Epoch [1/15], Step [241/847], Loss : 5.0258
# Epoch [1/15], Step [242/847], Loss : 5.0264
# Epoch [1/15], Step [243/847], Loss : 5.0245
# Epoch [1/15], Step [244/847], Loss : 5.0207
# Epoch [1/15], Step [245/847], Loss : 5.0195
# Epoch [1/15], Step [246/847], Loss : 5.0183
# Epoch [1/15], Step [247/847], Loss : 5.0162
# Epoch [1/15], Step [248/847], Loss : 5.0128
# Epoch [1/15], Step [249/847], Loss : 5.0098
# Epoch [1/15], Step [250/847], Loss : 5.0097
# Epoch [1/15], Step [251/847], Loss : 5.0091
# Epoch [1/15], Step [252/847], Loss : 5.0090
# Epoch [1/15], Step [253/847], Loss : 5.0065
# Epoch [1/15], Step [254/847], Loss : 5.0029
# Epoch [1/15], Step [255/847], Loss : 5.0017
# Epoch [1/15], Step [256/847], Loss : 5.0001
# Epoch [1/15], Step [257/847], Loss : 4.9985
# Epoch [1/15], Step [258/847], Loss : 4.9971
# Epoch [1/15], Step [259/847], Loss : 4.9970
# Epoch [1/15], Step [260/847], Loss : 4.9972
# Epoch [1/15], Step [261/847], Loss : 4.9954
# Epoch [1/15], Step [262/847], Loss : 4.9961
# Epoch [1/15], Step [263/847], Loss : 4.9950
# Epoch [1/15], Step [264/847], Loss : 4.9920
# Epoch [1/15], Step [265/847], Loss : 4.9916
# Epoch [1/15], Step [266/847], Loss : 4.9922
# Epoch [1/15], Step [267/847], Loss : 4.9933
# Epoch [1/15], Step [268/847], Loss : 4.9921
# Epoch [1/15], Step [269/847], Loss : 4.9923
# Epoch [1/15], Step [270/847], Loss : 4.9922
# Epoch [1/15], Step [271/847], Loss : 4.9894
# Epoch [1/15], Step [272/847], Loss : 4.9871
# Epoch [1/15], Step [273/847], Loss : 4.9865
# Epoch [1/15], Step [274/847], Loss : 4.9836
# Epoch [1/15], Step [275/847], Loss : 4.9850
# Epoch [1/15], Step [276/847], Loss : 4.9845
# Epoch [1/15], Step [277/847], Loss : 4.9795
# Epoch [1/15], Step [278/847], Loss : 4.9785
# Epoch [1/15], Step [279/847], Loss : 4.9774
# Epoch [1/15], Step [280/847], Loss : 4.9771
# Epoch [1/15], Step [281/847], Loss : 4.9745
# Epoch [1/15], Step [282/847], Loss : 4.9747
# Epoch [1/15], Step [283/847], Loss : 4.9723
# Epoch [1/15], Step [284/847], Loss : 4.9708
# Epoch [1/15], Step [285/847], Loss : 4.9678
# Epoch [1/15], Step [286/847], Loss : 4.9666
# Epoch [1/15], Step [287/847], Loss : 4.9684
# Epoch [1/15], Step [288/847], Loss : 4.9667
# Epoch [1/15], Step [289/847], Loss : 4.9622
# Epoch [1/15], Step [290/847], Loss : 4.9625
# Epoch [1/15], Step [291/847], Loss : 4.9599
# Epoch [1/15], Step [292/847], Loss : 4.9571
# Epoch [1/15], Step [293/847], Loss : 4.9542
# Epoch [1/15], Step [294/847], Loss : 4.9534
# Epoch [1/15], Step [295/847], Loss : 4.9522
# Epoch [1/15], Step [296/847], Loss : 4.9507
# Epoch [1/15], Step [297/847], Loss : 4.9504
# Epoch [1/15], Step [298/847], Loss : 4.9489
# Epoch [1/15], Step [299/847], Loss : 4.9478
# Epoch [1/15], Step [300/847], Loss : 4.9434
# Epoch [1/15], Step [301/847], Loss : 4.9425
# Epoch [1/15], Step [302/847], Loss : 4.9403
# Epoch [1/15], Step [303/847], Loss : 4.9389
# Epoch [1/15], Step [304/847], Loss : 4.9391
# Epoch [1/15], Step [305/847], Loss : 4.9384
# Epoch [1/15], Step [306/847], Loss : 4.9384
# Epoch [1/15], Step [307/847], Loss : 4.9422
# Epoch [1/15], Step [308/847], Loss : 4.9407
# Epoch [1/15], Step [309/847], Loss : 4.9408
# Epoch [1/15], Step [310/847], Loss : 4.9400
# Epoch [1/15], Step [311/847], Loss : 4.9385
# Epoch [1/15], Step [312/847], Loss : 4.9365
# Epoch [1/15], Step [313/847], Loss : 4.9335
# Epoch [1/15], Step [314/847], Loss : 4.9322
# Epoch [1/15], Step [315/847], Loss : 4.9322
# Epoch [1/15], Step [316/847], Loss : 4.9302
# Epoch [1/15], Step [317/847], Loss : 4.9285
# Epoch [1/15], Step [318/847], Loss : 4.9285
# Epoch [1/15], Step [319/847], Loss : 4.9293
# Epoch [1/15], Step [320/847], Loss : 4.9283
# Epoch [1/15], Step [321/847], Loss : 4.9281
# Epoch [1/15], Step [322/847], Loss : 4.9274
# Epoch [1/15], Step [323/847], Loss : 4.9250
# Epoch [1/15], Step [324/847], Loss : 4.9243
# Epoch [1/15], Step [325/847], Loss : 4.9228
# Epoch [1/15], Step [326/847], Loss : 4.9226
# Epoch [1/15], Step [327/847], Loss : 4.9201
# Epoch [1/15], Step [328/847], Loss : 4.9171
# Epoch [1/15], Step [329/847], Loss : 4.9168
# Epoch [1/15], Step [330/847], Loss : 4.9141
# Epoch [1/15], Step [331/847], Loss : 4.9132
# Epoch [1/15], Step [332/847], Loss : 4.9108
# Epoch [1/15], Step [333/847], Loss : 4.9113
# Epoch [1/15], Step [334/847], Loss : 4.9122
# Epoch [1/15], Step [335/847], Loss : 4.9126
# Epoch [1/15], Step [336/847], Loss : 4.9114
# Epoch [1/15], Step [337/847], Loss : 4.9112
# Epoch [1/15], Step [338/847], Loss : 4.9097
# Epoch [1/15], Step [339/847], Loss : 4.9074
# Epoch [1/15], Step [340/847], Loss : 4.9077
# Epoch [1/15], Step [341/847], Loss : 4.9056
# Epoch [1/15], Step [342/847], Loss : 4.9056
# Epoch [1/15], Step [343/847], Loss : 4.9035
# Epoch [1/15], Step [344/847], Loss : 4.9009
# Epoch [1/15], Step [345/847], Loss : 4.9001
# Epoch [1/15], Step [346/847], Loss : 4.8990
# Epoch [1/15], Step [347/847], Loss : 4.8954
# Epoch [1/15], Step [348/847], Loss : 4.8955
# Epoch [1/15], Step [349/847], Loss : 4.8954
# Epoch [1/15], Step [350/847], Loss : 4.8940
# Epoch [1/15], Step [351/847], Loss : 4.8943
# Epoch [1/15], Step [352/847], Loss : 4.8923
# Epoch [1/15], Step [353/847], Loss : 4.8909
# Epoch [1/15], Step [354/847], Loss : 4.8914
# Epoch [1/15], Step [355/847], Loss : 4.8891
# Epoch [1/15], Step [356/847], Loss : 4.8891
# Epoch [1/15], Step [357/847], Loss : 4.8897
# Epoch [1/15], Step [358/847], Loss : 4.8884
# Epoch [1/15], Step [359/847], Loss : 4.8881
# Epoch [1/15], Step [360/847], Loss : 4.8864
# Epoch [1/15], Step [361/847], Loss : 4.8865
# Epoch [1/15], Step [362/847], Loss : 4.8861
# Epoch [1/15], Step [363/847], Loss : 4.8838
# Epoch [1/15], Step [364/847], Loss : 4.8825
# Epoch [1/15], Step [365/847], Loss : 4.8813
# Epoch [1/15], Step [366/847], Loss : 4.8796
# Epoch [1/15], Step [367/847], Loss : 4.8790
# Epoch [1/15], Step [368/847], Loss : 4.8779
# Epoch [1/15], Step [369/847], Loss : 4.8751
# Epoch [1/15], Step [370/847], Loss : 4.8755
# Epoch [1/15], Step [371/847], Loss : 4.8752
# Epoch [1/15], Step [372/847], Loss : 4.8753
# Epoch [1/15], Step [373/847], Loss : 4.8738
# Epoch [1/15], Step [374/847], Loss : 4.8730
# Epoch [1/15], Step [375/847], Loss : 4.8719
# Epoch [1/15], Step [376/847], Loss : 4.8699
# Epoch [1/15], Step [377/847], Loss : 4.8687
# Epoch [1/15], Step [378/847], Loss : 4.8664
# Epoch [1/15], Step [379/847], Loss : 4.8644
# Epoch [1/15], Step [380/847], Loss : 4.8629
# Epoch [1/15], Step [381/847], Loss : 4.8604
# Epoch [1/15], Step [382/847], Loss : 4.8608
# Epoch [1/15], Step [383/847], Loss : 4.8620
# Epoch [1/15], Step [384/847], Loss : 4.8622
# Epoch [1/15], Step [385/847], Loss : 4.8620
# Epoch [1/15], Step [386/847], Loss : 4.8612
# Epoch [1/15], Step [387/847], Loss : 4.8593
# Epoch [1/15], Step [388/847], Loss : 4.8576
# Epoch [1/15], Step [389/847], Loss : 4.8580
# Epoch [1/15], Step [390/847], Loss : 4.8573
# Epoch [1/15], Step [391/847], Loss : 4.8573
# Epoch [1/15], Step [392/847], Loss : 4.8566
# Epoch [1/15], Step [393/847], Loss : 4.8568
# Epoch [1/15], Step [394/847], Loss : 4.8545
# Epoch [1/15], Step [395/847], Loss : 4.8529
# Epoch [1/15], Step [396/847], Loss : 4.8522
# Epoch [1/15], Step [397/847], Loss : 4.8521
# Epoch [1/15], Step [398/847], Loss : 4.8515
# Epoch [1/15], Step [399/847], Loss : 4.8490
# Epoch [1/15], Step [400/847], Loss : 4.8495
# Epoch [1/15], Step [401/847], Loss : 4.8501
# Epoch [1/15], Step [402/847], Loss : 4.8494
# Epoch [1/15], Step [403/847], Loss : 4.8484
# Epoch [1/15], Step [404/847], Loss : 4.8483
# Epoch [1/15], Step [405/847], Loss : 4.8474
# Epoch [1/15], Step [406/847], Loss : 4.8456
# Epoch [1/15], Step [407/847], Loss : 4.8424
# Epoch [1/15], Step [408/847], Loss : 4.8401
# Epoch [1/15], Step [409/847], Loss : 4.8391
# Epoch [1/15], Step [410/847], Loss : 4.8379
# Epoch [1/15], Step [411/847], Loss : 4.8362
# Epoch [1/15], Step [412/847], Loss : 4.8327
# Epoch [1/15], Step [413/847], Loss : 4.8290
# Epoch [1/15], Step [414/847], Loss : 4.8302
# Epoch [1/15], Step [415/847], Loss : 4.8322
# Epoch [1/15], Step [416/847], Loss : 4.8309
# Epoch [1/15], Step [417/847], Loss : 4.8280
# Epoch [1/15], Step [418/847], Loss : 4.8276
# Epoch [1/15], Step [419/847], Loss : 4.8272
# Epoch [1/15], Step [420/847], Loss : 4.8246
# Epoch [1/15], Step [421/847], Loss : 4.8268
# Epoch [1/15], Step [422/847], Loss : 4.8242
# Epoch [1/15], Step [423/847], Loss : 4.8231
# Epoch [1/15], Step [424/847], Loss : 4.8196
# Epoch [1/15], Step [425/847], Loss : 4.8181
# Epoch [1/15], Step [426/847], Loss : 4.8177
# Epoch [1/15], Step [427/847], Loss : 4.8146
# Epoch [1/15], Step [428/847], Loss : 4.8124
# Epoch [1/15], Step [429/847], Loss : 4.8101
# Epoch [1/15], Step [430/847], Loss : 4.8083
# Epoch [1/15], Step [431/847], Loss : 4.8088
# Epoch [1/15], Step [432/847], Loss : 4.8083
# Epoch [1/15], Step [433/847], Loss : 4.8070
# Epoch [1/15], Step [434/847], Loss : 4.8059
# Epoch [1/15], Step [435/847], Loss : 4.8051
# Epoch [1/15], Step [436/847], Loss : 4.8060
# Epoch [1/15], Step [437/847], Loss : 4.8059
# Epoch [1/15], Step [438/847], Loss : 4.8027
# Epoch [1/15], Step [439/847], Loss : 4.8017
# Epoch [1/15], Step [440/847], Loss : 4.8011
# Epoch [1/15], Step [441/847], Loss : 4.8021
# Epoch [1/15], Step [442/847], Loss : 4.8017
# Epoch [1/15], Step [443/847], Loss : 4.8013
# Epoch [1/15], Step [444/847], Loss : 4.8001
# Epoch [1/15], Step [445/847], Loss : 4.7993
# Epoch [1/15], Step [446/847], Loss : 4.7993
# Epoch [1/15], Step [447/847], Loss : 4.8000
# Epoch [1/15], Step [448/847], Loss : 4.8000
# Epoch [1/15], Step [449/847], Loss : 4.7980
# Epoch [1/15], Step [450/847], Loss : 4.7964
# Epoch [1/15], Step [451/847], Loss : 4.7940
# Epoch [1/15], Step [452/847], Loss : 4.7941
# Epoch [1/15], Step [453/847], Loss : 4.7940
# Epoch [1/15], Step [454/847], Loss : 4.7921
# Epoch [1/15], Step [455/847], Loss : 4.7910
# Epoch [1/15], Step [456/847], Loss : 4.7911
# Epoch [1/15], Step [457/847], Loss : 4.7910
# Epoch [1/15], Step [458/847], Loss : 4.7893
# Epoch [1/15], Step [459/847], Loss : 4.7893
# Epoch [1/15], Step [460/847], Loss : 4.7900
# Epoch [1/15], Step [461/847], Loss : 4.7889
# Epoch [1/15], Step [462/847], Loss : 4.7864
# Epoch [1/15], Step [463/847], Loss : 4.7846
# Epoch [1/15], Step [464/847], Loss : 4.7831
# Epoch [1/15], Step [465/847], Loss : 4.7818
# Epoch [1/15], Step [466/847], Loss : 4.7805
# Epoch [1/15], Step [467/847], Loss : 4.7798
# Epoch [1/15], Step [468/847], Loss : 4.7793
# Epoch [1/15], Step [469/847], Loss : 4.7790
# Epoch [1/15], Step [470/847], Loss : 4.7779
# Epoch [1/15], Step [471/847], Loss : 4.7770
# Epoch [1/15], Step [472/847], Loss : 4.7752
# Epoch [1/15], Step [473/847], Loss : 4.7732
# Epoch [1/15], Step [474/847], Loss : 4.7720
# Epoch [1/15], Step [475/847], Loss : 4.7709
# Epoch [1/15], Step [476/847], Loss : 4.7712
# Epoch [1/15], Step [477/847], Loss : 4.7704
# Epoch [1/15], Step [478/847], Loss : 4.7688
# Epoch [1/15], Step [479/847], Loss : 4.7679
# Epoch [1/15], Step [480/847], Loss : 4.7687
# Epoch [1/15], Step [481/847], Loss : 4.7672
# Epoch [1/15], Step [482/847], Loss : 4.7662
# Epoch [1/15], Step [483/847], Loss : 4.7650
# Epoch [1/15], Step [484/847], Loss : 4.7639
# Epoch [1/15], Step [485/847], Loss : 4.7645
# Epoch [1/15], Step [486/847], Loss : 4.7638
# Epoch [1/15], Step [487/847], Loss : 4.7621
# Epoch [1/15], Step [488/847], Loss : 4.7616
# Epoch [1/15], Step [489/847], Loss : 4.7607
# Epoch [1/15], Step [490/847], Loss : 4.7584
# Epoch [1/15], Step [491/847], Loss : 4.7569
# Epoch [1/15], Step [492/847], Loss : 4.7570
# Epoch [1/15], Step [493/847], Loss : 4.7561
# Epoch [1/15], Step [494/847], Loss : 4.7545
# Epoch [1/15], Step [495/847], Loss : 4.7544
# Epoch [1/15], Step [496/847], Loss : 4.7539
# Epoch [1/15], Step [497/847], Loss : 4.7515
# Epoch [1/15], Step [498/847], Loss : 4.7502
# Epoch [1/15], Step [499/847], Loss : 4.7473
# Epoch [1/15], Step [500/847], Loss : 4.7496
# Epoch [1/15], Step [501/847], Loss : 4.7481
# Epoch [1/15], Step [502/847], Loss : 4.7487
# Epoch [1/15], Step [503/847], Loss : 4.7466
# Epoch [1/15], Step [504/847], Loss : 4.7451
# Epoch [1/15], Step [505/847], Loss : 4.7437
# Epoch [1/15], Step [506/847], Loss : 4.7429
# Epoch [1/15], Step [507/847], Loss : 4.7427
# Epoch [1/15], Step [508/847], Loss : 4.7413
# Epoch [1/15], Step [509/847], Loss : 4.7413
# Epoch [1/15], Step [510/847], Loss : 4.7426
# Epoch [1/15], Step [511/847], Loss : 4.7411
# Epoch [1/15], Step [512/847], Loss : 4.7411
# Epoch [1/15], Step [513/847], Loss : 4.7402
# Epoch [1/15], Step [514/847], Loss : 4.7392
# Epoch [1/15], Step [515/847], Loss : 4.7383
# Epoch [1/15], Step [516/847], Loss : 4.7373
# Epoch [1/15], Step [517/847], Loss : 4.7362
# Epoch [1/15], Step [518/847], Loss : 4.7354
# Epoch [1/15], Step [519/847], Loss : 4.7349
# Epoch [1/15], Step [520/847], Loss : 4.7339
# Epoch [1/15], Step [521/847], Loss : 4.7338
# Epoch [1/15], Step [522/847], Loss : 4.7346
# Epoch [1/15], Step [523/847], Loss : 4.7340
# Epoch [1/15], Step [524/847], Loss : 4.7335
# Epoch [1/15], Step [525/847], Loss : 4.7324
# Epoch [1/15], Step [526/847], Loss : 4.7312
# Epoch [1/15], Step [527/847], Loss : 4.7301
# Epoch [1/15], Step [528/847], Loss : 4.7308
# Epoch [1/15], Step [529/847], Loss : 4.7320
# Epoch [1/15], Step [530/847], Loss : 4.7317
# Epoch [1/15], Step [531/847], Loss : 4.7302
# Epoch [1/15], Step [532/847], Loss : 4.7289
# Epoch [1/15], Step [533/847], Loss : 4.7283
# Epoch [1/15], Step [534/847], Loss : 4.7286
# Epoch [1/15], Step [535/847], Loss : 4.7272
# Epoch [1/15], Step [536/847], Loss : 4.7254
# Epoch [1/15], Step [537/847], Loss : 4.7253
# Epoch [1/15], Step [538/847], Loss : 4.7241
# Epoch [1/15], Step [539/847], Loss : 4.7236
# Epoch [1/15], Step [540/847], Loss : 4.7234
# Epoch [1/15], Step [541/847], Loss : 4.7195
# Epoch [1/15], Step [542/847], Loss : 4.7180
# Epoch [1/15], Step [543/847], Loss : 4.7165
# Epoch [1/15], Step [544/847], Loss : 4.7170
# Epoch [1/15], Step [545/847], Loss : 4.7160
# Epoch [1/15], Step [546/847], Loss : 4.7170
# Epoch [1/15], Step [547/847], Loss : 4.7145
# Epoch [1/15], Step [548/847], Loss : 4.7132
# Epoch [1/15], Step [549/847], Loss : 4.7134
# Epoch [1/15], Step [550/847], Loss : 4.7126
# Epoch [1/15], Step [551/847], Loss : 4.7121
# Epoch [1/15], Step [552/847], Loss : 4.7106
# Epoch [1/15], Step [553/847], Loss : 4.7103
# Epoch [1/15], Step [554/847], Loss : 4.7088
# Epoch [1/15], Step [555/847], Loss : 4.7087
# Epoch [1/15], Step [556/847], Loss : 4.7075
# Epoch [1/15], Step [557/847], Loss : 4.7080
# Epoch [1/15], Step [558/847], Loss : 4.7064
# Epoch [1/15], Step [559/847], Loss : 4.7048
# Epoch [1/15], Step [560/847], Loss : 4.7051
# Epoch [1/15], Step [561/847], Loss : 4.7048
# Epoch [1/15], Step [562/847], Loss : 4.7043
# Epoch [1/15], Step [563/847], Loss : 4.7032
# Epoch [1/15], Step [564/847], Loss : 4.7027
# Epoch [1/15], Step [565/847], Loss : 4.7026
# Epoch [1/15], Step [566/847], Loss : 4.7025
# Epoch [1/15], Step [567/847], Loss : 4.7027
# Epoch [1/15], Step [568/847], Loss : 4.7020
# Epoch [1/15], Step [569/847], Loss : 4.7011
# Epoch [1/15], Step [570/847], Loss : 4.7014
# Epoch [1/15], Step [571/847], Loss : 4.7012
# Epoch [1/15], Step [572/847], Loss : 4.6982
# Epoch [1/15], Step [573/847], Loss : 4.6976
# Epoch [1/15], Step [574/847], Loss : 4.6973
# Epoch [1/15], Step [575/847], Loss : 4.6950
# Epoch [1/15], Step [576/847], Loss : 4.6940
# Epoch [1/15], Step [577/847], Loss : 4.6942
# Epoch [1/15], Step [578/847], Loss : 4.6927
# Epoch [1/15], Step [579/847], Loss : 4.6924
# Epoch [1/15], Step [580/847], Loss : 4.6910
# Epoch [1/15], Step [581/847], Loss : 4.6901
# Epoch [1/15], Step [582/847], Loss : 4.6900
# Epoch [1/15], Step [583/847], Loss : 4.6896
# Epoch [1/15], Step [584/847], Loss : 4.6893
# Epoch [1/15], Step [585/847], Loss : 4.6879
# Epoch [1/15], Step [586/847], Loss : 4.6858
# Epoch [1/15], Step [587/847], Loss : 4.6849
# Epoch [1/15], Step [588/847], Loss : 4.6842
# Epoch [1/15], Step [589/847], Loss : 4.6833
# Epoch [1/15], Step [590/847], Loss : 4.6827
# Epoch [1/15], Step [591/847], Loss : 4.6835
# Epoch [1/15], Step [592/847], Loss : 4.6829
# Epoch [1/15], Step [593/847], Loss : 4.6828
# Epoch [1/15], Step [594/847], Loss : 4.6820
# Epoch [1/15], Step [595/847], Loss : 4.6805
# Epoch [1/15], Step [596/847], Loss : 4.6790
# Epoch [1/15], Step [597/847], Loss : 4.6788
# Epoch [1/15], Step [598/847], Loss : 4.6773
# Epoch [1/15], Step [599/847], Loss : 4.6778
# Epoch [1/15], Step [600/847], Loss : 4.6784
# Epoch [1/15], Step [601/847], Loss : 4.6773
# Epoch [1/15], Step [602/847], Loss : 4.6805
# Epoch [1/15], Step [603/847], Loss : 4.6806
# Epoch [1/15], Step [604/847], Loss : 4.6794
# Epoch [1/15], Step [605/847], Loss : 4.6791
# Epoch [1/15], Step [606/847], Loss : 4.6794
# Epoch [1/15], Step [607/847], Loss : 4.6788
# Epoch [1/15], Step [608/847], Loss : 4.6773
# Epoch [1/15], Step [609/847], Loss : 4.6753
# Epoch [1/15], Step [610/847], Loss : 4.6751
# Epoch [1/15], Step [611/847], Loss : 4.6746
# Epoch [1/15], Step [612/847], Loss : 4.6757
# Epoch [1/15], Step [613/847], Loss : 4.6758
# Epoch [1/15], Step [614/847], Loss : 4.6752
# Epoch [1/15], Step [615/847], Loss : 4.6750
# Epoch [1/15], Step [616/847], Loss : 4.6749
# Epoch [1/15], Step [617/847], Loss : 4.6744
# Epoch [1/15], Step [618/847], Loss : 4.6745
# Epoch [1/15], Step [619/847], Loss : 4.6747
# Epoch [1/15], Step [620/847], Loss : 4.6748
# Epoch [1/15], Step [621/847], Loss : 4.6743
# Epoch [1/15], Step [622/847], Loss : 4.6733
# Epoch [1/15], Step [623/847], Loss : 4.6728
# Epoch [1/15], Step [624/847], Loss : 4.6728
# Epoch [1/15], Step [625/847], Loss : 4.6728
# Epoch [1/15], Step [626/847], Loss : 4.6715
# Epoch [1/15], Step [627/847], Loss : 4.6704
# Epoch [1/15], Step [628/847], Loss : 4.6700
# Epoch [1/15], Step [629/847], Loss : 4.6682
# Epoch [1/15], Step [630/847], Loss : 4.6668
# Epoch [1/15], Step [631/847], Loss : 4.6665
# Epoch [1/15], Step [632/847], Loss : 4.6648
# Epoch [1/15], Step [633/847], Loss : 4.6650
# Epoch [1/15], Step [634/847], Loss : 4.6638
# Epoch [1/15], Step [635/847], Loss : 4.6632
# Epoch [1/15], Step [636/847], Loss : 4.6622
# Epoch [1/15], Step [637/847], Loss : 4.6610
# Epoch [1/15], Step [638/847], Loss : 4.6611
# Epoch [1/15], Step [639/847], Loss : 4.6593
# Epoch [1/15], Step [640/847], Loss : 4.6585
# Epoch [1/15], Step [641/847], Loss : 4.6570
# Epoch [1/15], Step [642/847], Loss : 4.6568
# Epoch [1/15], Step [643/847], Loss : 4.6557
# Epoch [1/15], Step [644/847], Loss : 4.6557
# Epoch [1/15], Step [645/847], Loss : 4.6559
# Epoch [1/15], Step [646/847], Loss : 4.6546
# Epoch [1/15], Step [647/847], Loss : 4.6543
# Epoch [1/15], Step [648/847], Loss : 4.6539
# Epoch [1/15], Step [649/847], Loss : 4.6525
# Epoch [1/15], Step [650/847], Loss : 4.6506
# Epoch [1/15], Step [651/847], Loss : 4.6520
# Epoch [1/15], Step [652/847], Loss : 4.6504
# Epoch [1/15], Step [653/847], Loss : 4.6488
# Epoch [1/15], Step [654/847], Loss : 4.6479
# Epoch [1/15], Step [655/847], Loss : 4.6462
# Epoch [1/15], Step [656/847], Loss : 4.6460
# Epoch [1/15], Step [657/847], Loss : 4.6454
# Epoch [1/15], Step [658/847], Loss : 4.6445
# Epoch [1/15], Step [659/847], Loss : 4.6443
# Epoch [1/15], Step [660/847], Loss : 4.6428
# Epoch [1/15], Step [661/847], Loss : 4.6423
# Epoch [1/15], Step [662/847], Loss : 4.6427
# Epoch [1/15], Step [663/847], Loss : 4.6419
# Epoch [1/15], Step [664/847], Loss : 4.6409
# Epoch [1/15], Step [665/847], Loss : 4.6406
# Epoch [1/15], Step [666/847], Loss : 4.6398
# Epoch [1/15], Step [667/847], Loss : 4.6383
# Epoch [1/15], Step [668/847], Loss : 4.6380
# Epoch [1/15], Step [669/847], Loss : 4.6388
# Epoch [1/15], Step [670/847], Loss : 4.6369
# Epoch [1/15], Step [671/847], Loss : 4.6366
# Epoch [1/15], Step [672/847], Loss : 4.6382
# Epoch [1/15], Step [673/847], Loss : 4.6378
# Epoch [1/15], Step [674/847], Loss : 4.6388
# Epoch [1/15], Step [675/847], Loss : 4.6376
# Epoch [1/15], Step [676/847], Loss : 4.6387
# Epoch [1/15], Step [677/847], Loss : 4.6372
# Epoch [1/15], Step [678/847], Loss : 4.6370
# Epoch [1/15], Step [679/847], Loss : 4.6361
# Epoch [1/15], Step [680/847], Loss : 4.6341
# Epoch [1/15], Step [681/847], Loss : 4.6334
# Epoch [1/15], Step [682/847], Loss : 4.6325
# Epoch [1/15], Step [683/847], Loss : 4.6316
# Epoch [1/15], Step [684/847], Loss : 4.6315
# Epoch [1/15], Step [685/847], Loss : 4.6308
# Epoch [1/15], Step [686/847], Loss : 4.6296
# Epoch [1/15], Step [687/847], Loss : 4.6283
# Epoch [1/15], Step [688/847], Loss : 4.6281
# Epoch [1/15], Step [689/847], Loss : 4.6265
# Epoch [1/15], Step [690/847], Loss : 4.6258
# Epoch [1/15], Step [691/847], Loss : 4.6237
# Epoch [1/15], Step [692/847], Loss : 4.6236
# Epoch [1/15], Step [693/847], Loss : 4.6229
# Epoch [1/15], Step [694/847], Loss : 4.6220
# Epoch [1/15], Step [695/847], Loss : 4.6217
# Epoch [1/15], Step [696/847], Loss : 4.6202
# Epoch [1/15], Step [697/847], Loss : 4.6201
# Epoch [1/15], Step [698/847], Loss : 4.6189
# Epoch [1/15], Step [699/847], Loss : 4.6186
# Epoch [1/15], Step [700/847], Loss : 4.6179
# Epoch [1/15], Step [701/847], Loss : 4.6179
# Epoch [1/15], Step [702/847], Loss : 4.6181
# Epoch [1/15], Step [703/847], Loss : 4.6161
# Epoch [1/15], Step [704/847], Loss : 4.6167
# Epoch [1/15], Step [705/847], Loss : 4.6165
# Epoch [1/15], Step [706/847], Loss : 4.6151
# Epoch [1/15], Step [707/847], Loss : 4.6149
# Epoch [1/15], Step [708/847], Loss : 4.6138
# Epoch [1/15], Step [709/847], Loss : 4.6130
# Epoch [1/15], Step [710/847], Loss : 4.6121
# Epoch [1/15], Step [711/847], Loss : 4.6130
# Epoch [1/15], Step [712/847], Loss : 4.6111
# Epoch [1/15], Step [713/847], Loss : 4.6108
# Epoch [1/15], Step [714/847], Loss : 4.6120
# Epoch [1/15], Step [715/847], Loss : 4.6121
# Epoch [1/15], Step [716/847], Loss : 4.6119
# Epoch [1/15], Step [717/847], Loss : 4.6103
# Epoch [1/15], Step [718/847], Loss : 4.6099
# Epoch [1/15], Step [719/847], Loss : 4.6100
# Epoch [1/15], Step [720/847], Loss : 4.6094
# Epoch [1/15], Step [721/847], Loss : 4.6087
# Epoch [1/15], Step [722/847], Loss : 4.6083
# Epoch [1/15], Step [723/847], Loss : 4.6067
# Epoch [1/15], Step [724/847], Loss : 4.6051
# Epoch [1/15], Step [725/847], Loss : 4.6041
# Epoch [1/15], Step [726/847], Loss : 4.6034
# Epoch [1/15], Step [727/847], Loss : 4.6027
# Epoch [1/15], Step [728/847], Loss : 4.6025
# Epoch [1/15], Step [729/847], Loss : 4.6011
# Epoch [1/15], Step [730/847], Loss : 4.6003
# Epoch [1/15], Step [731/847], Loss : 4.6003
# Epoch [1/15], Step [732/847], Loss : 4.5994
# Epoch [1/15], Step [733/847], Loss : 4.5987
# Epoch [1/15], Step [734/847], Loss : 4.5969
# Epoch [1/15], Step [735/847], Loss : 4.5975
# Epoch [1/15], Step [736/847], Loss : 4.5965
# Epoch [1/15], Step [737/847], Loss : 4.5954
# Epoch [1/15], Step [738/847], Loss : 4.5948
# Epoch [1/15], Step [739/847], Loss : 4.5935
# Epoch [1/15], Step [740/847], Loss : 4.5926
# Epoch [1/15], Step [741/847], Loss : 4.5915
# Epoch [1/15], Step [742/847], Loss : 4.5913
# Epoch [1/15], Step [743/847], Loss : 4.5923
# Epoch [1/15], Step [744/847], Loss : 4.5927
# Epoch [1/15], Step [745/847], Loss : 4.5935
# Epoch [1/15], Step [746/847], Loss : 4.5914
# Epoch [1/15], Step [747/847], Loss : 4.5903
# Epoch [1/15], Step [748/847], Loss : 4.5901
# Epoch [1/15], Step [749/847], Loss : 4.5898
# Epoch [1/15], Step [750/847], Loss : 4.5901
# Epoch [1/15], Step [751/847], Loss : 4.5898
# Epoch [1/15], Step [752/847], Loss : 4.5892
# Epoch [1/15], Step [753/847], Loss : 4.5899
# Epoch [1/15], Step [754/847], Loss : 4.5892
# Epoch [1/15], Step [755/847], Loss : 4.5892
# Epoch [1/15], Step [756/847], Loss : 4.5875
# Epoch [1/15], Step [757/847], Loss : 4.5873
# Epoch [1/15], Step [758/847], Loss : 4.5870
# Epoch [1/15], Step [759/847], Loss : 4.5868
# Epoch [1/15], Step [760/847], Loss : 4.5861
# Epoch [1/15], Step [761/847], Loss : 4.5854
# Epoch [1/15], Step [762/847], Loss : 4.5850
# Epoch [1/15], Step [763/847], Loss : 4.5847
# Epoch [1/15], Step [764/847], Loss : 4.5842
# Epoch [1/15], Step [765/847], Loss : 4.5835
# Epoch [1/15], Step [766/847], Loss : 4.5829
# Epoch [1/15], Step [767/847], Loss : 4.5819
# Epoch [1/15], Step [768/847], Loss : 4.5818
# Epoch [1/15], Step [769/847], Loss : 4.5803
# Epoch [1/15], Step [770/847], Loss : 4.5802
# Epoch [1/15], Step [771/847], Loss : 4.5795
# Epoch [1/15], Step [772/847], Loss : 4.5789
# Epoch [1/15], Step [773/847], Loss : 4.5788
# Epoch [1/15], Step [774/847], Loss : 4.5780
# Epoch [1/15], Step [775/847], Loss : 4.5779
# Epoch [1/15], Step [776/847], Loss : 4.5769
# Epoch [1/15], Step [777/847], Loss : 4.5757
# Epoch [1/15], Step [778/847], Loss : 4.5764
# Epoch [1/15], Step [779/847], Loss : 4.5766
# Epoch [1/15], Step [780/847], Loss : 4.5762
# Epoch [1/15], Step [781/847], Loss : 4.5756
# Epoch [1/15], Step [782/847], Loss : 4.5757
# Epoch [1/15], Step [783/847], Loss : 4.5754
# Epoch [1/15], Step [784/847], Loss : 4.5737
# Epoch [1/15], Step [785/847], Loss : 4.5727
# Epoch [1/15], Step [786/847], Loss : 4.5730
# Epoch [1/15], Step [787/847], Loss : 4.5726
# Epoch [1/15], Step [788/847], Loss : 4.5726
# Epoch [1/15], Step [789/847], Loss : 4.5722
# Epoch [1/15], Step [790/847], Loss : 4.5710
# Epoch [1/15], Step [791/847], Loss : 4.5708
# Epoch [1/15], Step [792/847], Loss : 4.5699
# Epoch [1/15], Step [793/847], Loss : 4.5689
# Epoch [1/15], Step [794/847], Loss : 4.5683
# Epoch [1/15], Step [795/847], Loss : 4.5668
# Epoch [1/15], Step [796/847], Loss : 4.5669
# Epoch [1/15], Step [797/847], Loss : 4.5687
# Epoch [1/15], Step [798/847], Loss : 4.5686
# Epoch [1/15], Step [799/847], Loss : 4.5673
# Epoch [1/15], Step [800/847], Loss : 4.5669
# Epoch [1/15], Step [801/847], Loss : 4.5671
# Epoch [1/15], Step [802/847], Loss : 4.5667
# Epoch [1/15], Step [803/847], Loss : 4.5663
# Epoch [1/15], Step [804/847], Loss : 4.5653
# Epoch [1/15], Step [805/847], Loss : 4.5645
# Epoch [1/15], Step [806/847], Loss : 4.5645
# Epoch [1/15], Step [807/847], Loss : 4.5639
# Epoch [1/15], Step [808/847], Loss : 4.5638
# Epoch [1/15], Step [809/847], Loss : 4.5636
# Epoch [1/15], Step [810/847], Loss : 4.5628
# Epoch [1/15], Step [811/847], Loss : 4.5616
# Epoch [1/15], Step [812/847], Loss : 4.5614
# Epoch [1/15], Step [813/847], Loss : 4.5609
# Epoch [1/15], Step [814/847], Loss : 4.5608
# Epoch [1/15], Step [815/847], Loss : 4.5588
# Epoch [1/15], Step [816/847], Loss : 4.5583
# Epoch [1/15], Step [817/847], Loss : 4.5594
# Epoch [1/15], Step [818/847], Loss : 4.5594
# Epoch [1/15], Step [819/847], Loss : 4.5592
# Epoch [1/15], Step [820/847], Loss : 4.5581
# Epoch [1/15], Step [821/847], Loss : 4.5570
# Epoch [1/15], Step [822/847], Loss : 4.5565
# Epoch [1/15], Step [823/847], Loss : 4.5558
# Epoch [1/15], Step [824/847], Loss : 4.5554
# Epoch [1/15], Step [825/847], Loss : 4.5565
# Epoch [1/15], Step [826/847], Loss : 4.5556
# Epoch [1/15], Step [827/847], Loss : 4.5556
# Epoch [1/15], Step [828/847], Loss : 4.5550
# Epoch [1/15], Step [829/847], Loss : 4.5546
# Epoch [1/15], Step [830/847], Loss : 4.5539
# Epoch [1/15], Step [831/847], Loss : 4.5535
# Epoch [1/15], Step [832/847], Loss : 4.5542
# Epoch [1/15], Step [833/847], Loss : 4.5545
# Epoch [1/15], Step [834/847], Loss : 4.5533
# Epoch [1/15], Step [835/847], Loss : 4.5538
# Epoch [1/15], Step [836/847], Loss : 4.5533
# Epoch [1/15], Step [837/847], Loss : 4.5533
# Epoch [1/15], Step [838/847], Loss : 4.5520
# Epoch [1/15], Step [839/847], Loss : 4.5518
# Epoch [1/15], Step [840/847], Loss : 4.5508
# Epoch [1/15], Step [841/847], Loss : 4.5504
# Epoch [1/15], Step [842/847], Loss : 4.5492
# Epoch [1/15], Step [843/847], Loss : 4.5498
# Epoch [1/15], Step [844/847], Loss : 4.5490
# Epoch [1/15], Step [845/847], Loss : 4.5490
# Epoch [1/15], Step [846/847], Loss : 4.5480
# Epoch [1/15], Step [847/847], Loss : 4.5469
# Epoch: 1, Loss: 4.5469, Accuracy: 0.1249
# Saving best model!
# Epoch [2/15], Step [1/847], Loss : 3.6318
# Epoch [2/15], Step [2/847], Loss : 3.9332
# Epoch [2/15], Step [3/847], Loss : 4.2553
# Epoch [2/15], Step [4/847], Loss : 3.9784
# Epoch [2/15], Step [5/847], Loss : 3.8629
# Epoch [2/15], Step [6/847], Loss : 3.8231
# Epoch [2/15], Step [7/847], Loss : 3.8109
# Epoch [2/15], Step [8/847], Loss : 3.8562
# Epoch [2/15], Step [9/847], Loss : 3.8167
# Epoch [2/15], Step [10/847], Loss : 3.8842
# Epoch [2/15], Step [11/847], Loss : 3.9195
# Epoch [2/15], Step [12/847], Loss : 3.8622
# Epoch [2/15], Step [13/847], Loss : 3.8216
# Epoch [2/15], Step [14/847], Loss : 3.7996
# Epoch [2/15], Step [15/847], Loss : 3.7272
# Epoch [2/15], Step [16/847], Loss : 3.7261
# Epoch [2/15], Step [17/847], Loss : 3.7352
# Epoch [2/15], Step [18/847], Loss : 3.8070
# Epoch [2/15], Step [19/847], Loss : 3.8387
# Epoch [2/15], Step [20/847], Loss : 3.8247
# Epoch [2/15], Step [21/847], Loss : 3.8148
# Epoch [2/15], Step [22/847], Loss : 3.8431
# Epoch [2/15], Step [23/847], Loss : 3.8521
# Epoch [2/15], Step [24/847], Loss : 3.8404
# Epoch [2/15], Step [25/847], Loss : 3.8178
# Epoch [2/15], Step [26/847], Loss : 3.8079
# Epoch [2/15], Step [27/847], Loss : 3.7790
# Epoch [2/15], Step [28/847], Loss : 3.8000
# Epoch [2/15], Step [29/847], Loss : 3.8176
# Epoch [2/15], Step [30/847], Loss : 3.8359
# Epoch [2/15], Step [31/847], Loss : 3.8299
# Epoch [2/15], Step [32/847], Loss : 3.8250
# Epoch [2/15], Step [33/847], Loss : 3.8606
# Epoch [2/15], Step [34/847], Loss : 3.8651
# Epoch [2/15], Step [35/847], Loss : 3.8687
# Epoch [2/15], Step [36/847], Loss : 3.8824
# Epoch [2/15], Step [37/847], Loss : 3.8804
# Epoch [2/15], Step [38/847], Loss : 3.8984
# Epoch [2/15], Step [39/847], Loss : 3.8910
# Epoch [2/15], Step [40/847], Loss : 3.8978
# Epoch [2/15], Step [41/847], Loss : 3.8914
# Epoch [2/15], Step [42/847], Loss : 3.8952
# Epoch [2/15], Step [43/847], Loss : 3.8919
# Epoch [2/15], Step [44/847], Loss : 3.8958
# Epoch [2/15], Step [45/847], Loss : 3.8908
# Epoch [2/15], Step [46/847], Loss : 3.8777
# Epoch [2/15], Step [47/847], Loss : 3.8910
# Epoch [2/15], Step [48/847], Loss : 3.8869
# Epoch [2/15], Step [49/847], Loss : 3.8934
# Epoch [2/15], Step [50/847], Loss : 3.9030
# Epoch [2/15], Step [51/847], Loss : 3.9089
# Epoch [2/15], Step [52/847], Loss : 3.9181
# Epoch [2/15], Step [53/847], Loss : 3.9118
# Epoch [2/15], Step [54/847], Loss : 3.9032
# Epoch [2/15], Step [55/847], Loss : 3.9034
# Epoch [2/15], Step [56/847], Loss : 3.9004
# Epoch [2/15], Step [57/847], Loss : 3.9187
# Epoch [2/15], Step [58/847], Loss : 3.9159
# Epoch [2/15], Step [59/847], Loss : 3.9177
# Epoch [2/15], Step [60/847], Loss : 3.9199
# Epoch [2/15], Step [61/847], Loss : 3.9199
# Epoch [2/15], Step [62/847], Loss : 3.9081
# Epoch [2/15], Step [63/847], Loss : 3.9228
# Epoch [2/15], Step [64/847], Loss : 3.9172
# Epoch [2/15], Step [65/847], Loss : 3.9200
# Epoch [2/15], Step [66/847], Loss : 3.9270
# Epoch [2/15], Step [67/847], Loss : 3.9362
# Epoch [2/15], Step [68/847], Loss : 3.9452
# Epoch [2/15], Step [69/847], Loss : 3.9429
# Epoch [2/15], Step [70/847], Loss : 3.9447
# Epoch [2/15], Step [71/847], Loss : 3.9360
# Epoch [2/15], Step [72/847], Loss : 3.9465
# Epoch [2/15], Step [73/847], Loss : 3.9469
# Epoch [2/15], Step [74/847], Loss : 3.9502
# Epoch [2/15], Step [75/847], Loss : 3.9499
# Epoch [2/15], Step [76/847], Loss : 3.9654
# Epoch [2/15], Step [77/847], Loss : 3.9568
# Epoch [2/15], Step [78/847], Loss : 3.9642
# Epoch [2/15], Step [79/847], Loss : 3.9645
# Epoch [2/15], Step [80/847], Loss : 3.9711
# Epoch [2/15], Step [81/847], Loss : 3.9700
# Epoch [2/15], Step [82/847], Loss : 3.9804
# Epoch [2/15], Step [83/847], Loss : 3.9815
# Epoch [2/15], Step [84/847], Loss : 3.9810
# Epoch [2/15], Step [85/847], Loss : 3.9749
# Epoch [2/15], Step [86/847], Loss : 3.9740
# Epoch [2/15], Step [87/847], Loss : 3.9756
# Epoch [2/15], Step [88/847], Loss : 3.9649
# Epoch [2/15], Step [89/847], Loss : 3.9646
# Epoch [2/15], Step [90/847], Loss : 3.9653
# Epoch [2/15], Step [91/847], Loss : 3.9608
# Epoch [2/15], Step [92/847], Loss : 3.9689
# Epoch [2/15], Step [93/847], Loss : 3.9610
# Epoch [2/15], Step [94/847], Loss : 3.9616
# Epoch [2/15], Step [95/847], Loss : 3.9521
# Epoch [2/15], Step [96/847], Loss : 3.9369
# Epoch [2/15], Step [97/847], Loss : 3.9391
# Epoch [2/15], Step [98/847], Loss : 3.9364
# Epoch [2/15], Step [99/847], Loss : 3.9373
# Epoch [2/15], Step [100/847], Loss : 3.9421
# Epoch [2/15], Step [101/847], Loss : 3.9490
# Epoch [2/15], Step [102/847], Loss : 3.9489
# Epoch [2/15], Step [103/847], Loss : 3.9481
# Epoch [2/15], Step [104/847], Loss : 3.9427
# Epoch [2/15], Step [105/847], Loss : 3.9435
# Epoch [2/15], Step [106/847], Loss : 3.9455
# Epoch [2/15], Step [107/847], Loss : 3.9394
# Epoch [2/15], Step [108/847], Loss : 3.9420
# Epoch [2/15], Step [109/847], Loss : 3.9549
# Epoch [2/15], Step [110/847], Loss : 3.9581
# Epoch [2/15], Step [111/847], Loss : 3.9595
# Epoch [2/15], Step [112/847], Loss : 3.9607
# Epoch [2/15], Step [113/847], Loss : 3.9677
# Epoch [2/15], Step [114/847], Loss : 3.9657
# Epoch [2/15], Step [115/847], Loss : 3.9691
# Epoch [2/15], Step [116/847], Loss : 3.9722
# Epoch [2/15], Step [117/847], Loss : 3.9742
# Epoch [2/15], Step [118/847], Loss : 3.9789
# Epoch [2/15], Step [119/847], Loss : 3.9791
# Epoch [2/15], Step [120/847], Loss : 3.9848
# Epoch [2/15], Step [121/847], Loss : 3.9919
# Epoch [2/15], Step [122/847], Loss : 3.9926
# Epoch [2/15], Step [123/847], Loss : 3.9914
# Epoch [2/15], Step [124/847], Loss : 3.9935
# Epoch [2/15], Step [125/847], Loss : 3.9911
# Epoch [2/15], Step [126/847], Loss : 3.9880
# Epoch [2/15], Step [127/847], Loss : 3.9929
# Epoch [2/15], Step [128/847], Loss : 3.9939
# Epoch [2/15], Step [129/847], Loss : 3.9865
# Epoch [2/15], Step [130/847], Loss : 3.9885
# Epoch [2/15], Step [131/847], Loss : 3.9873
# Epoch [2/15], Step [132/847], Loss : 3.9839
# Epoch [2/15], Step [133/847], Loss : 3.9839
# Epoch [2/15], Step [134/847], Loss : 3.9928
# Epoch [2/15], Step [135/847], Loss : 3.9904
# Epoch [2/15], Step [136/847], Loss : 3.9970
# Epoch [2/15], Step [137/847], Loss : 4.0045
# Epoch [2/15], Step [138/847], Loss : 4.0018
# Epoch [2/15], Step [139/847], Loss : 4.0028
# Epoch [2/15], Step [140/847], Loss : 4.0047
# Epoch [2/15], Step [141/847], Loss : 4.0052
# Epoch [2/15], Step [142/847], Loss : 4.0060
# Epoch [2/15], Step [143/847], Loss : 4.0124
# Epoch [2/15], Step [144/847], Loss : 4.0148
# Epoch [2/15], Step [145/847], Loss : 4.0143
# Epoch [2/15], Step [146/847], Loss : 4.0174
# Epoch [2/15], Step [147/847], Loss : 4.0238
# Epoch [2/15], Step [148/847], Loss : 4.0239
# Epoch [2/15], Step [149/847], Loss : 4.0255
# Epoch [2/15], Step [150/847], Loss : 4.0319
# Epoch [2/15], Step [151/847], Loss : 4.0346
# Epoch [2/15], Step [152/847], Loss : 4.0430
# Epoch [2/15], Step [153/847], Loss : 4.0436
# Epoch [2/15], Step [154/847], Loss : 4.0417
# Epoch [2/15], Step [155/847], Loss : 4.0441
# Epoch [2/15], Step [156/847], Loss : 4.0426
# Epoch [2/15], Step [157/847], Loss : 4.0452
# Epoch [2/15], Step [158/847], Loss : 4.0390
# Epoch [2/15], Step [159/847], Loss : 4.0381
# Epoch [2/15], Step [160/847], Loss : 4.0398
# Epoch [2/15], Step [161/847], Loss : 4.0419
# Epoch [2/15], Step [162/847], Loss : 4.0406
# Epoch [2/15], Step [163/847], Loss : 4.0372
# Epoch [2/15], Step [164/847], Loss : 4.0397
# Epoch [2/15], Step [165/847], Loss : 4.0368
# Epoch [2/15], Step [166/847], Loss : 4.0378
# Epoch [2/15], Step [167/847], Loss : 4.0381
# Epoch [2/15], Step [168/847], Loss : 4.0364
# Epoch [2/15], Step [169/847], Loss : 4.0406
# Epoch [2/15], Step [170/847], Loss : 4.0374
# Epoch [2/15], Step [171/847], Loss : 4.0417
# Epoch [2/15], Step [172/847], Loss : 4.0444
# Epoch [2/15], Step [173/847], Loss : 4.0461
# Epoch [2/15], Step [174/847], Loss : 4.0478
# Epoch [2/15], Step [175/847], Loss : 4.0475
# Epoch [2/15], Step [176/847], Loss : 4.0513
# Epoch [2/15], Step [177/847], Loss : 4.0506
# Epoch [2/15], Step [178/847], Loss : 4.0500
# Epoch [2/15], Step [179/847], Loss : 4.0490
# Epoch [2/15], Step [180/847], Loss : 4.0518
# Epoch [2/15], Step [181/847], Loss : 4.0500
# Epoch [2/15], Step [182/847], Loss : 4.0481
# Epoch [2/15], Step [183/847], Loss : 4.0519
# Epoch [2/15], Step [184/847], Loss : 4.0514
# Epoch [2/15], Step [185/847], Loss : 4.0512
# Epoch [2/15], Step [186/847], Loss : 4.0544
# Epoch [2/15], Step [187/847], Loss : 4.0565
# Epoch [2/15], Step [188/847], Loss : 4.0574
# Epoch [2/15], Step [189/847], Loss : 4.0612
# Epoch [2/15], Step [190/847], Loss : 4.0612
# Epoch [2/15], Step [191/847], Loss : 4.0616
# Epoch [2/15], Step [192/847], Loss : 4.0586
# Epoch [2/15], Step [193/847], Loss : 4.0572
# Epoch [2/15], Step [194/847], Loss : 4.0543
# Epoch [2/15], Step [195/847], Loss : 4.0592
# Epoch [2/15], Step [196/847], Loss : 4.0601
# Epoch [2/15], Step [197/847], Loss : 4.0587
# Epoch [2/15], Step [198/847], Loss : 4.0545
# Epoch [2/15], Step [199/847], Loss : 4.0522
# Epoch [2/15], Step [200/847], Loss : 4.0493
# Epoch [2/15], Step [201/847], Loss : 4.0583
# Epoch [2/15], Step [202/847], Loss : 4.0578
# Epoch [2/15], Step [203/847], Loss : 4.0574
# Epoch [2/15], Step [204/847], Loss : 4.0539
# Epoch [2/15], Step [205/847], Loss : 4.0526
# Epoch [2/15], Step [206/847], Loss : 4.0491
# Epoch [2/15], Step [207/847], Loss : 4.0535
# Epoch [2/15], Step [208/847], Loss : 4.0490
# Epoch [2/15], Step [209/847], Loss : 4.0476
# Epoch [2/15], Step [210/847], Loss : 4.0450
# Epoch [2/15], Step [211/847], Loss : 4.0502
# Epoch [2/15], Step [212/847], Loss : 4.0472
# Epoch [2/15], Step [213/847], Loss : 4.0470
# Epoch [2/15], Step [214/847], Loss : 4.0469
# Epoch [2/15], Step [215/847], Loss : 4.0501
# Epoch [2/15], Step [216/847], Loss : 4.0491
# Epoch [2/15], Step [217/847], Loss : 4.0503
# Epoch [2/15], Step [218/847], Loss : 4.0535
# Epoch [2/15], Step [219/847], Loss : 4.0545
# Epoch [2/15], Step [220/847], Loss : 4.0581
# Epoch [2/15], Step [221/847], Loss : 4.0591
# Epoch [2/15], Step [222/847], Loss : 4.0592
# Epoch [2/15], Step [223/847], Loss : 4.0607
# Epoch [2/15], Step [224/847], Loss : 4.0619
# Epoch [2/15], Step [225/847], Loss : 4.0618
# Epoch [2/15], Step [226/847], Loss : 4.0622
# Epoch [2/15], Step [227/847], Loss : 4.0648
# Epoch [2/15], Step [228/847], Loss : 4.0631
# Epoch [2/15], Step [229/847], Loss : 4.0642
# Epoch [2/15], Step [230/847], Loss : 4.0675
# Epoch [2/15], Step [231/847], Loss : 4.0678
# Epoch [2/15], Step [232/847], Loss : 4.0692
# Epoch [2/15], Step [233/847], Loss : 4.0710
# Epoch [2/15], Step [234/847], Loss : 4.0723
# Epoch [2/15], Step [235/847], Loss : 4.0738
# Epoch [2/15], Step [236/847], Loss : 4.0782
# Epoch [2/15], Step [237/847], Loss : 4.0791
# Epoch [2/15], Step [238/847], Loss : 4.0811
# Epoch [2/15], Step [239/847], Loss : 4.0827
# Epoch [2/15], Step [240/847], Loss : 4.0808
# Epoch [2/15], Step [241/847], Loss : 4.0806
# Epoch [2/15], Step [242/847], Loss : 4.0793
# Epoch [2/15], Step [243/847], Loss : 4.0803
# Epoch [2/15], Step [244/847], Loss : 4.0767
# Epoch [2/15], Step [245/847], Loss : 4.0721
# Epoch [2/15], Step [246/847], Loss : 4.0724
# Epoch [2/15], Step [247/847], Loss : 4.0725
# ...
# Epoch [15/15], Step [495/847], Loss : 2.0659
# Epoch [15/15], Step [496/847], Loss : 2.0656
# Epoch [15/15], Step [497/847], Loss : 2.0660
# Epoch [15/15], Step [498/847], Loss : 2.0640
# Epoch [15/15], Step [499/847], Loss : 2.0641
# Epoch [15/15], Step [500/847], Loss : 2.0635
# Epoch [15/15], Step [501/847], Loss : 2.0633
# Epoch [15/15], Step [502/847], Loss : 2.0629
# Epoch [15/15], Step [503/847], Loss : 2.0629
# Epoch [15/15], Step [504/847], Loss : 2.0631
# Epoch [15/15], Step [505/847], Loss : 2.0660
# Epoch [15/15], Step [506/847], Loss : 2.0664
# Epoch [15/15], Step [507/847], Loss : 2.0661
# Epoch [15/15], Step [508/847], Loss : 2.0663
# Epoch [15/15], Step [509/847], Loss : 2.0672
# Epoch [15/15], Step [510/847], Loss : 2.0668
# Epoch [15/15], Step [511/847], Loss : 2.0678
# Epoch [15/15], Step [512/847], Loss : 2.0694
# Epoch [15/15], Step [513/847], Loss : 2.0708
# Epoch [15/15], Step [514/847], Loss : 2.0716
# Epoch [15/15], Step [515/847], Loss : 2.0736
# Epoch [15/15], Step [516/847], Loss : 2.0732
# Epoch [15/15], Step [517/847], Loss : 2.0734
# Epoch [15/15], Step [518/847], Loss : 2.0734
# Epoch [15/15], Step [519/847], Loss : 2.0728
# Epoch [15/15], Step [520/847], Loss : 2.0732
# Epoch [15/15], Step [521/847], Loss : 2.0730
# Epoch [15/15], Step [522/847], Loss : 2.0746
# Epoch [15/15], Step [523/847], Loss : 2.0745
# Epoch [15/15], Step [524/847], Loss : 2.0753
# Epoch [15/15], Step [525/847], Loss : 2.0769
# Epoch [15/15], Step [526/847], Loss : 2.0764
# Epoch [15/15], Step [527/847], Loss : 2.0746
# Epoch [15/15], Step [528/847], Loss : 2.0753
# Epoch [15/15], Step [529/847], Loss : 2.0764
# Epoch [15/15], Step [530/847], Loss : 2.0761
# Epoch [15/15], Step [531/847], Loss : 2.0751
# Epoch [15/15], Step [532/847], Loss : 2.0768
# Epoch [15/15], Step [533/847], Loss : 2.0748
# Epoch [15/15], Step [534/847], Loss : 2.0743
# Epoch [15/15], Step [535/847], Loss : 2.0743
# Epoch [15/15], Step [536/847], Loss : 2.0749
# Epoch [15/15], Step [537/847], Loss : 2.0755
# Epoch [15/15], Step [538/847], Loss : 2.0745
# Epoch [15/15], Step [539/847], Loss : 2.0749
# Epoch [15/15], Step [540/847], Loss : 2.0757
# Epoch [15/15], Step [541/847], Loss : 2.0751
# Epoch [15/15], Step [542/847], Loss : 2.0752
# Epoch [15/15], Step [543/847], Loss : 2.0756
# Epoch [15/15], Step [544/847], Loss : 2.0743
# Epoch [15/15], Step [545/847], Loss : 2.0731
# Epoch [15/15], Step [546/847], Loss : 2.0734
# Epoch [15/15], Step [547/847], Loss : 2.0741
# Epoch [15/15], Step [548/847], Loss : 2.0736
# Epoch [15/15], Step [549/847], Loss : 2.0724
# Epoch [15/15], Step [550/847], Loss : 2.0717
# Epoch [15/15], Step [551/847], Loss : 2.0725
# Epoch [15/15], Step [552/847], Loss : 2.0717
# Epoch [15/15], Step [553/847], Loss : 2.0725
# Epoch [15/15], Step [554/847], Loss : 2.0715
# Epoch [15/15], Step [555/847], Loss : 2.0713
# Epoch [15/15], Step [556/847], Loss : 2.0738
# Epoch [15/15], Step [557/847], Loss : 2.0718
# Epoch [15/15], Step [558/847], Loss : 2.0733
# Epoch [15/15], Step [559/847], Loss : 2.0744
# Epoch [15/15], Step [560/847], Loss : 2.0748
# Epoch [15/15], Step [561/847], Loss : 2.0743
# Epoch [15/15], Step [562/847], Loss : 2.0747
# Epoch [15/15], Step [563/847], Loss : 2.0738
# Epoch [15/15], Step [564/847], Loss : 2.0734
# Epoch [15/15], Step [565/847], Loss : 2.0741
# Epoch [15/15], Step [566/847], Loss : 2.0743
# Epoch [15/15], Step [567/847], Loss : 2.0747
# Epoch [15/15], Step [568/847], Loss : 2.0747
# Epoch [15/15], Step [569/847], Loss : 2.0744
# Epoch [15/15], Step [570/847], Loss : 2.0736
# Epoch [15/15], Step [571/847], Loss : 2.0725
# Epoch [15/15], Step [572/847], Loss : 2.0704
# Epoch [15/15], Step [573/847], Loss : 2.0707
# Epoch [15/15], Step [574/847], Loss : 2.0704
# Epoch [15/15], Step [575/847], Loss : 2.0705
# Epoch [15/15], Step [576/847], Loss : 2.0708
# Epoch [15/15], Step [577/847], Loss : 2.0719
# Epoch [15/15], Step [578/847], Loss : 2.0721
# Epoch [15/15], Step [579/847], Loss : 2.0714
# Epoch [15/15], Step [580/847], Loss : 2.0729
# Epoch [15/15], Step [581/847], Loss : 2.0739
# Epoch [15/15], Step [582/847], Loss : 2.0741
# Epoch [15/15], Step [583/847], Loss : 2.0750
# Epoch [15/15], Step [584/847], Loss : 2.0763
# Epoch [15/15], Step [585/847], Loss : 2.0752
# Epoch [15/15], Step [586/847], Loss : 2.0742
# Epoch [15/15], Step [587/847], Loss : 2.0742
# Epoch [15/15], Step [588/847], Loss : 2.0745
# Epoch [15/15], Step [589/847], Loss : 2.0751
# Epoch [15/15], Step [590/847], Loss : 2.0749
# Epoch [15/15], Step [591/847], Loss : 2.0752
# Epoch [15/15], Step [592/847], Loss : 2.0752
# Epoch [15/15], Step [593/847], Loss : 2.0757
# Epoch [15/15], Step [594/847], Loss : 2.0760
# Epoch [15/15], Step [595/847], Loss : 2.0764
# Epoch [15/15], Step [596/847], Loss : 2.0751
# Epoch [15/15], Step [597/847], Loss : 2.0779
# Epoch [15/15], Step [598/847], Loss : 2.0790
# Epoch [15/15], Step [599/847], Loss : 2.0785
# Epoch [15/15], Step [600/847], Loss : 2.0783
# Epoch [15/15], Step [601/847], Loss : 2.0811
# Epoch [15/15], Step [602/847], Loss : 2.0794
# Epoch [15/15], Step [603/847], Loss : 2.0798
# Epoch [15/15], Step [604/847], Loss : 2.0797
# Epoch [15/15], Step [605/847], Loss : 2.0797
# Epoch [15/15], Step [606/847], Loss : 2.0805
# Epoch [15/15], Step [607/847], Loss : 2.0800
# Epoch [15/15], Step [608/847], Loss : 2.0788
# Epoch [15/15], Step [609/847], Loss : 2.0795
# Epoch [15/15], Step [610/847], Loss : 2.0790
# Epoch [15/15], Step [611/847], Loss : 2.0810
# Epoch [15/15], Step [612/847], Loss : 2.0817
# Epoch [15/15], Step [613/847], Loss : 2.0819
# Epoch [15/15], Step [614/847], Loss : 2.0808
# Epoch [15/15], Step [615/847], Loss : 2.0800
# Epoch [15/15], Step [616/847], Loss : 2.0792
# Epoch [15/15], Step [617/847], Loss : 2.0799
# Epoch [15/15], Step [618/847], Loss : 2.0800
# Epoch [15/15], Step [619/847], Loss : 2.0793
# Epoch [15/15], Step [620/847], Loss : 2.0798
# Epoch [15/15], Step [621/847], Loss : 2.0789
# Epoch [15/15], Step [622/847], Loss : 2.0796
# Epoch [15/15], Step [623/847], Loss : 2.0797
# Epoch [15/15], Step [624/847], Loss : 2.0810
# Epoch [15/15], Step [625/847], Loss : 2.0802
# Epoch [15/15], Step [626/847], Loss : 2.0796
# Epoch [15/15], Step [627/847], Loss : 2.0792
# Epoch [15/15], Step [628/847], Loss : 2.0794
# Epoch [15/15], Step [629/847], Loss : 2.0796
# Epoch [15/15], Step [630/847], Loss : 2.0792
# Epoch [15/15], Step [631/847], Loss : 2.0788
# Epoch [15/15], Step [632/847], Loss : 2.0791
# Epoch [15/15], Step [633/847], Loss : 2.0794
# Epoch [15/15], Step [634/847], Loss : 2.0800
# Epoch [15/15], Step [635/847], Loss : 2.0806
# Epoch [15/15], Step [636/847], Loss : 2.0802
# Epoch [15/15], Step [637/847], Loss : 2.0802
# Epoch [15/15], Step [638/847], Loss : 2.0795
# Epoch [15/15], Step [639/847], Loss : 2.0798
# Epoch [15/15], Step [640/847], Loss : 2.0797
# Epoch [15/15], Step [641/847], Loss : 2.0792
# Epoch [15/15], Step [642/847], Loss : 2.0790
# Epoch [15/15], Step [643/847], Loss : 2.0778
# Epoch [15/15], Step [644/847], Loss : 2.0792
# Epoch [15/15], Step [645/847], Loss : 2.0797
# Epoch [15/15], Step [646/847], Loss : 2.0812
# Epoch [15/15], Step [647/847], Loss : 2.0818
# Epoch [15/15], Step [648/847], Loss : 2.0826
# Epoch [15/15], Step [649/847], Loss : 2.0824
# Epoch [15/15], Step [650/847], Loss : 2.0833
# Epoch [15/15], Step [651/847], Loss : 2.0821
# Epoch [15/15], Step [652/847], Loss : 2.0809
# Epoch [15/15], Step [653/847], Loss : 2.0811
# Epoch [15/15], Step [654/847], Loss : 2.0815
# Epoch [15/15], Step [655/847], Loss : 2.0801
# Epoch [15/15], Step [656/847], Loss : 2.0810
# Epoch [15/15], Step [657/847], Loss : 2.0802
# Epoch [15/15], Step [658/847], Loss : 2.0810
# Epoch [15/15], Step [659/847], Loss : 2.0810
# Epoch [15/15], Step [660/847], Loss : 2.0816
# Epoch [15/15], Step [661/847], Loss : 2.0813
# Epoch [15/15], Step [662/847], Loss : 2.0817
# Epoch [15/15], Step [663/847], Loss : 2.0819
# Epoch [15/15], Step [664/847], Loss : 2.0806
# Epoch [15/15], Step [665/847], Loss : 2.0802
# Epoch [15/15], Step [666/847], Loss : 2.0800
# Epoch [15/15], Step [667/847], Loss : 2.0795
# Epoch [15/15], Step [668/847], Loss : 2.0790
# Epoch [15/15], Step [669/847], Loss : 2.0795
# Epoch [15/15], Step [670/847], Loss : 2.0786
# Epoch [15/15], Step [671/847], Loss : 2.0790
# Epoch [15/15], Step [672/847], Loss : 2.0820
# Epoch [15/15], Step [673/847], Loss : 2.0825
# Epoch [15/15], Step [674/847], Loss : 2.0834
# Epoch [15/15], Step [675/847], Loss : 2.0830
# Epoch [15/15], Step [676/847], Loss : 2.0823
# Epoch [15/15], Step [677/847], Loss : 2.0820
# Epoch [15/15], Step [678/847], Loss : 2.0829
# Epoch [15/15], Step [679/847], Loss : 2.0826
# Epoch [15/15], Step [680/847], Loss : 2.0824
# Epoch [15/15], Step [681/847], Loss : 2.0841
# Epoch [15/15], Step [682/847], Loss : 2.0836
# Epoch [15/15], Step [683/847], Loss : 2.0829
# Epoch [15/15], Step [684/847], Loss : 2.0821
# Epoch [15/15], Step [685/847], Loss : 2.0809
# Epoch [15/15], Step [686/847], Loss : 2.0809
# Epoch [15/15], Step [687/847], Loss : 2.0813
# Epoch [15/15], Step [688/847], Loss : 2.0814
# Epoch [15/15], Step [689/847], Loss : 2.0823
# Epoch [15/15], Step [690/847], Loss : 2.0826
# Epoch [15/15], Step [691/847], Loss : 2.0823
# Epoch [15/15], Step [692/847], Loss : 2.0809
# Epoch [15/15], Step [693/847], Loss : 2.0816
# Epoch [15/15], Step [694/847], Loss : 2.0810
# Epoch [15/15], Step [695/847], Loss : 2.0813
# Epoch [15/15], Step [696/847], Loss : 2.0807
# Epoch [15/15], Step [697/847], Loss : 2.0797
# Epoch [15/15], Step [698/847], Loss : 2.0782
# Epoch [15/15], Step [699/847], Loss : 2.0778
# Epoch [15/15], Step [700/847], Loss : 2.0784
# Epoch [15/15], Step [701/847], Loss : 2.0805
# Epoch [15/15], Step [702/847], Loss : 2.0800
# Epoch [15/15], Step [703/847], Loss : 2.0804
# Epoch [15/15], Step [704/847], Loss : 2.0804
# Epoch [15/15], Step [705/847], Loss : 2.0800
# Epoch [15/15], Step [706/847], Loss : 2.0802
# Epoch [15/15], Step [707/847], Loss : 2.0793
# Epoch [15/15], Step [708/847], Loss : 2.0790
# Epoch [15/15], Step [709/847], Loss : 2.0798
# Epoch [15/15], Step [710/847], Loss : 2.0786
# Epoch [15/15], Step [711/847], Loss : 2.0784
# Epoch [15/15], Step [712/847], Loss : 2.0786
# Epoch [15/15], Step [713/847], Loss : 2.0792
# Epoch [15/15], Step [714/847], Loss : 2.0795
# Epoch [15/15], Step [715/847], Loss : 2.0799
# Epoch [15/15], Step [716/847], Loss : 2.0800
# Epoch [15/15], Step [717/847], Loss : 2.0798
# Epoch [15/15], Step [718/847], Loss : 2.0804
# Epoch [15/15], Step [719/847], Loss : 2.0813
# Epoch [15/15], Step [720/847], Loss : 2.0801
# Epoch [15/15], Step [721/847], Loss : 2.0799
# Epoch [15/15], Step [722/847], Loss : 2.0798
# Epoch [15/15], Step [723/847], Loss : 2.0799
# Epoch [15/15], Step [724/847], Loss : 2.0792
# Epoch [15/15], Step [725/847], Loss : 2.0795
# Epoch [15/15], Step [726/847], Loss : 2.0783
# Epoch [15/15], Step [727/847], Loss : 2.0787
# Epoch [15/15], Step [728/847], Loss : 2.0782
# Epoch [15/15], Step [729/847], Loss : 2.0788
# Epoch [15/15], Step [730/847], Loss : 2.0782
# Epoch [15/15], Step [731/847], Loss : 2.0785
# Epoch [15/15], Step [732/847], Loss : 2.0774
# Epoch [15/15], Step [733/847], Loss : 2.0770
# Epoch [15/15], Step [734/847], Loss : 2.0786
# Epoch [15/15], Step [735/847], Loss : 2.0789
# Epoch [15/15], Step [736/847], Loss : 2.0796
# Epoch [15/15], Step [737/847], Loss : 2.0803
# Epoch [15/15], Step [738/847], Loss : 2.0802
# Epoch [15/15], Step [739/847], Loss : 2.0798
# Epoch [15/15], Step [740/847], Loss : 2.0802
# Epoch [15/15], Step [741/847], Loss : 2.0792
# Epoch [15/15], Step [742/847], Loss : 2.0786
# Epoch [15/15], Step [743/847], Loss : 2.0773
# Epoch [15/15], Step [744/847], Loss : 2.0787
# Epoch [15/15], Step [745/847], Loss : 2.0779
# Epoch [15/15], Step [746/847], Loss : 2.0775
# Epoch [15/15], Step [747/847], Loss : 2.0780
# Epoch [15/15], Step [748/847], Loss : 2.0780
# Epoch [15/15], Step [749/847], Loss : 2.0785
# Epoch [15/15], Step [750/847], Loss : 2.0785
# Epoch [15/15], Step [751/847], Loss : 2.0780
# Epoch [15/15], Step [752/847], Loss : 2.0801
# Epoch [15/15], Step [753/847], Loss : 2.0815
# Epoch [15/15], Step [754/847], Loss : 2.0822
# Epoch [15/15], Step [755/847], Loss : 2.0825
# Epoch [15/15], Step [756/847], Loss : 2.0826
# Epoch [15/15], Step [757/847], Loss : 2.0836
# Epoch [15/15], Step [758/847], Loss : 2.0851
# Epoch [15/15], Step [759/847], Loss : 2.0857
# Epoch [15/15], Step [760/847], Loss : 2.0852
# Epoch [15/15], Step [761/847], Loss : 2.0854
# Epoch [15/15], Step [762/847], Loss : 2.0844
# Epoch [15/15], Step [763/847], Loss : 2.0855
# Epoch [15/15], Step [764/847], Loss : 2.0857
# Epoch [15/15], Step [765/847], Loss : 2.0842
# Epoch [15/15], Step [766/847], Loss : 2.0855
# Epoch [15/15], Step [767/847], Loss : 2.0859
# Epoch [15/15], Step [768/847], Loss : 2.0855
# Epoch [15/15], Step [769/847], Loss : 2.0855
# Epoch [15/15], Step [770/847], Loss : 2.0847
# Epoch [15/15], Step [771/847], Loss : 2.0835
# Epoch [15/15], Step [772/847], Loss : 2.0836
# Epoch [15/15], Step [773/847], Loss : 2.0832
# Epoch [15/15], Step [774/847], Loss : 2.0823
# Epoch [15/15], Step [775/847], Loss : 2.0816
# Epoch [15/15], Step [776/847], Loss : 2.0809
# Epoch [15/15], Step [777/847], Loss : 2.0818
# Epoch [15/15], Step [778/847], Loss : 2.0817
# Epoch [15/15], Step [779/847], Loss : 2.0820
# Epoch [15/15], Step [780/847], Loss : 2.0816
# Epoch [15/15], Step [781/847], Loss : 2.0814
# Epoch [15/15], Step [782/847], Loss : 2.0819
# Epoch [15/15], Step [783/847], Loss : 2.0831
# Epoch [15/15], Step [784/847], Loss : 2.0825
# Epoch [15/15], Step [785/847], Loss : 2.0831
# Epoch [15/15], Step [786/847], Loss : 2.0822
# Epoch [15/15], Step [787/847], Loss : 2.0814
# Epoch [15/15], Step [788/847], Loss : 2.0810
# Epoch [15/15], Step [789/847], Loss : 2.0810
# Epoch [15/15], Step [790/847], Loss : 2.0808
# Epoch [15/15], Step [791/847], Loss : 2.0806
# Epoch [15/15], Step [792/847], Loss : 2.0799
# Epoch [15/15], Step [793/847], Loss : 2.0784
# Epoch [15/15], Step [794/847], Loss : 2.0786
# Epoch [15/15], Step [795/847], Loss : 2.0789
# Epoch [15/15], Step [796/847], Loss : 2.0785
# Epoch [15/15], Step [797/847], Loss : 2.0775
# Epoch [15/15], Step [798/847], Loss : 2.0775
# Epoch [15/15], Step [799/847], Loss : 2.0771
# Epoch [15/15], Step [800/847], Loss : 2.0768
# Epoch [15/15], Step [801/847], Loss : 2.0763
# Epoch [15/15], Step [802/847], Loss : 2.0762
# Epoch [15/15], Step [803/847], Loss : 2.0755
# Epoch [15/15], Step [804/847], Loss : 2.0752
# Epoch [15/15], Step [805/847], Loss : 2.0748
# Epoch [15/15], Step [806/847], Loss : 2.0759
# Epoch [15/15], Step [807/847], Loss : 2.0755
# Epoch [15/15], Step [808/847], Loss : 2.0750
# Epoch [15/15], Step [809/847], Loss : 2.0752
# Epoch [15/15], Step [810/847], Loss : 2.0755
# Epoch [15/15], Step [811/847], Loss : 2.0750
# Epoch [15/15], Step [812/847], Loss : 2.0743
# Epoch [15/15], Step [813/847], Loss : 2.0734
# Epoch [15/15], Step [814/847], Loss : 2.0737
# Epoch [15/15], Step [815/847], Loss : 2.0742
# Epoch [15/15], Step [816/847], Loss : 2.0729
# Epoch [15/15], Step [817/847], Loss : 2.0737
# Epoch [15/15], Step [818/847], Loss : 2.0727
# Epoch [15/15], Step [819/847], Loss : 2.0729
# Epoch [15/15], Step [820/847], Loss : 2.0729
# Epoch [15/15], Step [821/847], Loss : 2.0725
# Epoch [15/15], Step [822/847], Loss : 2.0725
# Epoch [15/15], Step [823/847], Loss : 2.0726
# Epoch [15/15], Step [824/847], Loss : 2.0723
# Epoch [15/15], Step [825/847], Loss : 2.0715
# Epoch [15/15], Step [826/847], Loss : 2.0712
# Epoch [15/15], Step [827/847], Loss : 2.0702
# Epoch [15/15], Step [828/847], Loss : 2.0703
# Epoch [15/15], Step [829/847], Loss : 2.0712
# Epoch [15/15], Step [830/847], Loss : 2.0718
# Epoch [15/15], Step [831/847], Loss : 2.0717
# Epoch [15/15], Step [832/847], Loss : 2.0727
# Epoch [15/15], Step [833/847], Loss : 2.0722
# Epoch [15/15], Step [834/847], Loss : 2.0716
# Epoch [15/15], Step [835/847], Loss : 2.0722
# Epoch [15/15], Step [836/847], Loss : 2.0721
# Epoch [15/15], Step [837/847], Loss : 2.0717
# Epoch [15/15], Step [838/847], Loss : 2.0720
# Epoch [15/15], Step [839/847], Loss : 2.0740
# Epoch [15/15], Step [840/847], Loss : 2.0738
# Epoch [15/15], Step [841/847], Loss : 2.0731
# Epoch [15/15], Step [842/847], Loss : 2.0726
# Epoch [15/15], Step [843/847], Loss : 2.0736
# Epoch [15/15], Step [844/847], Loss : 2.0728
# Epoch [15/15], Step [845/847], Loss : 2.0731
# Epoch [15/15], Step [846/847], Loss : 2.0720
# Epoch [15/15], Step [847/847], Loss : 2.0721
# Epoch: 15, Loss: 2.0721, Accuracy: 0.5107
# Saving best model!
# Finished Training

# %%
from sklearn.metrics import precision_score, recall_score, average_precision_score, f1_score
def testing(model, test_dl):
    criterion = nn.CrossEntropyLoss()
    gt = torch.tensor([])
    pred = torch.tensor([])
    gt = gt.to(device)
    pred = pred.to(device)
    with torch.no_grad():
        correct = 0
        total = 0
        val_loss = 0 
        for idx, data_ in enumerate(test_dl):
            inputs, labels = data_[0].to(device), data_[1].to(device)

            inputs_m, inputs_s = inputs.mean(), inputs.std()
            inputs = (inputs - inputs_m) / inputs_s

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            max_values, prediction = torch.max(outputs,1)
            
            predi = torch.softmax(outputs, dim = -1)
        
            gt = torch.cat((gt, labels), dim = 0)

            pred = torch.cat((pred, prediction), dim = 0)
            correct += (prediction == labels).sum().item()
            total += prediction.shape[0]

        gt = gt.to('cpu')
        pred = pred.to('cpu')
        
        precision = precision_score(gt, pred, average='weighted',  zero_division=0)
        recall = recall_score(gt, pred, average='weighted', zero_division=0)
        f1 = f1_score(gt, pred, average='weighted', zero_division=0)
        print("Precision:", precision)
        print("Recall:", recall)
        print("F1 Score:", f1)        
        final_score = 100 * correct / total
        print("Final Test Accuracy", final_score)
