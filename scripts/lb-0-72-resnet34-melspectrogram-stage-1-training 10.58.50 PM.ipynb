# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
import torch.nn.functional as F
import torchaudio
from torchaudio import transforms
from IPython.display import Audio
import torchvision
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd
import os

import math, random

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed = 0
seed_everything(seed)

# %%
class CFG:
    isOneHot = False
    rate = 32000
    num_classes = 264

# %%
class AudioUtil():
  @staticmethod
  def open(audio_file):
    sig, sr = torchaudio.load(audio_file)
    return (sig, sr)

  @staticmethod
  def rechannel(aud, new_channel):
    sig, sr = aud

    if (sig.shape[0] == new_channel):
      return aud

    if (new_channel == 1):
      resig = sig[:1, :]
    else:
      resig = torch.cat([sig, sig, sig])

    return ((resig, sr))

  @staticmethod
  def resample(aud, newsr):
    sig, sr = aud

    if (sr == newsr):
      return aud

    num_channels = sig.shape[0]
    resig = torchaudio.transforms.Resample(sr, newsr)(sig[:1,:])
    if (num_channels > 1):
      retwo = torchaudio.transforms.Resample(sr, newsr)(sig[1:,:])
      resig = torch.cat([resig, retwo])

    return ((resig, newsr))

  @staticmethod
  def pad_trunc(aud, max_ms):
    sig, sr = aud
    num_rows, sig_len = sig.shape
    max_len = sr//1000 * max_ms

    if (sig_len > max_len):
      sig = sig[:,:max_len]

    elif (sig_len < max_len):
      pad_begin_len = random.randint(0, max_len - sig_len)
      pad_end_len = max_len - sig_len - pad_begin_len
      pad_begin = torch.zeros((num_rows, pad_begin_len))
      pad_end = torch.zeros((num_rows, pad_end_len))

      sig = torch.cat((pad_begin, sig, pad_end), 1)
      
    return (sig, sr)

  @staticmethod
  def time_shift(aud, shift_limit):
    sig,sr = aud
    _, sig_len = sig.shape
    shift_amt = int(random.random() * shift_limit * sig_len)
    return (sig.roll(shift_amt), sr)

  @staticmethod
  def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
    sig,sr = aud
    top_db = 80
    spec = torchaudio.transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)
    spec = torchaudio.transforms.AmplitudeToDB(top_db=top_db)(spec)
    return (spec)

  @staticmethod
  def spectro_augment(spec, max_mask_pct=0.1, n_freq_masks=1, n_time_masks=1):
    _, n_mels, n_steps = spec.shape
    mask_value = spec.mean()
    aug_spec = spec
    freq_mask_param = max_mask_pct * n_mels
    for _ in range(n_freq_masks):
      aug_spec = torchaudio.transforms.FrequencyMasking(freq_mask_param)(aug_spec, mask_value)
    time_mask_param = max_mask_pct * n_steps
    for _ in range(n_time_masks):
      aug_spec = torchaudio.transforms.TimeMasking(time_mask_param)(aug_spec, mask_value)
    return aug_spec

# %%
meta_df = pd.read_csv('/birdclef-2023/train_metadata.csv')
print('data shape:',meta_df.shape)
meta_df.head()
# Out:
# data shape: (16941, 12)
#   primary_label secondary_labels              type  latitude  longitude  \
# 0       abethr1               []          ['song']    4.3906    38.2788
# 1       abethr1               []          ['call']   -2.9524    38.2921
# 2       abethr1               []          ['song']   -2.9524    38.2921
# 3       abethr1               []          ['song']   -2.9524    38.2921
# 4       abethr1               []  ['call', 'song']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.5
#
#                                  url              filename
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg
# 2  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg
# 3  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg
# 4  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg

# %%
# unique_categories = meta_df['primary_label'].unique()
# first_10_categories = unique_categories[:10]
# meta_df = meta_df[meta_df['primary_label'].isin(first_10_categories)]
# print(meta_df.shape)

# %%
print('Number of classes and number samples in each class:',meta_df.primary_label.value_counts().reset_index().shape)
print('Number of classes with more than 1 sample:',meta_df.primary_label.value_counts().reset_index()\
                                                              .query('primary_label > 1').shape)
# Out:
# Number of classes and number samples in each class: (264, 2)
# Number of classes with more than 1 sample: (257, 2)

# %%
if CFG.isOneHot:
    label = OneHotEncoder(sparse=False)\
                                    .fit_transform(meta_df['primary_label'].to_numpy().reshape(-1,1))
    meta_df['label'] = pd.DataFrame(label).apply(lambda x: list(x), axis = 1)
else:
    meta_df['label'] = LabelEncoder().fit_transform(meta_df['primary_label'])
meta_df.head(2)
# Out:
#   primary_label secondary_labels      type  latitude  longitude  \
# 0       abethr1               []  ['song']    4.3906    38.2788
# 1       abethr1               []  ['call']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
#
#                                  url              filename  label
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg      0
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg      0

# %%
def cv_split(Xtrain, ytrain, n_folds, seed):
    kfold = StratifiedKFold(n_splits = n_folds, shuffle = True, random_state = seed)
    for num, (train_index, val_index) in enumerate(kfold.split(Xtrain, ytrain)):
        Xtrain.loc[val_index, 'fold'] = int(num)
    Xtrain['fold'] = Xtrain['fold'].astype(int)
    return Xtrain

meta_df = cv_split(meta_df,meta_df['primary_label'], 5, 42)
meta_df.head(6)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   UserWarning,
#   primary_label secondary_labels              type  latitude  longitude  \
# 0       abethr1               []          ['song']    4.3906    38.2788
# 1       abethr1               []          ['call']   -2.9524    38.2921
# 2       abethr1               []          ['song']   -2.9524    38.2921
# 3       abethr1               []          ['song']   -2.9524    38.2921
# 4       abethr1               []  ['call', 'song']   -2.9524    38.2921
# 5       abethr1      ['rbsrob1']          ['song']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 5  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.5
# 5  Creative Commons Attribution-NonCommercial-Sha...     3.5
#
#                                  url              filename  label  fold
# 0  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg      0     3
# 1  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg      0     3
# 2  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg      0     0
# 3  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg      0     4
# 4  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg      0     1
# 5  https://www.xeno-canto.org/379322  abethr1/XC379322.ogg      0     2

# %%
class SoundDS(Dataset):
  def __init__(self, df, data_path ='/birdclef-2023/train_audio/', mode='train'):
    self.df = df
    self.data_path = str(data_path)
    self.duration = 8000
    self.sr = 32000
    self.channel = 3
    self.shift_pct = 0.4
    self.mode = mode

  def __len__(self):
    return len(self.df)    
    
  def __getitem__(self, idx):
    audio_file = self.data_path + self.df.loc[idx, 'filename']
    class_id = np.array(self.df.loc[idx, 'label'])
    aud = AudioUtil.open(audio_file)
    reaud = AudioUtil.resample(aud, self.sr)
    rechan = AudioUtil.rechannel(reaud, self.channel)
    dur_aud = AudioUtil.pad_trunc(rechan, self.duration)
    if self.mode == 'train':
        shift_aud = AudioUtil.time_shift(dur_aud, self.shift_pct)
        sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
        aug_sgram = AudioUtil.spectro_augment(sgram, max_mask_pct=0.1, n_freq_masks=2, n_time_masks=2)
        return aug_sgram, class_id
    else:
        shift_aud = dur_aud
        sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
        return sgram, class_id

# %%
train_ds = SoundDS(meta_df[meta_df.fold != 0].reset_index(), mode='train')
test_ds = SoundDS(meta_df[meta_df.fold == 0].reset_index(), mode='test')
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=16, shuffle=True)
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=16, shuffle=True)

print('train samples ', meta_df[meta_df.fold != 0].shape)
print('test samples ', meta_df[meta_df.fold == 0].shape)
# Out:
# train samples  (13552, 14)
# test samples  (3389, 14)

# %%
a,b = next(iter(train_dl))
print(a.shape)
print(b.shape)
# Out:
# torch.Size([16, 3, 64, 501])
# torch.Size([16])

# %%
model = torchvision.models.resnet34(pretrained=True)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, CFG.num_classes)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
myModel = model.to(device)
next(myModel.parameters()).device
# Out:
# /opt/conda/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# /opt/conda/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# device(type='cuda', index=0)

# %%
def training(model, train_dl, num_epochs):
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
  scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01,
                                                steps_per_epoch=int(len(train_dl)),
                                                epochs=num_epochs,
                                                anneal_strategy='linear')
  best_acc = -1
  for epoch in range(num_epochs):
    running_loss = 0.0
    correct_prediction = 0
    total_prediction = 0
    for i, data in enumerate(train_dl):
        inputs, labels = data[0].to(device), data[1].to(device)
        inputs_m, inputs_s = inputs.mean(), inputs.std()
        inputs = (inputs - inputs_m) / inputs_s
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()
        running_loss += loss.item()
        _, prediction = torch.max(outputs,1)
        correct_prediction += (prediction == labels).sum().item()
        total_prediction += prediction.shape[0]

        if (i + 1) % 1 == 0:   
           print('Epoch [{}/{}], Step [{}/{}], Loss : {:.4f}'
            .format(epoch + 1, num_epochs, i + 1, len(train_dl), running_loss/(i + 1)))
    num_batches = len(train_dl)
    avg_loss = running_loss / num_batches
    acc = correct_prediction/total_prediction
    print(f'Epoch: {epoch + 1}, Loss: {avg_loss:.4f}, Accuracy: {acc:.4f}')

    if (best_acc < acc):
        best_acc = acc
        print("Saving best model!")
        torch.save(model.state_dict(), f'BirdSound_MobileNetV2_fold0_epoch{epoch}.pth')

  print('Finished Training')
  
num_epochs = 15   
training(myModel, train_dl, num_epochs)
# Out:
# Epoch [1/15], Step [1/847], Loss : 5.9049
# Epoch [1/15], Step [2/847], Loss : 5.8063
# Epoch [1/15], Step [3/847], Loss : 5.7627
# Epoch [1/15], Step [4/847], Loss : 5.7121
# Epoch [1/15], Step [5/847], Loss : 5.7358
# Epoch [1/15], Step [6/847], Loss : 5.7646
# Epoch [1/15], Step [7/847], Loss : 5.7728
# Epoch [1/15], Step [8/847], Loss : 5.8069
# Epoch [1/15], Step [9/847], Loss : 5.7669
# Epoch [1/15], Step [10/847], Loss : 5.7533
# Epoch [1/15], Step [11/847], Loss : 5.7304
# Epoch [1/15], Step [12/847], Loss : 5.7034
# Epoch [1/15], Step [13/847], Loss : 5.6679
# Epoch [1/15], Step [14/847], Loss : 5.6784
# Epoch [1/15], Step [15/847], Loss : 5.6524
# Epoch [1/15], Step [16/847], Loss : 5.6368
# Epoch [1/15], Step [17/847], Loss : 5.6071
# Epoch [1/15], Step [18/847], Loss : 5.5962
# Epoch [1/15], Step [19/847], Loss : 5.6028
# Epoch [1/15], Step [20/847], Loss : 5.5825
# Epoch [1/15], Step [21/847], Loss : 5.5711
# Epoch [1/15], Step [22/847], Loss : 5.5401
# Epoch [1/15], Step [23/847], Loss : 5.5021
# Epoch [1/15], Step [24/847], Loss : 5.4804
# Epoch [1/15], Step [25/847], Loss : 5.4835
# Epoch [1/15], Step [26/847], Loss : 5.4672
# Epoch [1/15], Step [27/847], Loss : 5.4560
# Epoch [1/15], Step [28/847], Loss : 5.4552
# Epoch [1/15], Step [29/847], Loss : 5.4735
# Epoch [1/15], Step [30/847], Loss : 5.4521
# Epoch [1/15], Step [31/847], Loss : 5.4395
# Epoch [1/15], Step [32/847], Loss : 5.4326
# Epoch [1/15], Step [33/847], Loss : 5.4200
# Epoch [1/15], Step [34/847], Loss : 5.4262
# Epoch [1/15], Step [35/847], Loss : 5.4219
# Epoch [1/15], Step [36/847], Loss : 5.4071
# Epoch [1/15], Step [37/847], Loss : 5.3954
# Epoch [1/15], Step [38/847], Loss : 5.3893
# Epoch [1/15], Step [39/847], Loss : 5.3878
# Epoch [1/15], Step [40/847], Loss : 5.3643
# Epoch [1/15], Step [41/847], Loss : 5.3650
# Epoch [1/15], Step [42/847], Loss : 5.3523
# Epoch [1/15], Step [43/847], Loss : 5.3552
# Epoch [1/15], Step [44/847], Loss : 5.3456
# Epoch [1/15], Step [45/847], Loss : 5.3674
# Epoch [1/15], Step [46/847], Loss : 5.3655
# Epoch [1/15], Step [47/847], Loss : 5.3621
# Epoch [1/15], Step [48/847], Loss : 5.3393
# Epoch [1/15], Step [49/847], Loss : 5.3341
# Epoch [1/15], Step [50/847], Loss : 5.3308
# Epoch [1/15], Step [51/847], Loss : 5.3390
# Epoch [1/15], Step [52/847], Loss : 5.3383
# Epoch [1/15], Step [53/847], Loss : 5.3230
# Epoch [1/15], Step [54/847], Loss : 5.3172
# Epoch [1/15], Step [55/847], Loss : 5.3208
# Epoch [1/15], Step [56/847], Loss : 5.3117
# Epoch [1/15], Step [57/847], Loss : 5.3036
# Epoch [1/15], Step [58/847], Loss : 5.2949
# Epoch [1/15], Step [59/847], Loss : 5.2942
# Epoch [1/15], Step [60/847], Loss : 5.2802
# Epoch [1/15], Step [61/847], Loss : 5.2709
# Epoch [1/15], Step [62/847], Loss : 5.2749
# Epoch [1/15], Step [63/847], Loss : 5.2647
# Epoch [1/15], Step [64/847], Loss : 5.2596
# Epoch [1/15], Step [65/847], Loss : 5.2585
# Epoch [1/15], Step [66/847], Loss : 5.2551
# Epoch [1/15], Step [67/847], Loss : 5.2527
# Epoch [1/15], Step [68/847], Loss : 5.2536
# Epoch [1/15], Step [69/847], Loss : 5.2424
# Epoch [1/15], Step [70/847], Loss : 5.2550
# Epoch [1/15], Step [71/847], Loss : 5.2599
# Epoch [1/15], Step [72/847], Loss : 5.2449
# Epoch [1/15], Step [73/847], Loss : 5.2504
# Epoch [1/15], Step [74/847], Loss : 5.2489
# Epoch [1/15], Step [75/847], Loss : 5.2460
# Epoch [1/15], Step [76/847], Loss : 5.2353
# Epoch [1/15], Step [77/847], Loss : 5.2300
# Epoch [1/15], Step [78/847], Loss : 5.2311
# Epoch [1/15], Step [79/847], Loss : 5.2322
# Epoch [1/15], Step [80/847], Loss : 5.2221
# Epoch [1/15], Step [81/847], Loss : 5.2179
# Epoch [1/15], Step [82/847], Loss : 5.2081
# Epoch [1/15], Step [83/847], Loss : 5.2090
# Epoch [1/15], Step [84/847], Loss : 5.2058
# Epoch [1/15], Step [85/847], Loss : 5.1965
# Epoch [1/15], Step [86/847], Loss : 5.1893
# Epoch [1/15], Step [87/847], Loss : 5.1860
# Epoch [1/15], Step [88/847], Loss : 5.1896
# Epoch [1/15], Step [89/847], Loss : 5.1856
# Epoch [1/15], Step [90/847], Loss : 5.1827
# Epoch [1/15], Step [91/847], Loss : 5.1821
# Epoch [1/15], Step [92/847], Loss : 5.1771
# Epoch [1/15], Step [93/847], Loss : 5.1704
# Epoch [1/15], Step [94/847], Loss : 5.1637
# Epoch [1/15], Step [95/847], Loss : 5.1589
# Epoch [1/15], Step [96/847], Loss : 5.1529
# Epoch [1/15], Step [97/847], Loss : 5.1563
# Epoch [1/15], Step [98/847], Loss : 5.1550
# Epoch [1/15], Step [99/847], Loss : 5.1536
# Epoch [1/15], Step [100/847], Loss : 5.1540
# Epoch [1/15], Step [101/847], Loss : 5.1533
# Epoch [1/15], Step [102/847], Loss : 5.1555
# Epoch [1/15], Step [103/847], Loss : 5.1466
# Epoch [1/15], Step [104/847], Loss : 5.1472
# Epoch [1/15], Step [105/847], Loss : 5.1439
# Epoch [1/15], Step [106/847], Loss : 5.1479
# Epoch [1/15], Step [107/847], Loss : 5.1492
# Epoch [1/15], Step [108/847], Loss : 5.1510
# Epoch [1/15], Step [109/847], Loss : 5.1459
# Epoch [1/15], Step [110/847], Loss : 5.1434
# Epoch [1/15], Step [111/847], Loss : 5.1395
# Epoch [1/15], Step [112/847], Loss : 5.1397
# Epoch [1/15], Step [113/847], Loss : 5.1350
# Epoch [1/15], Step [114/847], Loss : 5.1336
# Epoch [1/15], Step [115/847], Loss : 5.1333
# Epoch [1/15], Step [116/847], Loss : 5.1356
# Epoch [1/15], Step [117/847], Loss : 5.1317
# Epoch [1/15], Step [118/847], Loss : 5.1330
# Epoch [1/15], Step [119/847], Loss : 5.1298
# Epoch [1/15], Step [120/847], Loss : 5.1257
# Epoch [1/15], Step [121/847], Loss : 5.1244
# Epoch [1/15], Step [122/847], Loss : 5.1215
# Epoch [1/15], Step [123/847], Loss : 5.1199
# Epoch [1/15], Step [124/847], Loss : 5.1151
# Epoch [1/15], Step [125/847], Loss : 5.1155
# Epoch [1/15], Step [126/847], Loss : 5.1129
# Epoch [1/15], Step [127/847], Loss : 5.1127
# Epoch [1/15], Step [128/847], Loss : 5.1125
# Epoch [1/15], Step [129/847], Loss : 5.1097
# Epoch [1/15], Step [130/847], Loss : 5.1074
# Epoch [1/15], Step [131/847], Loss : 5.1022
# Epoch [1/15], Step [132/847], Loss : 5.1047
# Epoch [1/15], Step [133/847], Loss : 5.1038
# Epoch [1/15], Step [134/847], Loss : 5.1037
# Epoch [1/15], Step [135/847], Loss : 5.1025
# Epoch [1/15], Step [136/847], Loss : 5.1026
# Epoch [1/15], Step [137/847], Loss : 5.0971
# Epoch [1/15], Step [138/847], Loss : 5.0943
# Epoch [1/15], Step [139/847], Loss : 5.0932
# Epoch [1/15], Step [140/847], Loss : 5.0927
# Epoch [1/15], Step [141/847], Loss : 5.0956
# Epoch [1/15], Step [142/847], Loss : 5.0925
# Epoch [1/15], Step [143/847], Loss : 5.0925
# Epoch [1/15], Step [144/847], Loss : 5.0923
# Epoch [1/15], Step [145/847], Loss : 5.0931
# Epoch [1/15], Step [146/847], Loss : 5.0938
# Epoch [1/15], Step [147/847], Loss : 5.0977
# Epoch [1/15], Step [148/847], Loss : 5.0973
# Epoch [1/15], Step [149/847], Loss : 5.0981
# Epoch [1/15], Step [150/847], Loss : 5.0991
# Epoch [1/15], Step [151/847], Loss : 5.0957
# Epoch [1/15], Step [152/847], Loss : 5.0918
# Epoch [1/15], Step [153/847], Loss : 5.0913
# Epoch [1/15], Step [154/847], Loss : 5.0941
# Epoch [1/15], Step [155/847], Loss : 5.0954
# Epoch [1/15], Step [156/847], Loss : 5.0947
# Epoch [1/15], Step [157/847], Loss : 5.0938
# Epoch [1/15], Step [158/847], Loss : 5.0905
# Epoch [1/15], Step [159/847], Loss : 5.0887
# Epoch [1/15], Step [160/847], Loss : 5.0897
# Epoch [1/15], Step [161/847], Loss : 5.0900
# Epoch [1/15], Step [162/847], Loss : 5.0918
# Epoch [1/15], Step [163/847], Loss : 5.0905
# Epoch [1/15], Step [164/847], Loss : 5.0937
# Epoch [1/15], Step [165/847], Loss : 5.0923
# Epoch [1/15], Step [166/847], Loss : 5.0908
# Epoch [1/15], Step [167/847], Loss : 5.0897
# Epoch [1/15], Step [168/847], Loss : 5.0891
# Epoch [1/15], Step [169/847], Loss : 5.0899
# Epoch [1/15], Step [170/847], Loss : 5.0902
# Epoch [1/15], Step [171/847], Loss : 5.0936
# Epoch [1/15], Step [172/847], Loss : 5.0898
# Epoch [1/15], Step [173/847], Loss : 5.0907
# Epoch [1/15], Step [174/847], Loss : 5.0880
# Epoch [1/15], Step [175/847], Loss : 5.0850
# Epoch [1/15], Step [176/847], Loss : 5.0853
# Epoch [1/15], Step [177/847], Loss : 5.0841
# Epoch [1/15], Step [178/847], Loss : 5.0841
# Epoch [1/15], Step [179/847], Loss : 5.0829
# Epoch [1/15], Step [180/847], Loss : 5.0827
# Epoch [1/15], Step [181/847], Loss : 5.0806
# Epoch [1/15], Step [182/847], Loss : 5.0790
# Epoch [1/15], Step [183/847], Loss : 5.0798
# Epoch [1/15], Step [184/847], Loss : 5.0776
# Epoch [1/15], Step [185/847], Loss : 5.0743
# Epoch [1/15], Step [186/847], Loss : 5.0760
# Epoch [1/15], Step [187/847], Loss : 5.0748
# Epoch [1/15], Step [188/847], Loss : 5.0719
# Epoch [1/15], Step [189/847], Loss : 5.0726
# Epoch [1/15], Step [190/847], Loss : 5.0722
# Epoch [1/15], Step [191/847], Loss : 5.0752
# Epoch [1/15], Step [192/847], Loss : 5.0754
# Epoch [1/15], Step [193/847], Loss : 5.0758
# Epoch [1/15], Step [194/847], Loss : 5.0738
# Epoch [1/15], Step [195/847], Loss : 5.0776
# Epoch [1/15], Step [196/847], Loss : 5.0788
# Epoch [1/15], Step [197/847], Loss : 5.0777
# Epoch [1/15], Step [198/847], Loss : 5.0788
# Epoch [1/15], Step [199/847], Loss : 5.0782
# Epoch [1/15], Step [200/847], Loss : 5.0784
# Epoch [1/15], Step [201/847], Loss : 5.0745
# Epoch [1/15], Step [202/847], Loss : 5.0744
# Epoch [1/15], Step [203/847], Loss : 5.0719
# Epoch [1/15], Step [204/847], Loss : 5.0724
# Epoch [1/15], Step [205/847], Loss : 5.0738
# Epoch [1/15], Step [206/847], Loss : 5.0732
# Epoch [1/15], Step [207/847], Loss : 5.0721
# Epoch [1/15], Step [208/847], Loss : 5.0719
# Epoch [1/15], Step [209/847], Loss : 5.0747
# Epoch [1/15], Step [210/847], Loss : 5.0743
# Epoch [1/15], Step [211/847], Loss : 5.0746
# Epoch [1/15], Step [212/847], Loss : 5.0739
# Epoch [1/15], Step [213/847], Loss : 5.0749
# Epoch [1/15], Step [214/847], Loss : 5.0753
# Epoch [1/15], Step [215/847], Loss : 5.0740
# Epoch [1/15], Step [216/847], Loss : 5.0743
# Epoch [1/15], Step [217/847], Loss : 5.0746
# Epoch [1/15], Step [218/847], Loss : 5.0746
# Epoch [1/15], Step [219/847], Loss : 5.0773
# Epoch [1/15], Step [220/847], Loss : 5.0764
# Epoch [1/15], Step [221/847], Loss : 5.0772
# Epoch [1/15], Step [222/847], Loss : 5.0765
# Epoch [1/15], Step [223/847], Loss : 5.0773
# Epoch [1/15], Step [224/847], Loss : 5.0776
# Epoch [1/15], Step [225/847], Loss : 5.0747
# Epoch [1/15], Step [226/847], Loss : 5.0718
# Epoch [1/15], Step [227/847], Loss : 5.0724
# Epoch [1/15], Step [228/847], Loss : 5.0690
# Epoch [1/15], Step [229/847], Loss : 5.0670
# Epoch [1/15], Step [230/847], Loss : 5.0656
# Epoch [1/15], Step [231/847], Loss : 5.0649
# Epoch [1/15], Step [232/847], Loss : 5.0666
# Epoch [1/15], Step [233/847], Loss : 5.0672
# Epoch [1/15], Step [234/847], Loss : 5.0658
# Epoch [1/15], Step [235/847], Loss : 5.0648
# Epoch [1/15], Step [236/847], Loss : 5.0625
# Epoch [1/15], Step [237/847], Loss : 5.0622
# Epoch [1/15], Step [238/847], Loss : 5.0606
# Epoch [1/15], Step [239/847], Loss : 5.0604
# Epoch [1/15], Step [240/847], Loss : 5.0615
# Epoch [1/15], Step [241/847], Loss : 5.0612
# Epoch [1/15], Step [242/847], Loss : 5.0627
# Epoch [1/15], Step [243/847], Loss : 5.0616
# Epoch [1/15], Step [244/847], Loss : 5.0591
# Epoch [1/15], Step [245/847], Loss : 5.0595
# Epoch [1/15], Step [246/847], Loss : 5.0607
# Epoch [1/15], Step [247/847], Loss : 5.0593
# Epoch [1/15], Step [248/847], Loss : 5.0586
# Epoch [1/15], Step [249/847], Loss : 5.0567
# Epoch [1/15], Step [250/847], Loss : 5.0543
# Epoch [1/15], Step [251/847], Loss : 5.0550
# Epoch [1/15], Step [252/847], Loss : 5.0546
# Epoch [1/15], Step [253/847], Loss : 5.0535
# Epoch [1/15], Step [254/847], Loss : 5.0537
# Epoch [1/15], Step [255/847], Loss : 5.0531
# Epoch [1/15], Step [256/847], Loss : 5.0518
# Epoch [1/15], Step [257/847], Loss : 5.0524
# Epoch [1/15], Step [258/847], Loss : 5.0527
# Epoch [1/15], Step [259/847], Loss : 5.0520
# Epoch [1/15], Step [260/847], Loss : 5.0535
# Epoch [1/15], Step [261/847], Loss : 5.0551
# Epoch [1/15], Step [262/847], Loss : 5.0555
# Epoch [1/15], Step [263/847], Loss : 5.0553
# Epoch [1/15], Step [264/847], Loss : 5.0543
# Epoch [1/15], Step [265/847], Loss : 5.0531
# Epoch [1/15], Step [266/847], Loss : 5.0523
# Epoch [1/15], Step [267/847], Loss : 5.0518
# Epoch [1/15], Step [268/847], Loss : 5.0527
# Epoch [1/15], Step [269/847], Loss : 5.0538
# Epoch [1/15], Step [270/847], Loss : 5.0538
# Epoch [1/15], Step [271/847], Loss : 5.0515
# Epoch [1/15], Step [272/847], Loss : 5.0505
# Epoch [1/15], Step [273/847], Loss : 5.0533
# Epoch [1/15], Step [274/847], Loss : 5.0517
# Epoch [1/15], Step [275/847], Loss : 5.0502
# Epoch [1/15], Step [276/847], Loss : 5.0510
# Epoch [1/15], Step [277/847], Loss : 5.0499
# Epoch [1/15], Step [278/847], Loss : 5.0493
# Epoch [1/15], Step [279/847], Loss : 5.0483
# Epoch [1/15], Step [280/847], Loss : 5.0477
# Epoch [1/15], Step [281/847], Loss : 5.0458
# Epoch [1/15], Step [282/847], Loss : 5.0455
# Epoch [1/15], Step [283/847], Loss : 5.0432
# Epoch [1/15], Step [284/847], Loss : 5.0442
# Epoch [1/15], Step [285/847], Loss : 5.0445
# Epoch [1/15], Step [286/847], Loss : 5.0454
# Epoch [1/15], Step [287/847], Loss : 5.0439
# Epoch [1/15], Step [288/847], Loss : 5.0437
# Epoch [1/15], Step [289/847], Loss : 5.0414
# Epoch [1/15], Step [290/847], Loss : 5.0399
# Epoch [1/15], Step [291/847], Loss : 5.0393
# Epoch [1/15], Step [292/847], Loss : 5.0414
# Epoch [1/15], Step [293/847], Loss : 5.0408
# Epoch [1/15], Step [294/847], Loss : 5.0399
# Epoch [1/15], Step [295/847], Loss : 5.0402
# Epoch [1/15], Step [296/847], Loss : 5.0406
# Epoch [1/15], Step [297/847], Loss : 5.0398
# Epoch [1/15], Step [298/847], Loss : 5.0386
# Epoch [1/15], Step [299/847], Loss : 5.0368
# Epoch [1/15], Step [300/847], Loss : 5.0365
# Epoch [1/15], Step [301/847], Loss : 5.0361
# Epoch [1/15], Step [302/847], Loss : 5.0379
# Epoch [1/15], Step [303/847], Loss : 5.0394
# Epoch [1/15], Step [304/847], Loss : 5.0396
# Epoch [1/15], Step [305/847], Loss : 5.0373
# Epoch [1/15], Step [306/847], Loss : 5.0369
# Epoch [1/15], Step [307/847], Loss : 5.0370
# Epoch [1/15], Step [308/847], Loss : 5.0373
# Epoch [1/15], Step [309/847], Loss : 5.0372
# Epoch [1/15], Step [310/847], Loss : 5.0366
# Epoch [1/15], Step [311/847], Loss : 5.0369
# Epoch [1/15], Step [312/847], Loss : 5.0365
# Epoch [1/15], Step [313/847], Loss : 5.0350
# Epoch [1/15], Step [314/847], Loss : 5.0337
# Epoch [1/15], Step [315/847], Loss : 5.0342
# Epoch [1/15], Step [316/847], Loss : 5.0334
# Epoch [1/15], Step [317/847], Loss : 5.0312
# Epoch [1/15], Step [318/847], Loss : 5.0306
# Epoch [1/15], Step [319/847], Loss : 5.0297
# Epoch [1/15], Step [320/847], Loss : 5.0286
# Epoch [1/15], Step [321/847], Loss : 5.0277
# Epoch [1/15], Step [322/847], Loss : 5.0286
# Epoch [1/15], Step [323/847], Loss : 5.0267
# Epoch [1/15], Step [324/847], Loss : 5.0244
# Epoch [1/15], Step [325/847], Loss : 5.0240
# Epoch [1/15], Step [326/847], Loss : 5.0236
# Epoch [1/15], Step [327/847], Loss : 5.0216
# Epoch [1/15], Step [328/847], Loss : 5.0208
# Epoch [1/15], Step [329/847], Loss : 5.0200
# Epoch [1/15], Step [330/847], Loss : 5.0203
# Epoch [1/15], Step [331/847], Loss : 5.0196
# Epoch [1/15], Step [332/847], Loss : 5.0189
# Epoch [1/15], Step [333/847], Loss : 5.0157
# Epoch [1/15], Step [334/847], Loss : 5.0153
# Epoch [1/15], Step [335/847], Loss : 5.0147
# Epoch [1/15], Step [336/847], Loss : 5.0144
# Epoch [1/15], Step [337/847], Loss : 5.0142
# Epoch [1/15], Step [338/847], Loss : 5.0155
# Epoch [1/15], Step [339/847], Loss : 5.0172
# Epoch [1/15], Step [340/847], Loss : 5.0138
# Epoch [1/15], Step [341/847], Loss : 5.0137
# Epoch [1/15], Step [342/847], Loss : 5.0134
# Epoch [1/15], Step [343/847], Loss : 5.0139
# Epoch [1/15], Step [344/847], Loss : 5.0119
# Epoch [1/15], Step [345/847], Loss : 5.0138
# Epoch [1/15], Step [346/847], Loss : 5.0125
# Epoch [1/15], Step [347/847], Loss : 5.0127
# Epoch [1/15], Step [348/847], Loss : 5.0122
# Epoch [1/15], Step [349/847], Loss : 5.0128
# Epoch [1/15], Step [350/847], Loss : 5.0130
# Epoch [1/15], Step [351/847], Loss : 5.0136
# Epoch [1/15], Step [352/847], Loss : 5.0146
# Epoch [1/15], Step [353/847], Loss : 5.0133
# Epoch [1/15], Step [354/847], Loss : 5.0114
# Epoch [1/15], Step [355/847], Loss : 5.0107
# Epoch [1/15], Step [356/847], Loss : 5.0104
# Epoch [1/15], Step [357/847], Loss : 5.0101
# Epoch [1/15], Step [358/847], Loss : 5.0116
# Epoch [1/15], Step [359/847], Loss : 5.0114
# Epoch [1/15], Step [360/847], Loss : 5.0106
# Epoch [1/15], Step [361/847], Loss : 5.0104
# Epoch [1/15], Step [362/847], Loss : 5.0096
# Epoch [1/15], Step [363/847], Loss : 5.0103
# Epoch [1/15], Step [364/847], Loss : 5.0101
# Epoch [1/15], Step [365/847], Loss : 5.0102
# Epoch [1/15], Step [366/847], Loss : 5.0090
# Epoch [1/15], Step [367/847], Loss : 5.0094
# Epoch [1/15], Step [368/847], Loss : 5.0093
# Epoch [1/15], Step [369/847], Loss : 5.0076
# Epoch [1/15], Step [370/847], Loss : 5.0083
# Epoch [1/15], Step [371/847], Loss : 5.0091
# Epoch [1/15], Step [372/847], Loss : 5.0081
# Epoch [1/15], Step [373/847], Loss : 5.0070
# Epoch [1/15], Step [374/847], Loss : 5.0059
# Epoch [1/15], Step [375/847], Loss : 5.0041
# Epoch [1/15], Step [376/847], Loss : 5.0027
# Epoch [1/15], Step [377/847], Loss : 5.0004
# Epoch [1/15], Step [378/847], Loss : 4.9993
# Epoch [1/15], Step [379/847], Loss : 4.9993
# Epoch [1/15], Step [380/847], Loss : 4.9992
# Epoch [1/15], Step [381/847], Loss : 4.9986
# Epoch [1/15], Step [382/847], Loss : 4.9979
# Epoch [1/15], Step [383/847], Loss : 4.9970
# Epoch [1/15], Step [384/847], Loss : 4.9960
# Epoch [1/15], Step [385/847], Loss : 4.9932
# Epoch [1/15], Step [386/847], Loss : 4.9926
# Epoch [1/15], Step [387/847], Loss : 4.9925
# Epoch [1/15], Step [388/847], Loss : 4.9938
# Epoch [1/15], Step [389/847], Loss : 4.9911
# Epoch [1/15], Step [390/847], Loss : 4.9902
# Epoch [1/15], Step [391/847], Loss : 4.9912
# Epoch [1/15], Step [392/847], Loss : 4.9904
# Epoch [1/15], Step [393/847], Loss : 4.9901
# Epoch [1/15], Step [394/847], Loss : 4.9899
# Epoch [1/15], Step [395/847], Loss : 4.9881
# Epoch [1/15], Step [396/847], Loss : 4.9891
# Epoch [1/15], Step [397/847], Loss : 4.9895
# Epoch [1/15], Step [398/847], Loss : 4.9889
# Epoch [1/15], Step [399/847], Loss : 4.9885
# Epoch [1/15], Step [400/847], Loss : 4.9860
# Epoch [1/15], Step [401/847], Loss : 4.9854
# Epoch [1/15], Step [402/847], Loss : 4.9860
# Epoch [1/15], Step [403/847], Loss : 4.9849
# Epoch [1/15], Step [404/847], Loss : 4.9835
# Epoch [1/15], Step [405/847], Loss : 4.9833
# Epoch [1/15], Step [406/847], Loss : 4.9834
# Epoch [1/15], Step [407/847], Loss : 4.9831
# Epoch [1/15], Step [408/847], Loss : 4.9829
# Epoch [1/15], Step [409/847], Loss : 4.9817
# Epoch [1/15], Step [410/847], Loss : 4.9811
# Epoch [1/15], Step [411/847], Loss : 4.9793
# Epoch [1/15], Step [412/847], Loss : 4.9788
# Epoch [1/15], Step [413/847], Loss : 4.9794
# Epoch [1/15], Step [414/847], Loss : 4.9788
# Epoch [1/15], Step [415/847], Loss : 4.9774
# Epoch [1/15], Step [416/847], Loss : 4.9771
# Epoch [1/15], Step [417/847], Loss : 4.9765
# Epoch [1/15], Step [418/847], Loss : 4.9760
# Epoch [1/15], Step [419/847], Loss : 4.9753
# Epoch [1/15], Step [420/847], Loss : 4.9750
# Epoch [1/15], Step [421/847], Loss : 4.9735
# Epoch [1/15], Step [422/847], Loss : 4.9726
# Epoch [1/15], Step [423/847], Loss : 4.9741
# Epoch [1/15], Step [424/847], Loss : 4.9723
# Epoch [1/15], Step [425/847], Loss : 4.9705
# Epoch [1/15], Step [426/847], Loss : 4.9700
# Epoch [1/15], Step [427/847], Loss : 4.9705
# Epoch [1/15], Step [428/847], Loss : 4.9694
# Epoch [1/15], Step [429/847], Loss : 4.9695
# Epoch [1/15], Step [430/847], Loss : 4.9693
# Epoch [1/15], Step [431/847], Loss : 4.9686
# Epoch [1/15], Step [432/847], Loss : 4.9667
# Epoch [1/15], Step [433/847], Loss : 4.9663
# Epoch [1/15], Step [434/847], Loss : 4.9662
# Epoch [1/15], Step [435/847], Loss : 4.9645
# Epoch [1/15], Step [436/847], Loss : 4.9660
# Epoch [1/15], Step [437/847], Loss : 4.9662
# Epoch [1/15], Step [438/847], Loss : 4.9648
# Epoch [1/15], Step [439/847], Loss : 4.9650
# Epoch [1/15], Step [440/847], Loss : 4.9638
# Epoch [1/15], Step [441/847], Loss : 4.9630
# Epoch [1/15], Step [442/847], Loss : 4.9627
# Epoch [1/15], Step [443/847], Loss : 4.9620
# Epoch [1/15], Step [444/847], Loss : 4.9606
# Epoch [1/15], Step [445/847], Loss : 4.9604
# Epoch [1/15], Step [446/847], Loss : 4.9595
# Epoch [1/15], Step [447/847], Loss : 4.9595
# Epoch [1/15], Step [448/847], Loss : 4.9583
# Epoch [1/15], Step [449/847], Loss : 4.9564
# Epoch [1/15], Step [450/847], Loss : 4.9553
# Epoch [1/15], Step [451/847], Loss : 4.9536
# Epoch [1/15], Step [452/847], Loss : 4.9532
# Epoch [1/15], Step [453/847], Loss : 4.9513
# Epoch [1/15], Step [454/847], Loss : 4.9505
# Epoch [1/15], Step [455/847], Loss : 4.9490
# Epoch [1/15], Step [456/847], Loss : 4.9474
# Epoch [1/15], Step [457/847], Loss : 4.9462
# Epoch [1/15], Step [458/847], Loss : 4.9464
# Epoch [1/15], Step [459/847], Loss : 4.9453
# Epoch [1/15], Step [460/847], Loss : 4.9457
# Epoch [1/15], Step [461/847], Loss : 4.9443
# Epoch [1/15], Step [462/847], Loss : 4.9424
# Epoch [1/15], Step [463/847], Loss : 4.9416
# Epoch [1/15], Step [464/847], Loss : 4.9406
# Epoch [1/15], Step [465/847], Loss : 4.9390
# Epoch [1/15], Step [466/847], Loss : 4.9386
# Epoch [1/15], Step [467/847], Loss : 4.9377
# Epoch [1/15], Step [468/847], Loss : 4.9382
# Epoch [1/15], Step [469/847], Loss : 4.9365
# Epoch [1/15], Step [470/847], Loss : 4.9372
# Epoch [1/15], Step [471/847], Loss : 4.9358
# Epoch [1/15], Step [472/847], Loss : 4.9354
# Epoch [1/15], Step [473/847], Loss : 4.9353
# Epoch [1/15], Step [474/847], Loss : 4.9349
# Epoch [1/15], Step [475/847], Loss : 4.9343
# Epoch [1/15], Step [476/847], Loss : 4.9350
# Epoch [1/15], Step [477/847], Loss : 4.9329
# Epoch [1/15], Step [478/847], Loss : 4.9317
# Epoch [1/15], Step [479/847], Loss : 4.9305
# Epoch [1/15], Step [480/847], Loss : 4.9301
# Epoch [1/15], Step [481/847], Loss : 4.9311
# Epoch [1/15], Step [482/847], Loss : 4.9300
# Epoch [1/15], Step [483/847], Loss : 4.9283
# Epoch [1/15], Step [484/847], Loss : 4.9268
# Epoch [1/15], Step [485/847], Loss : 4.9273
# Epoch [1/15], Step [486/847], Loss : 4.9260
# Epoch [1/15], Step [487/847], Loss : 4.9252
# Epoch [1/15], Step [488/847], Loss : 4.9260
# Epoch [1/15], Step [489/847], Loss : 4.9249
# Epoch [1/15], Step [490/847], Loss : 4.9249
# Epoch [1/15], Step [491/847], Loss : 4.9248
# Epoch [1/15], Step [492/847], Loss : 4.9247
# Epoch [1/15], Step [493/847], Loss : 4.9237
# Epoch [1/15], Step [494/847], Loss : 4.9240
# Epoch [1/15], Step [495/847], Loss : 4.9228
# Epoch [1/15], Step [496/847], Loss : 4.9230
# Epoch [1/15], Step [497/847], Loss : 4.9214
# Epoch [1/15], Step [498/847], Loss : 4.9227
# Epoch [1/15], Step [499/847], Loss : 4.9243
# Epoch [1/15], Step [500/847], Loss : 4.9239
# Epoch [1/15], Step [501/847], Loss : 4.9226
# Epoch [1/15], Step [502/847], Loss : 4.9227
# Epoch [1/15], Step [503/847], Loss : 4.9221
# Epoch [1/15], Step [504/847], Loss : 4.9222
# Epoch [1/15], Step [505/847], Loss : 4.9224
# Epoch [1/15], Step [506/847], Loss : 4.9215
# Epoch [1/15], Step [507/847], Loss : 4.9202
# Epoch [1/15], Step [508/847], Loss : 4.9195
# Epoch [1/15], Step [509/847], Loss : 4.9194
# Epoch [1/15], Step [510/847], Loss : 4.9201
# Epoch [1/15], Step [511/847], Loss : 4.9195
# Epoch [1/15], Step [512/847], Loss : 4.9190
# Epoch [1/15], Step [513/847], Loss : 4.9182
# Epoch [1/15], Step [514/847], Loss : 4.9197
# Epoch [1/15], Step [515/847], Loss : 4.9189
# Epoch [1/15], Step [516/847], Loss : 4.9171
# Epoch [1/15], Step [517/847], Loss : 4.9161
# Epoch [1/15], Step [518/847], Loss : 4.9147
# Epoch [1/15], Step [519/847], Loss : 4.9131
# Epoch [1/15], Step [520/847], Loss : 4.9120
# Epoch [1/15], Step [521/847], Loss : 4.9113
# Epoch [1/15], Step [522/847], Loss : 4.9119
# Epoch [1/15], Step [523/847], Loss : 4.9123
# Epoch [1/15], Step [524/847], Loss : 4.9125
# Epoch [1/15], Step [525/847], Loss : 4.9124
# Epoch [1/15], Step [526/847], Loss : 4.9118
# Epoch [1/15], Step [527/847], Loss : 4.9097
# Epoch [1/15], Step [528/847], Loss : 4.9081
# Epoch [1/15], Step [529/847], Loss : 4.9099
# Epoch [1/15], Step [530/847], Loss : 4.9100
# Epoch [1/15], Step [531/847], Loss : 4.9087
# Epoch [1/15], Step [532/847], Loss : 4.9083
# Epoch [1/15], Step [533/847], Loss : 4.9086
# Epoch [1/15], Step [534/847], Loss : 4.9074
# Epoch [1/15], Step [535/847], Loss : 4.9062
# Epoch [1/15], Step [536/847], Loss : 4.9056
# Epoch [1/15], Step [537/847], Loss : 4.9043
# Epoch [1/15], Step [538/847], Loss : 4.9034
# Epoch [1/15], Step [539/847], Loss : 4.9016
# Epoch [1/15], Step [540/847], Loss : 4.9001
# Epoch [1/15], Step [541/847], Loss : 4.8995
# Epoch [1/15], Step [542/847], Loss : 4.8998
# Epoch [1/15], Step [543/847], Loss : 4.8994
# Epoch [1/15], Step [544/847], Loss : 4.8996
# Epoch [1/15], Step [545/847], Loss : 4.8992
# Epoch [1/15], Step [546/847], Loss : 4.8974
# Epoch [1/15], Step [547/847], Loss : 4.8961
# Epoch [1/15], Step [548/847], Loss : 4.8950
# Epoch [1/15], Step [549/847], Loss : 4.8943
# Epoch [1/15], Step [550/847], Loss : 4.8934
# Epoch [1/15], Step [551/847], Loss : 4.8921
# Epoch [1/15], Step [552/847], Loss : 4.8901
# Epoch [1/15], Step [553/847], Loss : 4.8889
# Epoch [1/15], Step [554/847], Loss : 4.8878
# Epoch [1/15], Step [555/847], Loss : 4.8876
# Epoch [1/15], Step [556/847], Loss : 4.8863
# Epoch [1/15], Step [557/847], Loss : 4.8869
# Epoch [1/15], Step [558/847], Loss : 4.8870
# Epoch [1/15], Step [559/847], Loss : 4.8858
# Epoch [1/15], Step [560/847], Loss : 4.8845
# Epoch [1/15], Step [561/847], Loss : 4.8837
# Epoch [1/15], Step [562/847], Loss : 4.8826
# Epoch [1/15], Step [563/847], Loss : 4.8826
# Epoch [1/15], Step [564/847], Loss : 4.8827
# Epoch [1/15], Step [565/847], Loss : 4.8818
# Epoch [1/15], Step [566/847], Loss : 4.8808
# Epoch [1/15], Step [567/847], Loss : 4.8792
# Epoch [1/15], Step [568/847], Loss : 4.8783
# Epoch [1/15], Step [569/847], Loss : 4.8776
# Epoch [1/15], Step [570/847], Loss : 4.8769
# Epoch [1/15], Step [571/847], Loss : 4.8770
# Epoch [1/15], Step [572/847], Loss : 4.8766
# Epoch [1/15], Step [573/847], Loss : 4.8760
# Epoch [1/15], Step [574/847], Loss : 4.8750
# Epoch [1/15], Step [575/847], Loss : 4.8738
# Epoch [1/15], Step [576/847], Loss : 4.8728
# Epoch [1/15], Step [577/847], Loss : 4.8708
# Epoch [1/15], Step [578/847], Loss : 4.8720
# Epoch [1/15], Step [579/847], Loss : 4.8712
# Epoch [1/15], Step [580/847], Loss : 4.8712
# Epoch [1/15], Step [581/847], Loss : 4.8698
# Epoch [1/15], Step [582/847], Loss : 4.8694
# Epoch [1/15], Step [583/847], Loss : 4.8685
# Epoch [1/15], Step [584/847], Loss : 4.8686
# Epoch [1/15], Step [585/847], Loss : 4.8674
# Epoch [1/15], Step [586/847], Loss : 4.8678
# Epoch [1/15], Step [587/847], Loss : 4.8671
# Epoch [1/15], Step [588/847], Loss : 4.8675
# Epoch [1/15], Step [589/847], Loss : 4.8675
# Epoch [1/15], Step [590/847], Loss : 4.8666
# Epoch [1/15], Step [591/847], Loss : 4.8649
# Epoch [1/15], Step [592/847], Loss : 4.8640
# Epoch [1/15], Step [593/847], Loss : 4.8638
# Epoch [1/15], Step [594/847], Loss : 4.8640
# Epoch [1/15], Step [595/847], Loss : 4.8631
# Epoch [1/15], Step [596/847], Loss : 4.8618
# Epoch [1/15], Step [597/847], Loss : 4.8613
# Epoch [1/15], Step [598/847], Loss : 4.8602
# Epoch [1/15], Step [599/847], Loss : 4.8602
# Epoch [1/15], Step [600/847], Loss : 4.8602
# Epoch [1/15], Step [601/847], Loss : 4.8599
# Epoch [1/15], Step [602/847], Loss : 4.8588
# Epoch [1/15], Step [603/847], Loss : 4.8586
# Epoch [1/15], Step [604/847], Loss : 4.8577
# Epoch [1/15], Step [605/847], Loss : 4.8569
# Epoch [1/15], Step [606/847], Loss : 4.8558
# Epoch [1/15], Step [607/847], Loss : 4.8547
# Epoch [1/15], Step [608/847], Loss : 4.8538
# Epoch [1/15], Step [609/847], Loss : 4.8524
# Epoch [1/15], Step [610/847], Loss : 4.8516
# Epoch [1/15], Step [611/847], Loss : 4.8507
# Epoch [1/15], Step [612/847], Loss : 4.8496
# Epoch [1/15], Step [613/847], Loss : 4.8501
# Epoch [1/15], Step [614/847], Loss : 4.8502
# Epoch [1/15], Step [615/847], Loss : 4.8499
# Epoch [1/15], Step [616/847], Loss : 4.8496
# Epoch [1/15], Step [617/847], Loss : 4.8479
# Epoch [1/15], Step [618/847], Loss : 4.8477
# Epoch [1/15], Step [619/847], Loss : 4.8467
# Epoch [1/15], Step [620/847], Loss : 4.8461
# Epoch [1/15], Step [621/847], Loss : 4.8443
# Epoch [1/15], Step [622/847], Loss : 4.8439
# Epoch [1/15], Step [623/847], Loss : 4.8432
# Epoch [1/15], Step [624/847], Loss : 4.8416
# Epoch [1/15], Step [625/847], Loss : 4.8423
# Epoch [1/15], Step [626/847], Loss : 4.8412
# Epoch [1/15], Step [627/847], Loss : 4.8413
# Epoch [1/15], Step [628/847], Loss : 4.8406
# Epoch [1/15], Step [629/847], Loss : 4.8394
# Epoch [1/15], Step [630/847], Loss : 4.8384
# Epoch [1/15], Step [631/847], Loss : 4.8378
# Epoch [1/15], Step [632/847], Loss : 4.8373
# Epoch [1/15], Step [633/847], Loss : 4.8364
# Epoch [1/15], Step [634/847], Loss : 4.8347
# Epoch [1/15], Step [635/847], Loss : 4.8337
# Epoch [1/15], Step [636/847], Loss : 4.8329
# Epoch [1/15], Step [637/847], Loss : 4.8318
# Epoch [1/15], Step [638/847], Loss : 4.8310
# Epoch [1/15], Step [639/847], Loss : 4.8303
# Epoch [1/15], Step [640/847], Loss : 4.8294
# Epoch [1/15], Step [641/847], Loss : 4.8292
# Epoch [1/15], Step [642/847], Loss : 4.8286
# Epoch [1/15], Step [643/847], Loss : 4.8275
# Epoch [1/15], Step [644/847], Loss : 4.8260
# Epoch [1/15], Step [645/847], Loss : 4.8252
# Epoch [1/15], Step [646/847], Loss : 4.8251
# Epoch [1/15], Step [647/847], Loss : 4.8237
# Epoch [1/15], Step [648/847], Loss : 4.8227
# Epoch [1/15], Step [649/847], Loss : 4.8213
# Epoch [1/15], Step [650/847], Loss : 4.8205
# Epoch [1/15], Step [651/847], Loss : 4.8204
# Epoch [1/15], Step [652/847], Loss : 4.8214
# Epoch [1/15], Step [653/847], Loss : 4.8212
# Epoch [1/15], Step [654/847], Loss : 4.8205
# Epoch [1/15], Step [655/847], Loss : 4.8199
# Epoch [1/15], Step [656/847], Loss : 4.8186
# Epoch [1/15], Step [657/847], Loss : 4.8167
# Epoch [1/15], Step [658/847], Loss : 4.8166
# Epoch [1/15], Step [659/847], Loss : 4.8168
# Epoch [1/15], Step [660/847], Loss : 4.8151
# Epoch [1/15], Step [661/847], Loss : 4.8147
# Epoch [1/15], Step [662/847], Loss : 4.8136
# Epoch [1/15], Step [663/847], Loss : 4.8148
# Epoch [1/15], Step [664/847], Loss : 4.8141
# Epoch [1/15], Step [665/847], Loss : 4.8140
# Epoch [1/15], Step [666/847], Loss : 4.8129
# Epoch [1/15], Step [667/847], Loss : 4.8119
# Epoch [1/15], Step [668/847], Loss : 4.8111
# Epoch [1/15], Step [669/847], Loss : 4.8096
# Epoch [1/15], Step [670/847], Loss : 4.8081
# Epoch [1/15], Step [671/847], Loss : 4.8072
# Epoch [1/15], Step [672/847], Loss : 4.8067
# Epoch [1/15], Step [673/847], Loss : 4.8058
# Epoch [1/15], Step [674/847], Loss : 4.8059
# Epoch [1/15], Step [675/847], Loss : 4.8053
# Epoch [1/15], Step [676/847], Loss : 4.8043
# Epoch [1/15], Step [677/847], Loss : 4.8032
# Epoch [1/15], Step [678/847], Loss : 4.8039
# Epoch [1/15], Step [679/847], Loss : 4.8043
# Epoch [1/15], Step [680/847], Loss : 4.8035
# Epoch [1/15], Step [681/847], Loss : 4.8034
# Epoch [1/15], Step [682/847], Loss : 4.8030
# Epoch [1/15], Step [683/847], Loss : 4.8015
# Epoch [1/15], Step [684/847], Loss : 4.8003
# Epoch [1/15], Step [685/847], Loss : 4.7994
# Epoch [1/15], Step [686/847], Loss : 4.8001
# Epoch [1/15], Step [687/847], Loss : 4.7986
# Epoch [1/15], Step [688/847], Loss : 4.7983
# Epoch [1/15], Step [689/847], Loss : 4.7981
# Epoch [1/15], Step [690/847], Loss : 4.7968
# Epoch [1/15], Step [691/847], Loss : 4.7963
# Epoch [1/15], Step [692/847], Loss : 4.7962
# Epoch [1/15], Step [693/847], Loss : 4.7947
# Epoch [1/15], Step [694/847], Loss : 4.7945
# Epoch [1/15], Step [695/847], Loss : 4.7937
# Epoch [1/15], Step [696/847], Loss : 4.7942
# Epoch [1/15], Step [697/847], Loss : 4.7930
# Epoch [1/15], Step [698/847], Loss : 4.7927
# Epoch [1/15], Step [699/847], Loss : 4.7927
# Epoch [1/15], Step [700/847], Loss : 4.7918
# Epoch [1/15], Step [701/847], Loss : 4.7910
# Epoch [1/15], Step [702/847], Loss : 4.7899
# Epoch [1/15], Step [703/847], Loss : 4.7899
# Epoch [1/15], Step [704/847], Loss : 4.7904
# Epoch [1/15], Step [705/847], Loss : 4.7891
# Epoch [1/15], Step [706/847], Loss : 4.7880
# Epoch [1/15], Step [707/847], Loss : 4.7869
# Epoch [1/15], Step [708/847], Loss : 4.7866
# Epoch [1/15], Step [709/847], Loss : 4.7856
# Epoch [1/15], Step [710/847], Loss : 4.7839
# Epoch [1/15], Step [711/847], Loss : 4.7827
# Epoch [1/15], Step [712/847], Loss : 4.7819
# Epoch [1/15], Step [713/847], Loss : 4.7808
# Epoch [1/15], Step [714/847], Loss : 4.7802
# Epoch [1/15], Step [715/847], Loss : 4.7801
# Epoch [1/15], Step [716/847], Loss : 4.7788
# Epoch [1/15], Step [717/847], Loss : 4.7770
# Epoch [1/15], Step [718/847], Loss : 4.7776
# Epoch [1/15], Step [719/847], Loss : 4.7770
# Epoch [1/15], Step [720/847], Loss : 4.7758
# Epoch [1/15], Step [721/847], Loss : 4.7758
# Epoch [1/15], Step [722/847], Loss : 4.7744
# Epoch [1/15], Step [723/847], Loss : 4.7737
# Epoch [1/15], Step [724/847], Loss : 4.7726
# Epoch [1/15], Step [725/847], Loss : 4.7716
# Epoch [1/15], Step [726/847], Loss : 4.7713
# Epoch [1/15], Step [727/847], Loss : 4.7710
# Epoch [1/15], Step [728/847], Loss : 4.7717
# Epoch [1/15], Step [729/847], Loss : 4.7718
# Epoch [1/15], Step [730/847], Loss : 4.7715
# Epoch [1/15], Step [731/847], Loss : 4.7698
# Epoch [1/15], Step [732/847], Loss : 4.7704
# Epoch [1/15], Step [733/847], Loss : 4.7700
# Epoch [1/15], Step [734/847], Loss : 4.7690
# Epoch [1/15], Step [735/847], Loss : 4.7687
# Epoch [1/15], Step [736/847], Loss : 4.7682
# Epoch [1/15], Step [737/847], Loss : 4.7674
# Epoch [1/15], Step [738/847], Loss : 4.7669
# Epoch [1/15], Step [739/847], Loss : 4.7663
# Epoch [1/15], Step [740/847], Loss : 4.7652
# Epoch [1/15], Step [741/847], Loss : 4.7649
# Epoch [1/15], Step [742/847], Loss : 4.7651
# Epoch [1/15], Step [743/847], Loss : 4.7642
# Epoch [1/15], Step [744/847], Loss : 4.7636
# Epoch [1/15], Step [745/847], Loss : 4.7623
# Epoch [1/15], Step [746/847], Loss : 4.7631
# Epoch [1/15], Step [747/847], Loss : 4.7629
# Epoch [1/15], Step [748/847], Loss : 4.7629
# Epoch [1/15], Step [749/847], Loss : 4.7624
# Epoch [1/15], Step [750/847], Loss : 4.7622
# Epoch [1/15], Step [751/847], Loss : 4.7613
# Epoch [1/15], Step [752/847], Loss : 4.7606
# Epoch [1/15], Step [753/847], Loss : 4.7596
# Epoch [1/15], Step [754/847], Loss : 4.7590
# Epoch [1/15], Step [755/847], Loss : 4.7581
# Epoch [1/15], Step [756/847], Loss : 4.7564
# Epoch [1/15], Step [757/847], Loss : 4.7564
# Epoch [1/15], Step [758/847], Loss : 4.7560
# Epoch [1/15], Step [759/847], Loss : 4.7551
# Epoch [1/15], Step [760/847], Loss : 4.7550
# Epoch [1/15], Step [761/847], Loss : 4.7542
# Epoch [1/15], Step [762/847], Loss : 4.7545
# Epoch [1/15], Step [763/847], Loss : 4.7537
# Epoch [1/15], Step [764/847], Loss : 4.7530
# Epoch [1/15], Step [765/847], Loss : 4.7523
# Epoch [1/15], Step [766/847], Loss : 4.7516
# Epoch [1/15], Step [767/847], Loss : 4.7510
# Epoch [1/15], Step [768/847], Loss : 4.7497
# Epoch [1/15], Step [769/847], Loss : 4.7481
# Epoch [1/15], Step [770/847], Loss : 4.7482
# Epoch [1/15], Step [771/847], Loss : 4.7481
# Epoch [1/15], Step [772/847], Loss : 4.7473
# Epoch [1/15], Step [773/847], Loss : 4.7458
# Epoch [1/15], Step [774/847], Loss : 4.7446
# Epoch [1/15], Step [775/847], Loss : 4.7439
# Epoch [1/15], Step [776/847], Loss : 4.7431
# Epoch [1/15], Step [777/847], Loss : 4.7421
# Epoch [1/15], Step [778/847], Loss : 4.7406
# Epoch [1/15], Step [779/847], Loss : 4.7408
# Epoch [1/15], Step [780/847], Loss : 4.7410
# Epoch [1/15], Step [781/847], Loss : 4.7401
# Epoch [1/15], Step [782/847], Loss : 4.7404
# Epoch [1/15], Step [783/847], Loss : 4.7397
# Epoch [1/15], Step [784/847], Loss : 4.7387
# Epoch [1/15], Step [785/847], Loss : 4.7393
# Epoch [1/15], Step [786/847], Loss : 4.7377
# Epoch [1/15], Step [787/847], Loss : 4.7370
# Epoch [1/15], Step [788/847], Loss : 4.7362
# Epoch [1/15], Step [789/847], Loss : 4.7358
# Epoch [1/15], Step [790/847], Loss : 4.7352
# Epoch [1/15], Step [791/847], Loss : 4.7348
# Epoch [1/15], Step [792/847], Loss : 4.7340
# Epoch [1/15], Step [793/847], Loss : 4.7334
# Epoch [1/15], Step [794/847], Loss : 4.7332
# Epoch [1/15], Step [795/847], Loss : 4.7335
# Epoch [1/15], Step [796/847], Loss : 4.7324
# Epoch [1/15], Step [797/847], Loss : 4.7322
# Epoch [1/15], Step [798/847], Loss : 4.7319
# Epoch [1/15], Step [799/847], Loss : 4.7319
# Epoch [1/15], Step [800/847], Loss : 4.7317
# Epoch [1/15], Step [801/847], Loss : 4.7316
# Epoch [1/15], Step [802/847], Loss : 4.7300
# Epoch [1/15], Step [803/847], Loss : 4.7291
# Epoch [1/15], Step [804/847], Loss : 4.7291
# Epoch [1/15], Step [805/847], Loss : 4.7279
# Epoch [1/15], Step [806/847], Loss : 4.7274
# Epoch [1/15], Step [807/847], Loss : 4.7264
# Epoch [1/15], Step [808/847], Loss : 4.7258
# Epoch [1/15], Step [809/847], Loss : 4.7245
# Epoch [1/15], Step [810/847], Loss : 4.7240
# Epoch [1/15], Step [811/847], Loss : 4.7232
# Epoch [1/15], Step [812/847], Loss : 4.7221
# Epoch [1/15], Step [813/847], Loss : 4.7212
# Epoch [1/15], Step [814/847], Loss : 4.7197
# Epoch [1/15], Step [815/847], Loss : 4.7194
# Epoch [1/15], Step [816/847], Loss : 4.7180
# Epoch [1/15], Step [817/847], Loss : 4.7175
# Epoch [1/15], Step [818/847], Loss : 4.7169
# Epoch [1/15], Step [819/847], Loss : 4.7165
# Epoch [1/15], Step [820/847], Loss : 4.7145
# Epoch [1/15], Step [821/847], Loss : 4.7142
# Epoch [1/15], Step [822/847], Loss : 4.7133
# Epoch [1/15], Step [823/847], Loss : 4.7140
# Epoch [1/15], Step [824/847], Loss : 4.7142
# Epoch [1/15], Step [825/847], Loss : 4.7141
# Epoch [1/15], Step [826/847], Loss : 4.7131
# Epoch [1/15], Step [827/847], Loss : 4.7121
# Epoch [1/15], Step [828/847], Loss : 4.7113
# Epoch [1/15], Step [829/847], Loss : 4.7107
# Epoch [1/15], Step [830/847], Loss : 4.7108
# Epoch [1/15], Step [831/847], Loss : 4.7104
# Epoch [1/15], Step [832/847], Loss : 4.7108
# Epoch [1/15], Step [833/847], Loss : 4.7096
# Epoch [1/15], Step [834/847], Loss : 4.7090
# Epoch [1/15], Step [835/847], Loss : 4.7089
# Epoch [1/15], Step [836/847], Loss : 4.7078
# Epoch [1/15], Step [837/847], Loss : 4.7081
# Epoch [1/15], Step [838/847], Loss : 4.7079
# Epoch [1/15], Step [839/847], Loss : 4.7073
# Epoch [1/15], Step [840/847], Loss : 4.7069
# Epoch [1/15], Step [841/847], Loss : 4.7062
# Epoch [1/15], Step [842/847], Loss : 4.7056
# Epoch [1/15], Step [843/847], Loss : 4.7046
# Epoch [1/15], Step [844/847], Loss : 4.7033
# Epoch [1/15], Step [845/847], Loss : 4.7026
# Epoch [1/15], Step [846/847], Loss : 4.7018
# Epoch [1/15], Step [847/847], Loss : 4.7015
# Epoch: 1, Loss: 4.7015, Accuracy: 0.0759
# Saving best model!
# Epoch [2/15], Step [1/847], Loss : 3.9559
# Epoch [2/15], Step [2/847], Loss : 4.5034
# Epoch [2/15], Step [3/847], Loss : 4.2269
# Epoch [2/15], Step [4/847], Loss : 3.9931
# Epoch [2/15], Step [5/847], Loss : 4.1477
# Epoch [2/15], Step [6/847], Loss : 4.0579
# Epoch [2/15], Step [7/847], Loss : 4.0648
# Epoch [2/15], Step [8/847], Loss : 4.0726
# Epoch [2/15], Step [9/847], Loss : 4.0474
# Epoch [2/15], Step [10/847], Loss : 4.0469
# Epoch [2/15], Step [11/847], Loss : 4.0864
# Epoch [2/15], Step [12/847], Loss : 4.0482
# Epoch [2/15], Step [13/847], Loss : 4.0260
# Epoch [2/15], Step [14/847], Loss : 4.0391
# Epoch [2/15], Step [15/847], Loss : 3.9956
# Epoch [2/15], Step [16/847], Loss : 3.9935
# Epoch [2/15], Step [17/847], Loss : 4.0410
# Epoch [2/15], Step [18/847], Loss : 4.1183
# Epoch [2/15], Step [19/847], Loss : 4.1434
# Epoch [2/15], Step [20/847], Loss : 4.1490
# Epoch [2/15], Step [21/847], Loss : 4.1603
# Epoch [2/15], Step [22/847], Loss : 4.1611
# Epoch [2/15], Step [23/847], Loss : 4.1770
# Epoch [2/15], Step [24/847], Loss : 4.1415
# Epoch [2/15], Step [25/847], Loss : 4.1212
# Epoch [2/15], Step [26/847], Loss : 4.1101
# Epoch [2/15], Step [27/847], Loss : 4.0978
# Epoch [2/15], Step [28/847], Loss : 4.0823
# Epoch [2/15], Step [29/847], Loss : 4.0626
# Epoch [2/15], Step [30/847], Loss : 4.0707
# Epoch [2/15], Step [31/847], Loss : 4.0784
# Epoch [2/15], Step [32/847], Loss : 4.0941
# Epoch [2/15], Step [33/847], Loss : 4.0740
# Epoch [2/15], Step [34/847], Loss : 4.0616
# Epoch [2/15], Step [35/847], Loss : 4.0749
# Epoch [2/15], Step [36/847], Loss : 4.0590
# Epoch [2/15], Step [37/847], Loss : 4.0530
# Epoch [2/15], Step [38/847], Loss : 4.0521
# Epoch [2/15], Step [39/847], Loss : 4.0506
# Epoch [2/15], Step [40/847], Loss : 4.0491
# Epoch [2/15], Step [41/847], Loss : 4.0302
# Epoch [2/15], Step [42/847], Loss : 4.0360
# Epoch [2/15], Step [43/847], Loss : 4.0462
# Epoch [2/15], Step [44/847], Loss : 4.0497
# Epoch [2/15], Step [45/847], Loss : 4.0414
# Epoch [2/15], Step [46/847], Loss : 4.0381
# Epoch [2/15], Step [47/847], Loss : 4.0537
# Epoch [2/15], Step [48/847], Loss : 4.0502
# Epoch [2/15], Step [49/847], Loss : 4.0604
# Epoch [2/15], Step [50/847], Loss : 4.0672
# Epoch [2/15], Step [51/847], Loss : 4.0751
# Epoch [2/15], Step [52/847], Loss : 4.0938
# Epoch [2/15], Step [53/847], Loss : 4.1091
# Epoch [2/15], Step [54/847], Loss : 4.1003
# Epoch [2/15], Step [55/847], Loss : 4.0993
# Epoch [2/15], Step [56/847], Loss : 4.0944
# Epoch [2/15], Step [57/847], Loss : 4.0975
# Epoch [2/15], Step [58/847], Loss : 4.0843
# Epoch [2/15], Step [59/847], Loss : 4.0803
# Epoch [2/15], Step [60/847], Loss : 4.0858
# Epoch [2/15], Step [61/847], Loss : 4.0888
# Epoch [2/15], Step [62/847], Loss : 4.0820
# Epoch [2/15], Step [63/847], Loss : 4.0818
# Epoch [2/15], Step [64/847], Loss : 4.0783
# Epoch [2/15], Step [65/847], Loss : 4.0732
# Epoch [2/15], Step [66/847], Loss : 4.0775
# Epoch [2/15], Step [67/847], Loss : 4.0651
# Epoch [2/15], Step [68/847], Loss : 4.0704
# Epoch [2/15], Step [69/847], Loss : 4.0673
# Epoch [2/15], Step [70/847], Loss : 4.0746
# Epoch [2/15], Step [71/847], Loss : 4.0751
# Epoch [2/15], Step [72/847], Loss : 4.0821
# Epoch [2/15], Step [73/847], Loss : 4.0786
# Epoch [2/15], Step [74/847], Loss : 4.0890
# Epoch [2/15], Step [75/847], Loss : 4.0892
# Epoch [2/15], Step [76/847], Loss : 4.0898
# Epoch [2/15], Step [77/847], Loss : 4.0884
# Epoch [2/15], Step [78/847], Loss : 4.0842
# Epoch [2/15], Step [79/847], Loss : 4.0919
# Epoch [2/15], Step [80/847], Loss : 4.0956
# Epoch [2/15], Step [81/847], Loss : 4.1028
# Epoch [2/15], Step [82/847], Loss : 4.1096
# Epoch [2/15], Step [83/847], Loss : 4.1142
# Epoch [2/15], Step [84/847], Loss : 4.1152
# Epoch [2/15], Step [85/847], Loss : 4.1149
# Epoch [2/15], Step [86/847], Loss : 4.1113
# Epoch [2/15], Step [87/847], Loss : 4.1172
# Epoch [2/15], Step [88/847], Loss : 4.1188
# Epoch [2/15], Step [89/847], Loss : 4.1197
# Epoch [2/15], Step [90/847], Loss : 4.1264
# Epoch [2/15], Step [91/847], Loss : 4.1271
# Epoch [2/15], Step [92/847], Loss : 4.1272
# Epoch [2/15], Step [93/847], Loss : 4.1234
# Epoch [2/15], Step [94/847], Loss : 4.1229
# Epoch [2/15], Step [95/847], Loss : 4.1179
# Epoch [2/15], Step [96/847], Loss : 4.1148
# Epoch [2/15], Step [97/847], Loss : 4.1119
# Epoch [2/15], Step [98/847], Loss : 4.1113
# Epoch [2/15], Step [99/847], Loss : 4.1174
# Epoch [2/15], Step [100/847], Loss : 4.1174
# Epoch [2/15], Step [101/847], Loss : 4.1176
# Epoch [2/15], Step [102/847], Loss : 4.1114
# Epoch [2/15], Step [103/847], Loss : 4.1121
# Epoch [2/15], Step [104/847], Loss : 4.1070
# Epoch [2/15], Step [105/847], Loss : 4.1165
# Epoch [2/15], Step [106/847], Loss : 4.1211
# Epoch [2/15], Step [107/847], Loss : 4.1167
# Epoch [2/15], Step [108/847], Loss : 4.1161
# Epoch [2/15], Step [109/847], Loss : 4.1206
# Epoch [2/15], Step [110/847], Loss : 4.1189
# Epoch [2/15], Step [111/847], Loss : 4.1251
# Epoch [2/15], Step [112/847], Loss : 4.1261
# Epoch [2/15], Step [113/847], Loss : 4.1234
# Epoch [2/15], Step [114/847], Loss : 4.1242
# Epoch [2/15], Step [115/847], Loss : 4.1292
# Epoch [2/15], Step [116/847], Loss : 4.1320
# Epoch [2/15], Step [117/847], Loss : 4.1239
# Epoch [2/15], Step [118/847], Loss : 4.1247
# Epoch [2/15], Step [119/847], Loss : 4.1288
# Epoch [2/15], Step [120/847], Loss : 4.1287
# Epoch [2/15], Step [121/847], Loss : 4.1280
# Epoch [2/15], Step [122/847], Loss : 4.1227
# Epoch [2/15], Step [123/847], Loss : 4.1252
# Epoch [2/15], Step [124/847], Loss : 4.1224
# Epoch [2/15], Step [125/847], Loss : 4.1286
# Epoch [2/15], Step [126/847], Loss : 4.1255
# Epoch [2/15], Step [127/847], Loss : 4.1260
# Epoch [2/15], Step [128/847], Loss : 4.1222
# Epoch [2/15], Step [129/847], Loss : 4.1184
# Epoch [2/15], Step [130/847], Loss : 4.1185
# Epoch [2/15], Step [131/847], Loss : 4.1272
# Epoch [2/15], Step [132/847], Loss : 4.1233
# Epoch [2/15], Step [133/847], Loss : 4.1226
# Epoch [2/15], Step [134/847], Loss : 4.1240
# Epoch [2/15], Step [135/847], Loss : 4.1254
# Epoch [2/15], Step [136/847], Loss : 4.1233
# Epoch [2/15], Step [137/847], Loss : 4.1217
# Epoch [2/15], Step [138/847], Loss : 4.1249
# Epoch [2/15], Step [139/847], Loss : 4.1206
# Epoch [2/15], Step [140/847], Loss : 4.1203
# Epoch [2/15], Step [141/847], Loss : 4.1243
# Epoch [2/15], Step [142/847], Loss : 4.1174
# Epoch [2/15], Step [143/847], Loss : 4.1160
# Epoch [2/15], Step [144/847], Loss : 4.1135
# Epoch [2/15], Step [145/847], Loss : 4.1157
# Epoch [2/15], Step [146/847], Loss : 4.1209
# Epoch [2/15], Step [147/847], Loss : 4.1203
# Epoch [2/15], Step [148/847], Loss : 4.1206
# Epoch [2/15], Step [149/847], Loss : 4.1221
# Epoch [2/15], Step [150/847], Loss : 4.1229
# Epoch [2/15], Step [151/847], Loss : 4.1244
# Epoch [2/15], Step [152/847], Loss : 4.1210
# Epoch [2/15], Step [153/847], Loss : 4.1204
# Epoch [2/15], Step [154/847], Loss : 4.1197
# Epoch [2/15], Step [155/847], Loss : 4.1179
# Epoch [2/15], Step [156/847], Loss : 4.1221
# Epoch [2/15], Step [157/847], Loss : 4.1242
# Epoch [2/15], Step [158/847], Loss : 4.1250
# Epoch [2/15], Step [159/847], Loss : 4.1218
# Epoch [2/15], Step [160/847], Loss : 4.1237
# Epoch [2/15], Step [161/847], Loss : 4.1200
# Epoch [2/15], Step [162/847], Loss : 4.1195
# Epoch [2/15], Step [163/847], Loss : 4.1211
# Epoch [2/15], Step [164/847], Loss : 4.1208
# Epoch [2/15], Step [165/847], Loss : 4.1226
# Epoch [2/15], Step [166/847], Loss : 4.1252
# Epoch [2/15], Step [167/847], Loss : 4.1220
# Epoch [2/15], Step [168/847], Loss : 4.1224
# Epoch [2/15], Step [169/847], Loss : 4.1175
# Epoch [2/15], Step [170/847], Loss : 4.1211
# Epoch [2/15], Step [171/847], Loss : 4.1198
# Epoch [2/15], Step [172/847], Loss : 4.1162
# Epoch [2/15], Step [173/847], Loss : 4.1128
# Epoch [2/15], Step [174/847], Loss : 4.1087
# Epoch [2/15], Step [175/847], Loss : 4.1100
# Epoch [2/15], Step [176/847], Loss : 4.1072
# Epoch [2/15], Step [177/847], Loss : 4.1088
# Epoch [2/15], Step [178/847], Loss : 4.1077
# Epoch [2/15], Step [179/847], Loss : 4.1062
# Epoch [2/15], Step [180/847], Loss : 4.1044
# Epoch [2/15], Step [181/847], Loss : 4.1053
# Epoch [2/15], Step [182/847], Loss : 4.1062
# Epoch [2/15], Step [183/847], Loss : 4.1038
# Epoch [2/15], Step [184/847], Loss : 4.1027
# Epoch [2/15], Step [185/847], Loss : 4.1030
# Epoch [2/15], Step [186/847], Loss : 4.1020
# Epoch [2/15], Step [187/847], Loss : 4.1017
# Epoch [2/15], Step [188/847], Loss : 4.1060
# Epoch [2/15], Step [189/847], Loss : 4.1034
# Epoch [2/15], Step [190/847], Loss : 4.1067
# Epoch [2/15], Step [191/847], Loss : 4.1060
# Epoch [2/15], Step [192/847], Loss : 4.0995
# Epoch [2/15], Step [193/847], Loss : 4.1011
# Epoch [2/15], Step [194/847], Loss : 4.1032
# Epoch [2/15], Step [195/847], Loss : 4.1029
# Epoch [2/15], Step [196/847], Loss : 4.0985
# Epoch [2/15], Step [197/847], Loss : 4.1001
# Epoch [2/15], Step [198/847], Loss : 4.1016
# Epoch [2/15], Step [199/847], Loss : 4.1013
# Epoch [2/15], Step [200/847], Loss : 4.1002
# Epoch [2/15], Step [201/847], Loss : 4.1008
# Epoch [2/15], Step [202/847], Loss : 4.1003
# Epoch [2/15], Step [203/847], Loss : 4.0968
# Epoch [2/15], Step [204/847], Loss : 4.0961
# Epoch [2/15], Step [205/847], Loss : 4.0988
# Epoch [2/15], Step [206/847], Loss : 4.0969
# Epoch [2/15], Step [207/847], Loss : 4.0973
# Epoch [2/15], Step [208/847], Loss : 4.0989
# Epoch [2/15], Step [209/847], Loss : 4.0975
# Epoch [2/15], Step [210/847], Loss : 4.0952
# Epoch [2/15], Step [211/847], Loss : 4.0951
# Epoch [2/15], Step [212/847], Loss : 4.0959
# Epoch [2/15], Step [213/847], Loss : 4.0997
# Epoch [2/15], Step [214/847], Loss : 4.0993
# Epoch [2/15], Step [215/847], Loss : 4.1048
# Epoch [2/15], Step [216/847], Loss : 4.1050
# Epoch [2/15], Step [217/847], Loss : 4.1065
# Epoch [2/15], Step [218/847], Loss : 4.1078
# Epoch [2/15], Step [219/847], Loss : 4.1087
# Epoch [2/15], Step [220/847], Loss : 4.1101
# Epoch [2/15], Step [221/847], Loss : 4.1119
# Epoch [2/15], Step [222/847], Loss : 4.1154
# Epoch [2/15], Step [223/847], Loss : 4.1146
# Epoch [2/15], Step [224/847], Loss : 4.1146
# Epoch [2/15], Step [225/847], Loss : 4.1161
# Epoch [2/15], Step [226/847], Loss : 4.1159
# Epoch [2/15], Step [227/847], Loss : 4.1153
# Epoch [2/15], Step [228/847], Loss : 4.1182
# Epoch [2/15], Step [229/847], Loss : 4.1177
# Epoch [2/15], Step [230/847], Loss : 4.1183
# Epoch [2/15], Step [231/847], Loss : 4.1188
# Epoch [2/15], Step [232/847], Loss : 4.1161
# Epoch [2/15], Step [233/847], Loss : 4.1150
# Epoch [2/15], Step [234/847], Loss : 4.1130
# Epoch [2/15], Step [235/847], Loss : 4.1134
# Epoch [2/15], Step [236/847], Loss : 4.1122
# Epoch [2/15], Step [237/847], Loss : 4.1090
# Epoch [2/15], Step [238/847], Loss : 4.1097
# Epoch [2/15], Step [239/847], Loss : 4.1116
# Epoch [2/15], Step [240/847], Loss : 4.1131
# Epoch [2/15], Step [241/847], Loss : 4.1117
# Epoch [2/15], Step [242/847], Loss : 4.1109
# Epoch [2/15], Step [243/847], Loss : 4.1081
# Epoch [2/15], Step [244/847], Loss : 4.1082
# Epoch [2/15], Step [245/847], Loss : 4.1107
# Epoch [2/15], Step [246/847], Loss : 4.1104
# Epoch [2/15], Step [247/847], Loss : 4.1081
# ...
# Epoch [15/15], Step [495/847], Loss : 0.8969
# Epoch [15/15], Step [496/847], Loss : 0.8977
# Epoch [15/15], Step [497/847], Loss : 0.8988
# Epoch [15/15], Step [498/847], Loss : 0.8987
# Epoch [15/15], Step [499/847], Loss : 0.8993
# Epoch [15/15], Step [500/847], Loss : 0.8990
# Epoch [15/15], Step [501/847], Loss : 0.8985
# Epoch [15/15], Step [502/847], Loss : 0.8987
# Epoch [15/15], Step [503/847], Loss : 0.9005
# Epoch [15/15], Step [504/847], Loss : 0.8998
# Epoch [15/15], Step [505/847], Loss : 0.8993
# Epoch [15/15], Step [506/847], Loss : 0.8989
# Epoch [15/15], Step [507/847], Loss : 0.8988
# Epoch [15/15], Step [508/847], Loss : 0.8984
# Epoch [15/15], Step [509/847], Loss : 0.8990
# Epoch [15/15], Step [510/847], Loss : 0.8978
# Epoch [15/15], Step [511/847], Loss : 0.8972
# Epoch [15/15], Step [512/847], Loss : 0.8983
# Epoch [15/15], Step [513/847], Loss : 0.8981
# Epoch [15/15], Step [514/847], Loss : 0.8981
# Epoch [15/15], Step [515/847], Loss : 0.8975
# Epoch [15/15], Step [516/847], Loss : 0.8983
# Epoch [15/15], Step [517/847], Loss : 0.8979
# Epoch [15/15], Step [518/847], Loss : 0.8985
# Epoch [15/15], Step [519/847], Loss : 0.8984
# Epoch [15/15], Step [520/847], Loss : 0.8984
# Epoch [15/15], Step [521/847], Loss : 0.9002
# Epoch [15/15], Step [522/847], Loss : 0.8998
# Epoch [15/15], Step [523/847], Loss : 0.8990
# Epoch [15/15], Step [524/847], Loss : 0.8995
# Epoch [15/15], Step [525/847], Loss : 0.8988
# Epoch [15/15], Step [526/847], Loss : 0.8984
# Epoch [15/15], Step [527/847], Loss : 0.8994
# Epoch [15/15], Step [528/847], Loss : 0.9003
# Epoch [15/15], Step [529/847], Loss : 0.9015
# Epoch [15/15], Step [530/847], Loss : 0.9005
# Epoch [15/15], Step [531/847], Loss : 0.8997
# Epoch [15/15], Step [532/847], Loss : 0.9000
# Epoch [15/15], Step [533/847], Loss : 0.9005
# Epoch [15/15], Step [534/847], Loss : 0.9000
# Epoch [15/15], Step [535/847], Loss : 0.8992
# Epoch [15/15], Step [536/847], Loss : 0.8991
# Epoch [15/15], Step [537/847], Loss : 0.8989
# Epoch [15/15], Step [538/847], Loss : 0.8981
# Epoch [15/15], Step [539/847], Loss : 0.8980
# Epoch [15/15], Step [540/847], Loss : 0.8978
# Epoch [15/15], Step [541/847], Loss : 0.8975
# Epoch [15/15], Step [542/847], Loss : 0.8970
# Epoch [15/15], Step [543/847], Loss : 0.8978
# Epoch [15/15], Step [544/847], Loss : 0.8974
# Epoch [15/15], Step [545/847], Loss : 0.8972
# Epoch [15/15], Step [546/847], Loss : 0.8965
# Epoch [15/15], Step [547/847], Loss : 0.8976
# Epoch [15/15], Step [548/847], Loss : 0.8972
# Epoch [15/15], Step [549/847], Loss : 0.8965
# Epoch [15/15], Step [550/847], Loss : 0.8971
# Epoch [15/15], Step [551/847], Loss : 0.8977
# Epoch [15/15], Step [552/847], Loss : 0.8964
# Epoch [15/15], Step [553/847], Loss : 0.8963
# Epoch [15/15], Step [554/847], Loss : 0.8963
# Epoch [15/15], Step [555/847], Loss : 0.8961
# Epoch [15/15], Step [556/847], Loss : 0.8951
# Epoch [15/15], Step [557/847], Loss : 0.8945
# Epoch [15/15], Step [558/847], Loss : 0.8937
# Epoch [15/15], Step [559/847], Loss : 0.8938
# Epoch [15/15], Step [560/847], Loss : 0.8934
# Epoch [15/15], Step [561/847], Loss : 0.8932
# Epoch [15/15], Step [562/847], Loss : 0.8931
# Epoch [15/15], Step [563/847], Loss : 0.8925
# Epoch [15/15], Step [564/847], Loss : 0.8919
# Epoch [15/15], Step [565/847], Loss : 0.8922
# Epoch [15/15], Step [566/847], Loss : 0.8917
# Epoch [15/15], Step [567/847], Loss : 0.8918
# Epoch [15/15], Step [568/847], Loss : 0.8923
# Epoch [15/15], Step [569/847], Loss : 0.8930
# Epoch [15/15], Step [570/847], Loss : 0.8928
# Epoch [15/15], Step [571/847], Loss : 0.8924
# Epoch [15/15], Step [572/847], Loss : 0.8922
# Epoch [15/15], Step [573/847], Loss : 0.8925
# Epoch [15/15], Step [574/847], Loss : 0.8937
# Epoch [15/15], Step [575/847], Loss : 0.8948
# Epoch [15/15], Step [576/847], Loss : 0.8949
# Epoch [15/15], Step [577/847], Loss : 0.8951
# Epoch [15/15], Step [578/847], Loss : 0.8946
# Epoch [15/15], Step [579/847], Loss : 0.8946
# Epoch [15/15], Step [580/847], Loss : 0.8937
# Epoch [15/15], Step [581/847], Loss : 0.8932
# Epoch [15/15], Step [582/847], Loss : 0.8948
# Epoch [15/15], Step [583/847], Loss : 0.8942
# Epoch [15/15], Step [584/847], Loss : 0.8941
# Epoch [15/15], Step [585/847], Loss : 0.8942
# Epoch [15/15], Step [586/847], Loss : 0.8957
# Epoch [15/15], Step [587/847], Loss : 0.8957
# Epoch [15/15], Step [588/847], Loss : 0.8962
# Epoch [15/15], Step [589/847], Loss : 0.8966
# Epoch [15/15], Step [590/847], Loss : 0.8964
# Epoch [15/15], Step [591/847], Loss : 0.8967
# Epoch [15/15], Step [592/847], Loss : 0.8962
# Epoch [15/15], Step [593/847], Loss : 0.8966
# Epoch [15/15], Step [594/847], Loss : 0.8961
# Epoch [15/15], Step [595/847], Loss : 0.8955
# Epoch [15/15], Step [596/847], Loss : 0.8945
# Epoch [15/15], Step [597/847], Loss : 0.8950
# Epoch [15/15], Step [598/847], Loss : 0.8954
# Epoch [15/15], Step [599/847], Loss : 0.8956
# Epoch [15/15], Step [600/847], Loss : 0.8958
# Epoch [15/15], Step [601/847], Loss : 0.8958
# Epoch [15/15], Step [602/847], Loss : 0.8958
# Epoch [15/15], Step [603/847], Loss : 0.8953
# Epoch [15/15], Step [604/847], Loss : 0.8950
# Epoch [15/15], Step [605/847], Loss : 0.8950
# Epoch [15/15], Step [606/847], Loss : 0.8950
# Epoch [15/15], Step [607/847], Loss : 0.8949
# Epoch [15/15], Step [608/847], Loss : 0.8953
# Epoch [15/15], Step [609/847], Loss : 0.8940
# Epoch [15/15], Step [610/847], Loss : 0.8946
# Epoch [15/15], Step [611/847], Loss : 0.8937
# Epoch [15/15], Step [612/847], Loss : 0.8943
# Epoch [15/15], Step [613/847], Loss : 0.8939
# Epoch [15/15], Step [614/847], Loss : 0.8937
# Epoch [15/15], Step [615/847], Loss : 0.8942
# Epoch [15/15], Step [616/847], Loss : 0.8945
# Epoch [15/15], Step [617/847], Loss : 0.8948
# Epoch [15/15], Step [618/847], Loss : 0.8944
# Epoch [15/15], Step [619/847], Loss : 0.8947
# Epoch [15/15], Step [620/847], Loss : 0.8948
# Epoch [15/15], Step [621/847], Loss : 0.8946
# Epoch [15/15], Step [622/847], Loss : 0.8937
# Epoch [15/15], Step [623/847], Loss : 0.8944
# Epoch [15/15], Step [624/847], Loss : 0.8943
# Epoch [15/15], Step [625/847], Loss : 0.8951
# Epoch [15/15], Step [626/847], Loss : 0.8953
# Epoch [15/15], Step [627/847], Loss : 0.8950
# Epoch [15/15], Step [628/847], Loss : 0.8950
# Epoch [15/15], Step [629/847], Loss : 0.8954
# Epoch [15/15], Step [630/847], Loss : 0.8956
# Epoch [15/15], Step [631/847], Loss : 0.8954
# Epoch [15/15], Step [632/847], Loss : 0.8950
# Epoch [15/15], Step [633/847], Loss : 0.8945
# Epoch [15/15], Step [634/847], Loss : 0.8951
# Epoch [15/15], Step [635/847], Loss : 0.8946
# Epoch [15/15], Step [636/847], Loss : 0.8944
# Epoch [15/15], Step [637/847], Loss : 0.8945
# Epoch [15/15], Step [638/847], Loss : 0.8944
# Epoch [15/15], Step [639/847], Loss : 0.8939
# Epoch [15/15], Step [640/847], Loss : 0.8935
# Epoch [15/15], Step [641/847], Loss : 0.8944
# Epoch [15/15], Step [642/847], Loss : 0.8943
# Epoch [15/15], Step [643/847], Loss : 0.8939
# Epoch [15/15], Step [644/847], Loss : 0.8943
# Epoch [15/15], Step [645/847], Loss : 0.8943
# Epoch [15/15], Step [646/847], Loss : 0.8946
# Epoch [15/15], Step [647/847], Loss : 0.8936
# Epoch [15/15], Step [648/847], Loss : 0.8937
# Epoch [15/15], Step [649/847], Loss : 0.8936
# Epoch [15/15], Step [650/847], Loss : 0.8930
# Epoch [15/15], Step [651/847], Loss : 0.8931
# Epoch [15/15], Step [652/847], Loss : 0.8929
# Epoch [15/15], Step [653/847], Loss : 0.8926
# Epoch [15/15], Step [654/847], Loss : 0.8925
# Epoch [15/15], Step [655/847], Loss : 0.8924
# Epoch [15/15], Step [656/847], Loss : 0.8920
# Epoch [15/15], Step [657/847], Loss : 0.8928
# Epoch [15/15], Step [658/847], Loss : 0.8923
# Epoch [15/15], Step [659/847], Loss : 0.8920
# Epoch [15/15], Step [660/847], Loss : 0.8913
# Epoch [15/15], Step [661/847], Loss : 0.8906
# Epoch [15/15], Step [662/847], Loss : 0.8909
# Epoch [15/15], Step [663/847], Loss : 0.8909
# Epoch [15/15], Step [664/847], Loss : 0.8914
# Epoch [15/15], Step [665/847], Loss : 0.8917
# Epoch [15/15], Step [666/847], Loss : 0.8920
# Epoch [15/15], Step [667/847], Loss : 0.8913
# Epoch [15/15], Step [668/847], Loss : 0.8913
# Epoch [15/15], Step [669/847], Loss : 0.8912
# Epoch [15/15], Step [670/847], Loss : 0.8907
# Epoch [15/15], Step [671/847], Loss : 0.8903
# Epoch [15/15], Step [672/847], Loss : 0.8898
# Epoch [15/15], Step [673/847], Loss : 0.8909
# Epoch [15/15], Step [674/847], Loss : 0.8912
# Epoch [15/15], Step [675/847], Loss : 0.8906
# Epoch [15/15], Step [676/847], Loss : 0.8910
# Epoch [15/15], Step [677/847], Loss : 0.8911
# Epoch [15/15], Step [678/847], Loss : 0.8909
# Epoch [15/15], Step [679/847], Loss : 0.8902
# Epoch [15/15], Step [680/847], Loss : 0.8900
# Epoch [15/15], Step [681/847], Loss : 0.8898
# Epoch [15/15], Step [682/847], Loss : 0.8896
# Epoch [15/15], Step [683/847], Loss : 0.8896
# Epoch [15/15], Step [684/847], Loss : 0.8891
# Epoch [15/15], Step [685/847], Loss : 0.8895
# Epoch [15/15], Step [686/847], Loss : 0.8889
# Epoch [15/15], Step [687/847], Loss : 0.8890
# Epoch [15/15], Step [688/847], Loss : 0.8898
# Epoch [15/15], Step [689/847], Loss : 0.8896
# Epoch [15/15], Step [690/847], Loss : 0.8894
# Epoch [15/15], Step [691/847], Loss : 0.8890
# Epoch [15/15], Step [692/847], Loss : 0.8894
# Epoch [15/15], Step [693/847], Loss : 0.8899
# Epoch [15/15], Step [694/847], Loss : 0.8902
# Epoch [15/15], Step [695/847], Loss : 0.8900
# Epoch [15/15], Step [696/847], Loss : 0.8895
# Epoch [15/15], Step [697/847], Loss : 0.8890
# Epoch [15/15], Step [698/847], Loss : 0.8891
# Epoch [15/15], Step [699/847], Loss : 0.8888
# Epoch [15/15], Step [700/847], Loss : 0.8889
# Epoch [15/15], Step [701/847], Loss : 0.8889
# Epoch [15/15], Step [702/847], Loss : 0.8885
# Epoch [15/15], Step [703/847], Loss : 0.8889
# Epoch [15/15], Step [704/847], Loss : 0.8885
# Epoch [15/15], Step [705/847], Loss : 0.8887
# Epoch [15/15], Step [706/847], Loss : 0.8888
# Epoch [15/15], Step [707/847], Loss : 0.8889
# Epoch [15/15], Step [708/847], Loss : 0.8886
# Epoch [15/15], Step [709/847], Loss : 0.8888
# Epoch [15/15], Step [710/847], Loss : 0.8902
# Epoch [15/15], Step [711/847], Loss : 0.8910
# Epoch [15/15], Step [712/847], Loss : 0.8906
# Epoch [15/15], Step [713/847], Loss : 0.8915
# Epoch [15/15], Step [714/847], Loss : 0.8924
# Epoch [15/15], Step [715/847], Loss : 0.8922
# Epoch [15/15], Step [716/847], Loss : 0.8920
# Epoch [15/15], Step [717/847], Loss : 0.8918
# Epoch [15/15], Step [718/847], Loss : 0.8924
# Epoch [15/15], Step [719/847], Loss : 0.8933
# Epoch [15/15], Step [720/847], Loss : 0.8934
# Epoch [15/15], Step [721/847], Loss : 0.8934
# Epoch [15/15], Step [722/847], Loss : 0.8931
# Epoch [15/15], Step [723/847], Loss : 0.8939
# Epoch [15/15], Step [724/847], Loss : 0.8940
# Epoch [15/15], Step [725/847], Loss : 0.8947
# Epoch [15/15], Step [726/847], Loss : 0.8947
# Epoch [15/15], Step [727/847], Loss : 0.8952
# Epoch [15/15], Step [728/847], Loss : 0.8958
# Epoch [15/15], Step [729/847], Loss : 0.8966
# Epoch [15/15], Step [730/847], Loss : 0.8960
# Epoch [15/15], Step [731/847], Loss : 0.8961
# Epoch [15/15], Step [732/847], Loss : 0.8967
# Epoch [15/15], Step [733/847], Loss : 0.8975
# Epoch [15/15], Step [734/847], Loss : 0.8974
# Epoch [15/15], Step [735/847], Loss : 0.8979
# Epoch [15/15], Step [736/847], Loss : 0.8988
# Epoch [15/15], Step [737/847], Loss : 0.8982
# Epoch [15/15], Step [738/847], Loss : 0.8980
# Epoch [15/15], Step [739/847], Loss : 0.8977
# Epoch [15/15], Step [740/847], Loss : 0.8975
# Epoch [15/15], Step [741/847], Loss : 0.8979
# Epoch [15/15], Step [742/847], Loss : 0.8975
# Epoch [15/15], Step [743/847], Loss : 0.8972
# Epoch [15/15], Step [744/847], Loss : 0.8973
# Epoch [15/15], Step [745/847], Loss : 0.8969
# Epoch [15/15], Step [746/847], Loss : 0.8971
# Epoch [15/15], Step [747/847], Loss : 0.8972
# Epoch [15/15], Step [748/847], Loss : 0.8974
# Epoch [15/15], Step [749/847], Loss : 0.8973
# Epoch [15/15], Step [750/847], Loss : 0.8981
# Epoch [15/15], Step [751/847], Loss : 0.8980
# Epoch [15/15], Step [752/847], Loss : 0.8984
# Epoch [15/15], Step [753/847], Loss : 0.8985
# Epoch [15/15], Step [754/847], Loss : 0.8990
# Epoch [15/15], Step [755/847], Loss : 0.8997
# Epoch [15/15], Step [756/847], Loss : 0.8993
# Epoch [15/15], Step [757/847], Loss : 0.8991
# Epoch [15/15], Step [758/847], Loss : 0.8994
# Epoch [15/15], Step [759/847], Loss : 0.8990
# Epoch [15/15], Step [760/847], Loss : 0.8993
# Epoch [15/15], Step [761/847], Loss : 0.8995
# Epoch [15/15], Step [762/847], Loss : 0.8996
# Epoch [15/15], Step [763/847], Loss : 0.8988
# Epoch [15/15], Step [764/847], Loss : 0.8985
# Epoch [15/15], Step [765/847], Loss : 0.8982
# Epoch [15/15], Step [766/847], Loss : 0.8983
# Epoch [15/15], Step [767/847], Loss : 0.8992
# Epoch [15/15], Step [768/847], Loss : 0.8992
# Epoch [15/15], Step [769/847], Loss : 0.8988
# Epoch [15/15], Step [770/847], Loss : 0.8986
# Epoch [15/15], Step [771/847], Loss : 0.8987
# Epoch [15/15], Step [772/847], Loss : 0.8987
# Epoch [15/15], Step [773/847], Loss : 0.8984
# Epoch [15/15], Step [774/847], Loss : 0.8987
# Epoch [15/15], Step [775/847], Loss : 0.8986
# Epoch [15/15], Step [776/847], Loss : 0.8980
# Epoch [15/15], Step [777/847], Loss : 0.8978
# Epoch [15/15], Step [778/847], Loss : 0.8971
# Epoch [15/15], Step [779/847], Loss : 0.8971
# Epoch [15/15], Step [780/847], Loss : 0.8972
# Epoch [15/15], Step [781/847], Loss : 0.8971
# Epoch [15/15], Step [782/847], Loss : 0.8970
# Epoch [15/15], Step [783/847], Loss : 0.8969
# Epoch [15/15], Step [784/847], Loss : 0.8972
# Epoch [15/15], Step [785/847], Loss : 0.8968
# Epoch [15/15], Step [786/847], Loss : 0.8988
# Epoch [15/15], Step [787/847], Loss : 0.8992
# Epoch [15/15], Step [788/847], Loss : 0.8996
# Epoch [15/15], Step [789/847], Loss : 0.8991
# Epoch [15/15], Step [790/847], Loss : 0.8982
# Epoch [15/15], Step [791/847], Loss : 0.8978
# Epoch [15/15], Step [792/847], Loss : 0.8972
# Epoch [15/15], Step [793/847], Loss : 0.8974
# Epoch [15/15], Step [794/847], Loss : 0.8983
# Epoch [15/15], Step [795/847], Loss : 0.8991
# Epoch [15/15], Step [796/847], Loss : 0.8994
# Epoch [15/15], Step [797/847], Loss : 0.8996
# Epoch [15/15], Step [798/847], Loss : 0.8996
# Epoch [15/15], Step [799/847], Loss : 0.9006
# Epoch [15/15], Step [800/847], Loss : 0.9005
# Epoch [15/15], Step [801/847], Loss : 0.9004
# Epoch [15/15], Step [802/847], Loss : 0.9009
# Epoch [15/15], Step [803/847], Loss : 0.9010
# Epoch [15/15], Step [804/847], Loss : 0.9015
# Epoch [15/15], Step [805/847], Loss : 0.9022
# Epoch [15/15], Step [806/847], Loss : 0.9017
# Epoch [15/15], Step [807/847], Loss : 0.9025
# Epoch [15/15], Step [808/847], Loss : 0.9021
# Epoch [15/15], Step [809/847], Loss : 0.9027
# Epoch [15/15], Step [810/847], Loss : 0.9023
# Epoch [15/15], Step [811/847], Loss : 0.9025
# Epoch [15/15], Step [812/847], Loss : 0.9027
# Epoch [15/15], Step [813/847], Loss : 0.9021
# Epoch [15/15], Step [814/847], Loss : 0.9023
# Epoch [15/15], Step [815/847], Loss : 0.9022
# Epoch [15/15], Step [816/847], Loss : 0.9028
# Epoch [15/15], Step [817/847], Loss : 0.9029
# Epoch [15/15], Step [818/847], Loss : 0.9023
# Epoch [15/15], Step [819/847], Loss : 0.9019
# Epoch [15/15], Step [820/847], Loss : 0.9016
# Epoch [15/15], Step [821/847], Loss : 0.9012
# Epoch [15/15], Step [822/847], Loss : 0.9020
# Epoch [15/15], Step [823/847], Loss : 0.9019
# Epoch [15/15], Step [824/847], Loss : 0.9027
# Epoch [15/15], Step [825/847], Loss : 0.9031
# Epoch [15/15], Step [826/847], Loss : 0.9029
# Epoch [15/15], Step [827/847], Loss : 0.9034
# Epoch [15/15], Step [828/847], Loss : 0.9032
# Epoch [15/15], Step [829/847], Loss : 0.9034
# Epoch [15/15], Step [830/847], Loss : 0.9032
# Epoch [15/15], Step [831/847], Loss : 0.9036
# Epoch [15/15], Step [832/847], Loss : 0.9044
# Epoch [15/15], Step [833/847], Loss : 0.9048
# Epoch [15/15], Step [834/847], Loss : 0.9049
# Epoch [15/15], Step [835/847], Loss : 0.9050
# Epoch [15/15], Step [836/847], Loss : 0.9055
# Epoch [15/15], Step [837/847], Loss : 0.9057
# Epoch [15/15], Step [838/847], Loss : 0.9059
# Epoch [15/15], Step [839/847], Loss : 0.9057
# Epoch [15/15], Step [840/847], Loss : 0.9059
# Epoch [15/15], Step [841/847], Loss : 0.9058
# Epoch [15/15], Step [842/847], Loss : 0.9051
# Epoch [15/15], Step [843/847], Loss : 0.9050
# Epoch [15/15], Step [844/847], Loss : 0.9045
# Epoch [15/15], Step [845/847], Loss : 0.9043
# Epoch [15/15], Step [846/847], Loss : 0.9039
# Epoch [15/15], Step [847/847], Loss : 0.9040
# Epoch: 15, Loss: 0.9040, Accuracy: 0.7580
# Saving best model!
# Finished Training

# %%
def testing(model, test_dl):
    criterion = nn.CrossEntropyLoss()
    gt = []
    pred = []
    with torch.no_grad():
        correct = 0
        total = 0
        val_loss = 0 
        for idx, data_ in enumerate(test_dl):
            inputs, labels = data_[0].to(device), data_[1].to(device)
            inputs_m, inputs_s = inputs.mean(), inputs.std()
            inputs = (inputs - inputs_m) / inputs_s
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, prediction = torch.max(outputs,1)
            predi = torch.softmax(outputs, dim = -1)
            gt.append(labels)
            pred.append(predi[:,1])
            correct += (prediction == labels).sum().item()
            total += prediction.shape[0]


        final_score = 100 * correct / total
        print("Final Test Accuracy", final_score)

# %%
saved_model_path = '/kaggle/working/BirdSound_MobileNetV2_fold0_epoch14.pth'
checkpoint = torch.load(saved_model_path)
model.load_state_dict(checkpoint)
model.eval()

testing(model, test_dl)
# Out:
# Final Test Accuracy 60.40129831808793
